# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
import getpass
import pdvega
import seaborn as sns
# for configuring connection 
from configobj import ConfigObj
import os

# %matplotlib inline

# %%
# Create a database connection using settings from config file
config='../db/config.ini'

# connection info
conn_info = dict()
if os.path.isfile(config):
    config = ConfigObj(config)
    conn_info["sqluser"] = config['username']
    conn_info["sqlpass"] = config['password']
    conn_info["sqlhost"] = config['host']
    conn_info["sqlport"] = config['port']
    conn_info["dbname"] = config['dbname']
    conn_info["schema_name"] = config['schema_name']
else:
    conn_info["sqluser"] = 'postgres'
    conn_info["sqlpass"] = ''
    conn_info["sqlhost"] = '192.168.60.144'
    conn_info["sqlport"] = 6432
    conn_info["dbname"] = 'eicu'
    conn_info["schema_name"] = 'public,eicu_crd'
    
# Connect to the eICU database
print('Database: {}'.format(conn_info['dbname']))
print('Username: {}'.format(conn_info["sqluser"]))
if conn_info["sqlpass"] == '':
    # try connecting without password, i.e. peer or OS authentication
    try:
        if (conn_info["sqlhost"] == '192.168.60.144') & (conn_info["sqlport"]=='6432'):
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   user=conn_info["sqluser"])            
        else:
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   host=conn_info["sqlhost"],
                                   port=conn_info["sqlport"],
                                   user=conn_info["sqluser"])
    except:
        conn_info["sqlpass"] = getpass.getpass('Password: ')

        con = psycopg2.connect(dbname=conn_info["dbname"],
                               host=conn_info["sqlhost"],
                               port=conn_info["sqlport"],
                               user=conn_info["sqluser"],
                               password=conn_info["sqlpass"])
query_schema = 'set search_path to ' + conn_info['schema_name'] + ';'
# Out:
# Database: eicu
# Username: postgres

# %%
from sqlalchemy import create_engine,text
con= create_engine('postgresql://eicu@192.168.60.144:6432/eicu')

# %%
datadir = '/home/mei/nas/docker/dataset/EICU/eicu-collaborative-research-database-2.0/'
porcesseddir2 = '/home/mei/nas/docker/processedData_2/'

# %%
def round_up(x, base=5):
    return base * round(x/base)

# %%
query = query_schema + """
select p.patientunitstayid, p.hospitaladmitOffset,a.drugoffset,p.gender, p.age, 
      p.apacheadmissiondx,a.drugname,p.unitadmitsource, p.admissionweight,	
      p.dischargeweight, p.unitdischargeoffset, p.unitdischargelocation,	
      p.unitdischargestatus
from admissiondrug a
join patient_2 p
  on a.patientunitstayid = p.patientunitstayid
  
order by p.patientunitstayid, p.hospitaladmitOffset,a.drugoffset
"""

# %%
df_drug_p = pd.read_sql_query(query,con)

# %%
df_drug_p.head(n=30)
# Out:
#     patientunitstayid  hospitaladmitoffset  drugoffset gender age  \
# 0              252784                    0          99   Male  56
# 1              252784                    0          99   Male  56
# 2              252784                    0          99   Male  56
# 3              252784                    0          99   Male  56
# 4              252784                    0          99   Male  56
# 5              252784                    0          99   Male  56
# 6              252784                    0          99   Male  56
# 7              252784                    0          99   Male  56
# 8              252784                    0          99   Male  56
# 9              252784                    0          99   Male  56
# 10             252784                    0          99   Male  56
# 11             252784                    0          99   Male  56
# 12             253331                  -42           2   Male  76
# 13             253331                  -42           2   Male  76
# 14             253331                  -42           2   Male  76
# 15             253331                  -42           2   Male  76
# 16             253331                  -42           2   Male  76
# 17             253331                  -42           2   Male  76
# 18             253331                  -42           2   Male  76
# 19             253331                  -42           2   Male  76
# 20             253331                  -42           2   Male  76
# 21             253331                  -42           2   Male  76
# 22             253331                  -42           2   Male  76
# 23             253331                  -42           2   Male  76
# 24             253331                  -42         867   Male  76
# 25             253331                  -42         867   Male  76
# 26             253331                  -42         867   Male  76
# 27             253331                  -42         867   Male  76
# 28             253331                  -42         867   Male  76
# 29             253331                  -42         867   Male  76
#
#                 apacheadmissiondx  \
# 0           Diabetic ketoacidosis
# 1           Diabetic ketoacidosis
# 2           Diabetic ketoacidosis
# 3           Diabetic ketoacidosis
# 4           Diabetic ketoacidosis
# 5           Diabetic ketoacidosis
# 6           Diabetic ketoacidosis
# 7           Diabetic ketoacidosis
# 8           Diabetic ketoacidosis
# 9           Diabetic ketoacidosis
# 10          Diabetic ketoacidosis
# 11          Diabetic ketoacidosis
# 12  CHF, congestive heart failure
# 13  CHF, congestive heart failure
# 14  CHF, congestive heart failure
# 15  CHF, congestive heart failure
# 16  CHF, congestive heart failure
# 17  CHF, congestive heart failure
# 18  CHF, congestive heart failure
# 19  CHF, congestive heart failure
# 20  CHF, congestive heart failure
# 21  CHF, congestive heart failure
# 22  CHF, congestive heart failure
# 23  CHF, congestive heart failure
# 24  CHF, congestive heart failure
# 25  CHF, congestive heart failure
# 26  CHF, congestive heart failure
# 27  CHF, congestive heart failure
# 28  CHF, congestive heart failure
# 29  CHF, congestive heart failure
#
#                                              drugname       unitadmitsource  \
# 0   LANTUS                                        ...  Emergency Department
# 1   OMEPRAZOLE                                    ...  Emergency Department
# 2   NITROGLYCERIN                                 ...  Emergency Department
# 3   LISINOPRIL                                    ...  Emergency Department
# 4   MULTIVITAMIN                                  ...  Emergency Department
# 5   ASPIRIN                                       ...  Emergency Department
# 6   FLAX SEED OIL                                 ...  Emergency Department
# 7   OMEGA 3                                       ...  Emergency Department
# 8   NOVOLOG                                       ...  Emergency Department
# 9   ATORVASTATIN CALCIUM                          ...  Emergency Department
# 10  CARVEDILOL                                    ...  Emergency Department
# 11  CHOLECALCIFEROL (VITAMIN D3)                  ...  Emergency Department
# 12  WARFARIN SODIUM                               ...          Direct Admit
# 13  MIRALAX                                       ...          Direct Admit
# 14  COREG                                         ...          Direct Admit
# 15  FUROSEMIDE                                    ...          Direct Admit
# 16  ALBUTEROL                                     ...          Direct Admit
# 17  AGGRENOX                                      ...          Direct Admit
# 18  CRESTOR                                       ...          Direct Admit
# 19  SOTALOL                                       ...          Direct Admit
# 20  ALLOPURINOL                                   ...          Direct Admit
# 21  SPIRIVA                                       ...          Direct Admit
# 22  ALDACTONE                                     ...          Direct Admit
# 23  VITAMIN D-3                                   ...          Direct Admit
# 24  SPIRIVA                                       ...          Direct Admit
# 25  COREG                                         ...          Direct Admit
# 26  WARFARIN SODIUM                               ...          Direct Admit
# 27  ALLOPURINOL                                   ...          Direct Admit
# 28  AGGRENOX                                      ...          Direct Admit
# 29  FUROSEMIDE                                    ...          Direct Admit
#
#     admissionweight  dischargeweight  unitdischargeoffset  \
# 0              75.0             75.7                 2952
# 1              75.0             75.7                 2952
# 2              75.0             75.7                 2952
# 3              75.0             75.7                 2952
# 4              75.0             75.7                 2952
# 5              75.0             75.7                 2952
# 6              75.0             75.7                 2952
# 7              75.0             75.7                 2952
# 8              75.0             75.7                 2952
# 9              75.0             75.7                 2952
# 10             75.0             75.7                 2952
# 11             75.0             75.7                 2952
# 12            114.7            114.4                 2538
# 13            114.7            114.4                 2538
# 14            114.7            114.4                 2538
# 15            114.7            114.4                 2538
# 16            114.7            114.4                 2538
# 17            114.7            114.4                 2538
# 18            114.7            114.4                 2538
# 19            114.7            114.4                 2538
# 20            114.7            114.4                 2538
# 21            114.7            114.4                 2538
# 22            114.7            114.4                 2538
# 23            114.7            114.4                 2538
# 24            114.7            114.4                 2538
# 25            114.7            114.4                 2538
# 26            114.7            114.4                 2538
# 27            114.7            114.4                 2538
# 28            114.7            114.4                 2538
# 29            114.7            114.4                 2538
#
#    unitdischargelocation unitdischargestatus
# 0                  Floor               Alive
# 1                  Floor               Alive
# 2                  Floor               Alive
# 3                  Floor               Alive
# 4                  Floor               Alive
# 5                  Floor               Alive
# 6                  Floor               Alive
# 7                  Floor               Alive
# 8                  Floor               Alive
# 9                  Floor               Alive
# 10                 Floor               Alive
# 11                 Floor               Alive
# 12                 Floor               Alive
# 13                 Floor               Alive
# 14                 Floor               Alive
# 15                 Floor               Alive
# 16                 Floor               Alive
# 17                 Floor               Alive
# 18                 Floor               Alive
# 19                 Floor               Alive
# 20                 Floor               Alive
# 21                 Floor               Alive
# 22                 Floor               Alive
# 23                 Floor               Alive
# 24                 Floor               Alive
# 25                 Floor               Alive
# 26                 Floor               Alive
# 27                 Floor               Alive
# 28                 Floor               Alive
# 29                 Floor               Alive

# %%
df= df_drug_p.copy()
df = df.set_index(['patientunitstayid', 'hospitaladmitoffset','drugoffset'])
df = df.drop(df.index[np.where(df.index.get_level_values('drugoffset') < 0)])
df.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'drugoffset'], inplace = True)
# Resample every 5 mins
df.rename(round_up, level = 'drugoffset', inplace = True)
df['drugname'] = df['drugname'].str.split(' ').str[0].str.lower()

# %%
df.head(n=20)
# Out:
#                                                  gender age  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
# 253331            -42                 0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#                                       0            Male  76
#
#                                                               apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
#                                       100                 Diabetic ketoacidosis
# 253331            -42                 0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#                                       0           CHF, congestive heart failure
#
#                                                          drugname  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                 novolog
#                                       100                    flax
#                                       100              lisinopril
#                                       100            multivitamin
#                                       100                 aspirin
#                                       100              omeprazole
#                                       100                   omega
#                                       100                  lantus
#                                       100              carvedilol
#                                       100            atorvastatin
#                                       100         cholecalciferol
#                                       100           nitroglycerin
# 253331            -42                 0                   sotalol
#                                       0                   miralax
#                                       0                 albuterol
#                                       0                  aggrenox
#                                       0                   spiriva
#                                       0               allopurinol
#                                       0                   crestor
#                                       0                   vitamin
#
#                                                        unitadmitsource  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
# 253331            -42                 0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#                                       0                   Direct Admit
#
#                                                   admissionweight  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
# 253331            -42                 0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#                                       0                     114.7
#
#                                                   dischargeweight  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
# 253331            -42                 0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#                                       0                     114.4
#
#                                                   unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
# 253331            -42                 0                          2538
#                                       0                          2538
#                                       0                          2538
#                                       0                          2538
#                                       0                          2538
#                                       0                          2538
#                                       0                          2538
#                                       0                          2538
#
#                                                  unitdischargelocation  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
# 253331            -42                 0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#                                       0                          Floor
#
#                                                  unitdischargestatus
# patientunitstayid hospitaladmitoffset drugoffset
# 252784             0                  100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
# 253331            -42                 0                        Alive
#                                       0                        Alive
#                                       0                        Alive
#                                       0                        Alive
#                                       0                        Alive
#                                       0                        Alive
#                                       0                        Alive
#                                       0                        Alive

# %%
# df.to_csv(porcesseddir2 + 'selected_patient_drugname.csv',  index=True)

# %%
n=len(list(df.index.get_level_values('patientunitstayid').unique()))
r=len(df)
print("There are {} unique patientunitstayid in the selected patients with the total {} records.".format(n,r))
# Out:
# There are 15789 unique patientunitstayid in the selected patients with the total 325226 records.

# %% [markdown]
# ## frequency of drug

# %%
freq_addrug = pd.DataFrame()
freq_addrug['noAnnotations'] = df['drugname'].value_counts() 
freq_addrug['%'] = df['drugname'].value_counts() / len(df.index) * 100
# freq_addrug.to_csv(porcesseddir2 + 'selected_patient_drugname_freq.csv',  index=True)

# %%
freq_addrug= pd.read_csv(porcesseddir2 + 'selected_patient_drugname_freq.csv')

# %%
print(freq_addrug)
# Out:
#         drugname  noAnnotations         %
# 0        aspirin          10705  3.291557
# 1     lisinopril           6917  2.126829
# 2          lasix           5968  1.835032
# 3        vitamin           5883  1.808896
# 4     metoprolol           5205  1.600426
# ...          ...            ...       ...
# 2518    immulife              1  0.000307
# 2519    multigen              1  0.000307
# 2520    solosite              1  0.000307
# 2521  hemorrhoid              1  0.000307
# 2522        tart              1  0.000307
#
# [2523 rows x 3 columns]

# %%
df_drug=df.copy()
frequency_table =df_drug.groupby(['apacheadmissiondx','drugname']).size().reset_index(name='count')
frequency_table = frequency_table.sort_values(by='count', ascending=False)

print(frequency_table)
# Out:
#                           apacheadmissiondx       drugname  count
# 30757                     Sepsis, pulmonary        aspirin    808
# 5705          CHF, congestive heart failure        aspirin    628
# 31224                     Sepsis, pulmonary          lasix    620
# 6524   CVA, cerebrovascular accident/stroke        aspirin    616
# 6050          CHF, congestive heart failure          lasix    605
# ...                                     ...            ...    ...
# 13490               Encephalopathy, hepatic  acetaminophen      1
# 13489  Encephalopathies (excluding hepatic)         zyrtec      1
# 13486  Encephalopathies (excluding hepatic)    zafirlukast      1
# 13483  Encephalopathies (excluding hepatic)     wellbutrin      1
# 17548                Hepatic failure, acute          zyvox      1
#
# [35097 rows x 3 columns]

# %%
# frequency_table.to_csv(porcesseddir2 + 'selected_patient_drugname_addx_freq.csv',  index=False)

# %%
frequency_table=pd.read_csv(porcesseddir2 + 'selected_patient_drugname_addx_freq.csv')

# %%
frequency_table.head(n=20)
# Out:
#                         apacheadmissiondx    drugname  count
# 0                       Sepsis, pulmonary     aspirin    808
# 1           CHF, congestive heart failure     aspirin    628
# 2                       Sepsis, pulmonary       lasix    620
# 3    CVA, cerebrovascular accident/stroke     aspirin    616
# 4           CHF, congestive heart failure       lasix    605
# 5                       Sepsis, pulmonary   albuterol    579
# 6                   Diabetic ketoacidosis      lantus    561
# 7                    Emphysema/bronchitis   albuterol    508
# 8   Sepsis, renal/UTI (including bladder)     aspirin    477
# 9   Sepsis, renal/UTI (including bladder)     vitamin    454
# 10   CVA, cerebrovascular accident/stroke  lisinopril    432
# 11                      Sepsis, pulmonary  lisinopril    421
# 12                   Pneumonia, bacterial     vitamin    404
# 13                      Sepsis, pulmonary  metoprolol    395
# 14      Infarction, acute myocardial (MI)     aspirin    375
# 15                   Emphysema/bronchitis      advair    375
# 16                      Sepsis, pulmonary     vitamin    374
# 17           Respiratory - medical, other     aspirin    370
# 18          CHF, congestive heart failure  lisinopril    359
# 19                   Emphysema/bronchitis  prednisone    342

# %% [markdown]
# ## 统计 nan 值

# %%
missing_ratio = pd.DataFrame(df.isna().sum() / len(df.index), columns = ['missing ratio %']) * 100
missing_ratio.sort_values('missing ratio %', inplace = True, ascending = False) 
missing_ratio
# Out:
#                        missing ratio %
# dischargeweight              36.762743
# admissionweight               0.432622
# gender                        0.000000
# age                           0.000000
# apacheadmissiondx             0.000000
# drugname                      0.000000
# unitadmitsource               0.000000
# unitdischargeoffset           0.000000
# unitdischargelocation         0.000000
# unitdischargestatus           0.000000

# %% [markdown]
# ## encoding drug name via one hot encoding

# %%
df_drug_p=pd.read_csv(porcesseddir2 + 'selected_patient_drugname.csv')

df= df_drug_p.copy()
df = df.set_index(['patientunitstayid', 'hospitaladmitoffset','drugoffset'])
df.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'drugoffset'], inplace = True)

# %%
df.head(n=10)
# Out:
#                                                  gender age  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#                                       100          Male  56
#
#                                                       apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#                                       100         Diabetic ketoacidosis
#
#                                                       drugname  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100              novolog
#                                       100                 flax
#                                       100           lisinopril
#                                       100         multivitamin
#                                       100              aspirin
#                                       100           omeprazole
#                                       100                omega
#                                       100               lantus
#                                       100           carvedilol
#                                       100         atorvastatin
#
#                                                        unitadmitsource  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#                                       100         Emergency Department
#
#                                                   admissionweight  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#                                       100                    75.0
#
#                                                   dischargeweight  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#                                       100                    75.7
#
#                                                   unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#                                       100                        2952
#
#                                                  unitdischargelocation  \
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#                                       100                        Floor
#
#                                                  unitdischargestatus
# patientunitstayid hospitaladmitoffset drugoffset
# 252784            0                   100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive
#                                       100                      Alive

# %%
drug_dummies = pd.get_dummies(df['drugname'])

df_encoded = pd.concat([df, drug_dummies], axis=1)

df_patient_drug = df_encoded.groupby('patientunitstayid').max()

df_patient_drug.head()
# Out:
#                    gender age  \
# patientunitstayid
# 252784               Male  56
# 253331               Male  76
# 255112               Male  52
# 258354             Female  61
# 259414               Male  81
#
#                                                    apacheadmissiondx  \
# patientunitstayid
# 252784                                         Diabetic ketoacidosis
# 253331                                 CHF, congestive heart failure
# 255112             Cardiac arrest (with or without respiratory ar...
# 258354             Hypertension, uncontrolled (for cerebrovascula...
# 259414                          CVA, cerebrovascular accident/stroke
#
#                      drugname       unitadmitsource  admissionweight  \
# patientunitstayid
# 252784             omeprazole  Emergency Department            75.00
# 253331               warfarin          Direct Admit           114.70
# 255112                   zinc          Direct Admit            50.60
# 258354                xopenex  Emergency Department            74.38
# 259414               zyloprim  Emergency Department           107.50
#
#                    dischargeweight  unitdischargeoffset unitdischargelocation  \
# patientunitstayid
# 252784                        75.7                 2952                 Floor
# 253331                       114.4                 2538                 Floor
# 255112                        58.2                15463                 Death
# 258354                        75.3                 4333                 Floor
# 259414                       106.7                 8433                 Floor
#
#                   unitdischargestatus  ...  zovirax  zyban  zyflo  zyloprim  \
# patientunitstayid                      ...
# 252784                          Alive  ...    False  False  False     False
# 253331                          Alive  ...    False  False  False     False
# 255112                        Expired  ...    False  False  False     False
# 258354                          Alive  ...    False  False  False     False
# 259414                          Alive  ...    False  False  False      True
#
#                    zymaxid  zyprexa  zyrtec  zyrtec-d  zytiga  zyvox
# patientunitstayid
# 252784               False    False   False     False   False  False
# 253331               False    False   False     False   False  False
# 255112               False    False   False     False   False  False
# 258354               False    False   False     False   False  False
# 259414               False    False   False     False   False  False
#
# [5 rows x 2533 columns]
