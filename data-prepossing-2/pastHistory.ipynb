# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
import getpass
import pdvega
import seaborn as sns
# for configuring connection 
from configobj import ConfigObj
import os

# %matplotlib inline

# %%
datadir = '/home/mei/nas/docker/dataset/EICU/eicu-collaborative-research-database-2.0/'
porcesseddir2 = '/home/mei/nas/docker/processedData_2/'

# %%
# Create a database connection using settings from config file
config='../db/config.ini'

# connection info
conn_info = dict()
if os.path.isfile(config):
    config = ConfigObj(config)
    conn_info["sqluser"] = config['username']
    conn_info["sqlpass"] = config['password']
    conn_info["sqlhost"] = config['host']
    conn_info["sqlport"] = config['port']
    conn_info["dbname"] = config['dbname']
    conn_info["schema_name"] = config['schema_name']
else:
    conn_info["sqluser"] = 'postgres'
    conn_info["sqlpass"] = ''
    conn_info["sqlhost"] = '192.168.60.144'
    conn_info["sqlport"] = 6432
    conn_info["dbname"] = 'eicu'
    conn_info["schema_name"] = 'public,eicu_crd'
    
# Connect to the eICU database
print('Database: {}'.format(conn_info['dbname']))
print('Username: {}'.format(conn_info["sqluser"]))
if conn_info["sqlpass"] == '':
    # try connecting without password, i.e. peer or OS authentication
    try:
        if (conn_info["sqlhost"] == '192.168.60.144') & (conn_info["sqlport"]=='6432'):
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   user=conn_info["sqluser"])            
        else:
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   host=conn_info["sqlhost"],
                                   port=conn_info["sqlport"],
                                   user=conn_info["sqluser"])
    except:
        conn_info["sqlpass"] = getpass.getpass('Password: ')

        con = psycopg2.connect(dbname=conn_info["dbname"],
                               host=conn_info["sqlhost"],
                               port=conn_info["sqlport"],
                               user=conn_info["sqluser"],
                               password=conn_info["sqlpass"])
query_schema = 'set search_path to ' + conn_info['schema_name'] + ';'
# Out:
# Database: eicu
# Username: postgres

# %%
from sqlalchemy import create_engine,text
con= create_engine('postgresql://eicu@192.168.60.144:6432/eicu')

# %%
def round_up(x, base=5):
    return base * round(x/base)

# %%
query = query_schema + """
select p.patientunitstayid, p.hospitaladmitOffset,ph.pasthistoryoffset,p.gender, p.age, 
      p.apacheadmissiondx,ph.pasthistorypath,p.unitadmitsource, p.admissionweight,	
      p.dischargeweight, p.unitdischargeoffset, p.unitdischargelocation,	
      p.unitdischargestatus
from pasthistory ph
join patient_2 p
  on ph.patientunitstayid = p.patientunitstayid
  
order by p.patientunitstayid, p.hospitaladmitOffset,ph.pasthistoryoffset
"""

# %%
df_past= pd.read_sql_query(query,con)
df_past.head(n=20)
# Out:
#     patientunitstayid  hospitaladmitoffset  pasthistoryoffset  gender age  \
# 0              141168                    0                 60  Female  70
# 1              141168                    0                 60  Female  70
# 2              141168                    0                 60  Female  70
# 3              141168                    0                 60  Female  70
# 4              141168                    0                 60  Female  70
# 5              141168                    0                 60  Female  70
# 6              141168                    0                 60  Female  70
# 7              141168                    0                 60  Female  70
# 8              141168                    0                 60  Female  70
# 9              141168                    0                114  Female  70
# 10             141168                    0                114  Female  70
# 11             141168                    0                114  Female  70
# 12             141168                    0                114  Female  70
# 13             141168                    0                114  Female  70
# 14             141168                    0                114  Female  70
# 15             141168                    0                114  Female  70
# 16             141265                   -1                 23    Male  67
# 17             141265                   -1                 23    Male  67
# 18             141266                  -18                 40    Male  73
# 19             141266                  -18                 40    Male  73
#
#                                 apacheadmissiondx  \
# 0   Rhythm disturbance (atrial, supraventricular)
# 1   Rhythm disturbance (atrial, supraventricular)
# 2   Rhythm disturbance (atrial, supraventricular)
# 3   Rhythm disturbance (atrial, supraventricular)
# 4   Rhythm disturbance (atrial, supraventricular)
# 5   Rhythm disturbance (atrial, supraventricular)
# 6   Rhythm disturbance (atrial, supraventricular)
# 7   Rhythm disturbance (atrial, supraventricular)
# 8   Rhythm disturbance (atrial, supraventricular)
# 9   Rhythm disturbance (atrial, supraventricular)
# 10  Rhythm disturbance (atrial, supraventricular)
# 11  Rhythm disturbance (atrial, supraventricular)
# 12  Rhythm disturbance (atrial, supraventricular)
# 13  Rhythm disturbance (atrial, supraventricular)
# 14  Rhythm disturbance (atrial, supraventricular)
# 15  Rhythm disturbance (atrial, supraventricular)
# 16           CVA, cerebrovascular accident/stroke
# 17           CVA, cerebrovascular accident/stroke
# 18          Sepsis, renal/UTI (including bladder)
# 19          Sepsis, renal/UTI (including bladder)
#
#                                       pasthistorypath       unitadmitsource  \
# 0   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 1   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 2   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 3   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 4   notes/Progress Notes/Past History/Past History...          Direct Admit
# 5   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 6   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 7   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 8   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 9   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 10  notes/Progress Notes/Past History/Past History...          Direct Admit
# 11  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 12  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 13  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 14  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 15  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 16  notes/Progress Notes/Past History/Past History...          Direct Admit
# 17  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 18  notes/Progress Notes/Past History/Organ System...  Emergency Department
# 19  notes/Progress Notes/Past History/Past History...  Emergency Department
#
#     admissionweight  dischargeweight  unitdischargeoffset  \
# 0              84.3             85.8                 3596
# 1              84.3             85.8                 3596
# 2              84.3             85.8                 3596
# 3              84.3             85.8                 3596
# 4              84.3             85.8                 3596
# 5              84.3             85.8                 3596
# 6              84.3             85.8                 3596
# 7              84.3             85.8                 3596
# 8              84.3             85.8                 3596
# 9              84.3             85.8                 3596
# 10             84.3             85.8                 3596
# 11             84.3             85.8                 3596
# 12             84.3             85.8                 3596
# 13             84.3             85.8                 3596
# 14             84.3             85.8                 3596
# 15             84.3             85.8                 3596
# 16            100.0             91.8                 6068
# 17            100.0             91.8                 6068
# 18            120.4            112.9                 1501
# 19            120.4            112.9                 1501
#
#    unitdischargelocation unitdischargestatus
# 0                  Death             Expired
# 1                  Death             Expired
# 2                  Death             Expired
# 3                  Death             Expired
# 4                  Death             Expired
# 5                  Death             Expired
# 6                  Death             Expired
# 7                  Death             Expired
# 8                  Death             Expired
# 9                  Death             Expired
# 10                 Death             Expired
# 11                 Death             Expired
# 12                 Death             Expired
# 13                 Death             Expired
# 14                 Death             Expired
# 15                 Death             Expired
# 16                 Floor               Alive
# 17                 Floor               Alive
# 18                 Floor               Alive
# 19                 Floor               Alive

# %%
df=df_past.copy()
# Set indices
df = df.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df = df.drop(df.index[np.where(df.index.get_level_values('pasthistoryoffset') < 0)])
df.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
# Resample every 5 mins
df.rename(round_up, level = 'pasthistoryoffset', inplace = True)
df.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Past History...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       115                notes/Progress Notes/Past History/Organ System...
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired

# %%
df1 = df[df['pasthistorypath'].str.contains('Organ Systems')]
df1 = df1.reset_index()
df1['pasthistorypath'] = df1['pasthistorypath'].str.replace('notes/Progress Notes/Past History/Organ Systems/', ' ')
df1['pasthistorypath'] = df1['pasthistorypath'].str.replace('|', '/')
split = df1['pasthistorypath'].str.split('/')
df1['first'] = split.str[0]
df1['second'] = split.str[1]
df1['third'] = split.str[2]
df1['fourth'] = split.str[3]

df1.head()
# Out:
#    patientunitstayid  hospitaladmitoffset  pasthistoryoffset  gender age  \
# 0             141168                    0                 60  Female  70
# 1             141168                    0                 60  Female  70
# 2             141168                    0                 60  Female  70
# 3             141168                    0                 60  Female  70
# 4             141168                    0                 60  Female  70
#
#                                apacheadmissiondx  \
# 0  Rhythm disturbance (atrial, supraventricular)
# 1  Rhythm disturbance (atrial, supraventricular)
# 2  Rhythm disturbance (atrial, supraventricular)
# 3  Rhythm disturbance (atrial, supraventricular)
# 4  Rhythm disturbance (atrial, supraventricular)
#
#                                      pasthistorypath unitadmitsource  \
# 0              Pulmonary/COPD/COPD  - no limitations    Direct Admit
# 1                Cardiovascular (R)/Valve disease/AS    Direct Admit
# 2   Cardiovascular (R)/Congestive Heart Failure/C...    Direct Admit
# 3   Cardiovascular (R)/Hypertension Requiring Tre...    Direct Admit
# 4                       Cardiovascular (R)/AICD/AICD    Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1             84.3             85.8                 3596
# 2             84.3             85.8                 3596
# 3             84.3             85.8                 3596
# 4             84.3             85.8                 3596
#
#   unitdischargelocation unitdischargestatus                first  \
# 0                 Death             Expired            Pulmonary
# 1                 Death             Expired   Cardiovascular (R)
# 2                 Death             Expired   Cardiovascular (R)
# 3                 Death             Expired   Cardiovascular (R)
# 4                 Death             Expired   Cardiovascular (R)
#
#                              second                             third fourth
# 0                              COPD            COPD  - no limitations    NaN
# 1                     Valve disease                                AS    NaN
# 2          Congestive Heart Failure                    CHF - class II    NaN
# 3  Hypertension Requiring Treatment  hypertension requiring treatment    NaN
# 4                              AICD                              AICD    NaN

# %%
columns = df1.columns.tolist()
index = columns.index('pasthistorypath')
new_order = columns[:index + 1] + ['first', 'second', 'third', 'fourth'] + columns[index + 1:-4]
df1 = df1.reindex(columns=new_order)
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
# df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
df1.head()
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#
#                                                                                     third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           COPD  - no limitations
#                                       60                                               AS
#                                       60                                   CHF - class II
#                                       60                 hypertension requiring treatment
#                                       60                                             AICD
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired

# %%
# df1.to_csv(porcesseddir2 + 'selected_pastHistory.csv',  index=True)

# %%
n=len(list(df1.index.get_level_values('patientunitstayid').unique()))
r=len(df1)
print("There are {} unique patientunitstayid in the selected patients with the total {} records.".format(n,r))
# Out:
# There are 53612 unique patientunitstayid in the selected patients with the total 312103 records.

# %%
df1= pd.read_csv(porcesseddir2 + 'selected_pastHistory.csv')
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
df1.head(n=20)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
# 141265            -1                  25                   Male  67
# 141266            -18                 40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
# 141265            -1                  25                          CVA, cerebrovascular accident/stroke
# 141266            -18                 40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#                                       115                 Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                            Pulmonary/COPD/COPD  - no limitations
#                                       115                 Cardiovascular (R)/Congestive Heart Failure/C...
#                                       115                 Renal  (R)/Renal Failure/renal failure- not c...
# 141265            -1                  25                  Endocrine (R)/Non-Insulin Dependent Diabetes/...
# 141266            -18                 40                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       40                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       40                  Cardiovascular (R)/Angina/angina - severity u...
#                                       40                  Renal  (R)/Renal Insufficiency/renal insuffic...
#                                       40                  Endocrine (R)/Insulin Dependent Diabetes/insu...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                          Pulmonary
#                                       115                 Cardiovascular (R)
#                                       115                         Renal  (R)
# 141265            -1                  25                       Endocrine (R)
# 141266            -18                 40                  Cardiovascular (R)
#                                       40                  Cardiovascular (R)
#                                       40                  Cardiovascular (R)
#                                       40                          Renal  (R)
#                                       40                       Endocrine (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#                                       115                                     Arrhythmias
#                                       115                                            COPD
#                                       115                        Congestive Heart Failure
#                                       115                                   Renal Failure
# 141265            -1                  25                   Non-Insulin Dependent Diabetes
# 141266            -18                 40                 Hypertension Requiring Treatment
#                                       40                         Congestive Heart Failure
#                                       40                                           Angina
#                                       40                              Renal Insufficiency
#                                       40                       Insulin Dependent Diabetes
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                                COPD  - no limitations
#                                       60                                                    AS
#                                       60                                        CHF - class II
#                                       60                      hypertension requiring treatment
#                                       60                                                  AICD
#                                       60                 renal failure- not currently dialyzed
#                                       60                                  rheumatoid arthritis
#                                       60                         atrial fibrillation - chronic
#                                       115                                                   AS
#                                       115                     hypertension requiring treatment
#                                       115                        atrial fibrillation - chronic
#                                       115                               COPD  - no limitations
#                                       115                               CHF - severity unknown
#                                       115                renal failure- not currently dialyzed
# 141265            -1                  25                                  medication dependent
# 141266            -18                 40                      hypertension requiring treatment
#                                       40                                CHF - severity unknown
#                                       40                             angina - severity unknown
#                                       40                  renal insufficiency - creatinine 1-2
#                                       40                            insulin dependent diabetes
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       115                  NaN
#                                       115                  NaN
#                                       115                  NaN
#                                       115                  NaN
#                                       115                  NaN
#                                       115                  NaN
# 141265            -1                  25                   NaN
# 141266            -18                 40                   NaN
#                                       40                   NaN
#                                       40                   NaN
#                                       40                   NaN
#                                       40                   NaN
#
#                                                               unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       60                         Direct Admit
#                                       115                        Direct Admit
#                                       115                        Direct Admit
#                                       115                        Direct Admit
#                                       115                        Direct Admit
#                                       115                        Direct Admit
#                                       115                        Direct Admit
# 141265            -1                  25                         Direct Admit
# 141266            -18                 40                 Emergency Department
#                                       40                 Emergency Department
#                                       40                 Emergency Department
#                                       40                 Emergency Department
#                                       40                 Emergency Department
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#                                       115                           84.3
#                                       115                           84.3
#                                       115                           84.3
#                                       115                           84.3
#                                       115                           84.3
# 141265            -1                  25                           100.0
# 141266            -18                 40                           120.4
#                                       40                           120.4
#                                       40                           120.4
#                                       40                           120.4
#                                       40                           120.4
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#                                       115                           85.8
#                                       115                           85.8
#                                       115                           85.8
#                                       115                           85.8
#                                       115                           85.8
# 141265            -1                  25                            91.8
# 141266            -18                 40                           112.9
#                                       40                           112.9
#                                       40                           112.9
#                                       40                           112.9
#                                       40                           112.9
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#                                       115                               3596
#                                       115                               3596
#                                       115                               3596
#                                       115                               3596
#                                       115                               3596
# 141265            -1                  25                                6068
# 141266            -18                 40                                1501
#                                       40                                1501
#                                       40                                1501
#                                       40                                1501
#                                       40                                1501
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#                                       115                               Death
#                                       115                               Death
#                                       115                               Death
#                                       115                               Death
#                                       115                               Death
# 141265            -1                  25                                Floor
# 141266            -18                 40                                Floor
#                                       40                                Floor
#                                       40                                Floor
#                                       40                                Floor
#                                       40                                Floor
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired
#                                       115                           Expired
#                                       115                           Expired
#                                       115                           Expired
#                                       115                           Expired
#                                       115                           Expired
# 141265            -1                  25                              Alive
# 141266            -18                 40                              Alive
#                                       40                              Alive
#                                       40                              Alive
#                                       40                              Alive
#                                       40                              Alive

# %%
df1_reset = df1.reset_index()
df_unique = df1_reset.drop_duplicates(subset=['patientunitstayid'])
freq = pd.DataFrame()
freq['noAnnotations'] = df_unique['apacheadmissiondx'].value_counts()
freq['%'] = (df_unique['apacheadmissiondx'].value_counts() / len(df_unique)) * 100
freq.head(n=10)
# Out:
#                                                     noAnnotations         %
# apacheadmissiondx
# Sepsis, pulmonary                                            3972  7.408789
# CVA, cerebrovascular accident/stroke                         2923  5.452138
# Infarction, acute myocardial (MI)                            2867  5.347683
# CHF, congestive heart failure                                2773  5.172349
# Sepsis, renal/UTI (including bladder)                        2552  4.760128
# Diabetic ketoacidosis                                        2316  4.319928
# Emphysema/bronchitis                                         1944  3.626054
# Cardiac arrest (with or without respiratory arr...           1599  2.982541
# Pneumonia, bacterial                                         1576  2.939640
# Rhythm disturbance (atrial, supraventricular)                1560  2.909796

# %%
# freq.to_csv(porcesseddir2 + 'selected_pastHistory_apacheaddx_freq.csv',  index=True)

# %% [markdown]
# ## nan 值统计

# %%
missing_ratio = pd.DataFrame(df1.isna().sum() / len(df1.index), columns = ['missing ratio %']) * 100
missing_ratio.sort_values('missing ratio %', inplace = True, ascending = False) 
missing_ratio
# Out:
#                        missing ratio %
# fourth                       89.413431
# dischargeweight              34.968264
# admissionweight               1.186788
# gender                        0.000000
# age                           0.000000
# apacheadmissiondx             0.000000
# pasthistorypath               0.000000
# first                         0.000000
# second                        0.000000
# third                         0.000000
# unitadmitsource               0.000000
# unitdischargeoffset           0.000000
# unitdischargelocation         0.000000
# unitdischargestatus           0.000000

# %% [markdown]
# ## frequency of past dx history

# %% [markdown]
# ### first

# %%
frequency1 = pd.DataFrame()
frequency1['noAnnotations'] = df1['first'].value_counts() 
frequency1['%'] = df1['first'].value_counts() / len(df1.index) * 100
frequency1
# Out:
#                         noAnnotations          %
# first
# Cardiovascular (R)             144104  46.171937
# Endocrine (R)                   45774  14.666312
# Pulmonary                       39744  12.734258
# Neurologic                      27196   8.713790
# Hematology                      22345   7.159495
# Renal  (R)                      17722   5.678254
# Gastrointestinal (R)            10621   3.403043
# Rheumatic                        2666   0.854205
# Infectious Disease (R)           1931   0.618706

# %%
frequency2 = pd.DataFrame()
frequency2['noAnnotations'] = df1['second'].value_counts() 
frequency2['%'] = df1['second'].value_counts() / len(df1.index) * 100
frequency2
# Out:
#                                         noAnnotations          %
# second
# Hypertension Requiring Treatment                56983  18.257755
# Oncology (R)                                    22345   7.159495
# COPD                                            19067   6.109201
# Congestive Heart Failure                        18473   5.918879
# Non-Insulin Dependent Diabetes                  17760   5.690429
# Insulin Dependent Diabetes                      16268   5.212382
# Arrhythmias                                     15676   5.022701
# Myocardial Infarction                           10655   3.413937
# Hypothyroidism                                  10649   3.412015
# Strokes                                         10374   3.323903
# Renal Insufficiency                              8535   2.734674
# Asthma                                           8242   2.640795
# Procedural Coronary Intervention                 7897   2.530254
# Seizures                                         7720   2.473542
# Renal Failure                                    7279   2.332243
# Coronary Artery Bypass                           7155   2.292512
# Cirrhosis                                        7148   2.290270
# Valve disease                                    5973   1.913791
# Peripheral Vascular Disease                      5149   1.649776
# Home Oxygen                                      4963   1.590180
# Dementia                                         4536   1.453366
# Venous Thrombosis                                4292   1.375187
# Pacemaker                                        4019   1.287716
# Respiratory Failure                              3573   1.144814
# Peptic Ulcer Disease                             3112   0.997107
# TIA(s)                                           3003   0.962182
# Pulmonary Function Tests                         2831   0.907072
# Angina                                           2533   0.811591
# Pulmonary Embolism                               2389   0.765452
# AICD                                             2270   0.727324
# Rheumatoid Arthritis                             1973   0.632163
# Neuromuscular Disease                            1127   0.361099
# Immunosuppression within past 6 months           1053   0.337389
# Chronic Stone Disease                            1019   0.326495
# s                                                 999   0.320087
# Restrictive Disease                               894   0.286444
# HIV (only)                                        676   0.216595
# Recent Steroid Use (for > 10 days)                559   0.179108
# Exercise Tolerance                                526   0.168534
# SLE                                               525   0.168214
# Hyperthyroidism                                   452   0.144824
# Intracranial Mass                                 436   0.139697
# Neurogenic Bladder                                270   0.086510
# AIDS                                              202   0.064722
# Sarcoidosis                                       142   0.045498
# Vasculitis                                        110   0.035245
# Hypersplenism                                     106   0.033963
# Hypercalcemia                                      64   0.020506
# Scleroderma                                        33   0.010573
# Dermato                                            25   0.008010
# Cushing's Syndrome                                 22   0.007049
# RTA                                                21   0.006729

# %%
frequency3 = pd.DataFrame()
frequency3['noAnnotations'] = df1['third'].value_counts() 
frequency3['%'] = df1['third'].value_counts() / len(df1.index) * 100
frequency3.head(n=10)
# Out:
#                                   noAnnotations          %
# third
# hypertension requiring treatment          56983  18.257755
# Cancer                                    17532   5.617376
# insulin dependent diabetes                16268   5.212382
# CHF                                       14251   4.566121
# medication dependent                      13678   4.382528
# atrial fibrillation - chronic             10881   3.486349
# hypothyroidism                            10649   3.412015
# COPD  - moderate                           9063   2.903849
# asthma                                     8242   2.640795
# stroke - date unknown                      6399   2.050285

# %%
frequency4 = pd.DataFrame()
frequency4['noAnnotations'] = df1['fourth'].value_counts() 
frequency4['%'] = df1['fourth'].value_counts() / len(df1.index) * 100
frequency4
# Out:
#                                         noAnnotations         %
# fourth
# Cancer-Primary Site                             12246  3.923705
# Metastases                                       3389  1.085859
# multiple                                         3035  0.972435
# Chemotherapy                                     2274  0.728606
# Hematologic Malignancy                           1897  0.607812
# p AVR                                            1286  0.412043
# Radiation Therapy within past 6 months           1113  0.356613
# s                                                 999  0.320087
# o GI bleeding                                     967  0.309834
# V paced                                           796  0.255044
# FVC Ratio                                         715  0.229091
# p MVR                                             592  0.189681
# hemolytic anemia                                  468  0.149950
# FVC >80                                           263  0.084267
# FEV1 41-50                                        257  0.082345
# hypercoagulable condition                         214  0.068567
# ITP                                               196  0.062800
# FEV1 31-40                                        195  0.062479
# FEV1 >80                                          177  0.056712
# clotting disorder                                 173  0.055430
# sickle cell disease                               167  0.053508
# FEV1 51-60                                        161  0.051586
# FVC 51-60                                         140  0.044857
# FVC 41-50                                         126  0.040371
# FEV1 61-70                                        125  0.040051
# FVC 61-70                                         113  0.036206
# FEV1 <30                                           97  0.031079
# FEV1 71-80                                         92  0.029477
# aplastic anemia                                    87  0.027875
# brisk walking (5-10 mets)                          84  0.026914
# p TVR                                              81  0.025953
# FVC 71-80                                          59  0.018904
# FVC 31-40                                          58  0.018584
# DLCO 31-40                                         52  0.016661
# essential thrombocytosis                           52  0.016661
# DLCO <30                                           46  0.014739
# DLCO 51-60                                         43  0.013778
# myelofibrosis                                      42  0.013457
# FVC <30                                            34  0.010894
# DLCO 71-80                                         33  0.010573
# polycythemia vera                                  27  0.008651
# dermatomyositis                                    25  0.008010
# DLCO 41-50                                         17  0.005447
# DLCO >80                                           15  0.004806
# DLCO 61-70                                         13  0.004165

# %%
df_past_dx=df1.copy()
frequency_table_1 =df_past_dx.groupby(['apacheadmissiondx','first']).size().reset_index(name='count')
frequency_table_1 = frequency_table_1.sort_values(by='count', ascending=False)
frequency_table_1.head(n=20)
# Out:
#                                       apacheadmissiondx                first  \
# 309                       CHF, congestive heart failure   Cardiovascular (R)
# 1603                                  Sepsis, pulmonary   Cardiovascular (R)
# 318                CVA, cerebrovascular accident/stroke   Cardiovascular (R)
# 1110                  Infarction, acute myocardial (MI)   Cardiovascular (R)
# 1612              Sepsis, renal/UTI (including bladder)   Cardiovascular (R)
# 677                                Emphysema/bronchitis            Pulmonary
# 389   Cardiac arrest (with or without respiratory ar...   Cardiovascular (R)
# 671                                Emphysema/bronchitis   Cardiovascular (R)
# 1413                               Pneumonia, bacterial   Cardiovascular (R)
# 1534      Rhythm disturbance (atrial, supraventricular)   Cardiovascular (R)
# 1609                                  Sepsis, pulmonary            Pulmonary
# 1621                                    Sepsis, unknown   Cardiovascular (R)
# 1507                       Respiratory - medical, other   Cardiovascular (R)
# 1604                                  Sepsis, pulmonary        Endocrine (R)
# 607                               Diabetic ketoacidosis        Endocrine (R)
# 260                                  Bleeding, upper GI   Cardiovascular (R)
# 251                                  Bleeding, lower GI   Cardiovascular (R)
# 1474                               Renal failure, acute   Cardiovascular (R)
# 242                       Bleeding, GI-location unknown   Cardiovascular (R)
# 310                       CHF, congestive heart failure        Endocrine (R)
#
#       count
# 309   11868
# 1603  10688
# 318    7596
# 1110   7308
# 1612   6442
# 677    5130
# 389    4985
# 671    4823
# 1413   4509
# 1534   4405
# 1609   4161
# 1621   3941
# 1507   3879
# 1604   3390
# 607    3338
# 260    3244
# 251    3185
# 1474   3120
# 242    2847
# 310    2746

# %%
frequency_table_2 =df_past_dx.groupby(['apacheadmissiondx','second']).size().reset_index(name='count')
frequency_table_2 = frequency_table_2.sort_values(by='count', ascending=False)
frequency_table_2.head(n=20)
# Out:
#                                       apacheadmissiondx  \
# 5294                                  Sepsis, pulmonary
# 1023               CVA, cerebrovascular accident/stroke
# 974                       CHF, congestive heart failure
# 965                       CHF, congestive heart failure
# 3564                  Infarction, acute myocardial (MI)
# 2135                               Emphysema/bronchitis
# 5344              Sepsis, renal/UTI (including bladder)
# 1904                              Diabetic ketoacidosis
# 5304                                  Sepsis, pulmonary
# 5283                                  Sepsis, pulmonary
# 1193  Cardiac arrest (with or without respiratory ar...
# 2147                               Emphysema/bronchitis
# 4518                               Pneumonia, bacterial
# 5286                                  Sepsis, pulmonary
# 3171                  Hemorrhage/hematoma, intracranial
# 4974      Rhythm disturbance (atrial, supraventricular)
# 842                                  Bleeding, upper GI
# 4856                       Respiratory - medical, other
# 5281                                  Sepsis, pulmonary
# 5354              Sepsis, renal/UTI (including bladder)
#
#                                 second  count
# 5294  Hypertension Requiring Treatment   3941
# 1023  Hypertension Requiring Treatment   3595
# 974   Hypertension Requiring Treatment   3101
# 965           Congestive Heart Failure   2856
# 3564  Hypertension Requiring Treatment   2841
# 2135                              COPD   2599
# 5344  Hypertension Requiring Treatment   2585
# 1904        Insulin Dependent Diabetes   2573
# 5304                      Oncology (R)   2436
# 5283                              COPD   2203
# 1193  Hypertension Requiring Treatment   1903
# 2147  Hypertension Requiring Treatment   1858
# 4518  Hypertension Requiring Treatment   1757
# 5286          Congestive Heart Failure   1673
# 3171  Hypertension Requiring Treatment   1529
# 4974  Hypertension Requiring Treatment   1517
# 842   Hypertension Requiring Treatment   1379
# 4856  Hypertension Requiring Treatment   1367
# 5281                       Arrhythmias   1329
# 5354                      Oncology (R)   1313

# %%
df1.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                COPD  - no limitations
#                                       60                                                    AS
#                                       60                                        CHF - class II
#                                       60                      hypertension requiring treatment
#                                       60                                                  AICD
#                                       60                 renal failure- not currently dialyzed
#                                       60                                  rheumatoid arthritis
#                                       60                         atrial fibrillation - chronic
#                                       115                                                   AS
#                                       115                     hypertension requiring treatment
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       115                  NaN
#                                       115                  NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#                                       115                               Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired
#                                       115                           Expired

# %%
df1['first'].unique()
# Out:
# array(['Pulmonary', 'Cardiovascular (R)', 'Renal  (R)', 'Rheumatic',
#        'Endocrine (R)', 'Gastrointestinal (R)', 'Infectious Disease (R)',
#        'Neurologic', 'Hematology'], dtype=object)

# %%
# 去除 first 列中的多余空格
df1['first'] = df1['first'].str.strip()

# 然后运行你的代码
from tabulate import tabulate

diseases = ['Cardiovascular (R)', 'Endocrine (R)', 'Pulmonary', 'Neurologic', 'Hematology', 'Renal  (R)', 'Gastrointestinal (R)', 'Rheumatic', 'Infectious Disease (R)']

for disease in diseases:
    # 筛选出特定疾病的数据
    df_disease = df1[df1['first'] == disease].copy()
    # 统计疾病的频率
    freq = pd.DataFrame()
    freq['noAnnotations'] = df_disease['second'].value_counts()
    freq['%'] = round(df_disease['second'].value_counts() / len(df_disease.index) * 100, 2)

    # 格式化输出
    table = tabulate(freq, headers="keys", tablefmt="psql", showindex=True)
    print(f"The frequency of {disease}:")
    print(table)
    print("------------------------------")
# Out:
# The frequency of Cardiovascular (R):
# +----------------------------------+-----------------+-------+
# | second                           |   noAnnotations |     % |
# |----------------------------------+-----------------+-------|
# | Hypertension Requiring Treatment |           56983 | 39.54 |
# | Congestive Heart Failure         |           18473 | 12.82 |
# | Arrhythmias                      |           15676 | 10.88 |
# | Myocardial Infarction            |           10655 |  7.39 |
# | Procedural Coronary Intervention |            7897 |  5.48 |
# | Coronary Artery Bypass           |            7155 |  4.97 |
# | Valve disease                    |            5973 |  4.14 |
# | Peripheral Vascular Disease      |            5149 |  3.57 |
# | Venous Thrombosis                |            4292 |  2.98 |
# | Pacemaker                        |            4019 |  2.79 |
# | Angina                           |            2533 |  1.76 |
# | Pulmonary Embolism               |            2389 |  1.66 |
# | AICD                             |            2270 |  1.58 |
# | Exercise Tolerance               |             526 |  0.37 |
# | s                                |             114 |  0.08 |
# +----------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Endocrine (R):
# +------------------------------------+-----------------+-------+
# | second                             |   noAnnotations |     % |
# |------------------------------------+-----------------+-------|
# | Non-Insulin Dependent Diabetes     |           17760 | 38.8  |
# | Insulin Dependent Diabetes         |           16268 | 35.54 |
# | Hypothyroidism                     |           10649 | 23.26 |
# | Recent Steroid Use (for > 10 days) |             559 |  1.22 |
# | Hyperthyroidism                    |             452 |  0.99 |
# | Hypercalcemia                      |              64 |  0.14 |
# | Cushing's Syndrome                 |              22 |  0.05 |
# +------------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Pulmonary:
# +--------------------------+-----------------+-------+
# | second                   |   noAnnotations |     % |
# |--------------------------+-----------------+-------|
# | COPD                     |           19067 | 47.97 |
# | Asthma                   |            8242 | 20.74 |
# | Home Oxygen              |            4963 | 12.49 |
# | Respiratory Failure      |            3573 |  8.99 |
# | Pulmonary Function Tests |            2831 |  7.12 |
# | Restrictive Disease      |             894 |  2.25 |
# | Sarcoidosis              |             142 |  0.36 |
# | s                        |              32 |  0.08 |
# +--------------------------+-----------------+-------+
# ------------------------------
# The frequency of Neurologic:
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Strokes               |           10374 | 38.15 |
# | Seizures              |            7720 | 28.39 |
# | Dementia              |            4536 | 16.68 |
# | TIA(s)                |            3003 | 11.04 |
# | Neuromuscular Disease |            1127 |  4.14 |
# | Intracranial Mass     |             436 |  1.6  |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Hematology:
# +--------------+-----------------+-----+
# | second       |   noAnnotations |   % |
# |--------------+-----------------+-----|
# | Oncology (R) |           22345 | 100 |
# +--------------+-----------------+-----+
# ------------------------------
# The frequency of Renal  (R):
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Renal Insufficiency   |            8535 | 48.16 |
# | Renal Failure         |            7279 | 41.07 |
# | Chronic Stone Disease |            1019 |  5.75 |
# | s                     |             598 |  3.37 |
# | Neurogenic Bladder    |             270 |  1.52 |
# | RTA                   |              21 |  0.12 |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Gastrointestinal (R):
# +----------------------+-----------------+------+
# | second               |   noAnnotations |    % |
# |----------------------+-----------------+------|
# | Cirrhosis            |            7148 | 67.3 |
# | Peptic Ulcer Disease |            3112 | 29.3 |
# | s                    |             255 |  2.4 |
# | Hypersplenism        |             106 |  1   |
# +----------------------+-----------------+------+
# ------------------------------
# The frequency of Rheumatic:
# +----------------------+-----------------+-------+
# | second               |   noAnnotations |     % |
# |----------------------+-----------------+-------|
# | Rheumatoid Arthritis |            1973 | 74.01 |
# | SLE                  |             525 | 19.69 |
# | Vasculitis           |             110 |  4.13 |
# | Scleroderma          |              33 |  1.24 |
# | Dermato              |              25 |  0.94 |
# +----------------------+-----------------+-------+
# ------------------------------
# The frequency of Infectious Disease (R):
# +----------------------------------------+-----------------+-------+
# | second                                 |   noAnnotations |     % |
# |----------------------------------------+-----------------+-------|
# | Immunosuppression within past 6 months |            1053 | 54.53 |
# | HIV (only)                             |             676 | 35.01 |
# | AIDS                                   |             202 | 10.46 |
# +----------------------------------------+-----------------+-------+
# ------------------------------

# %%
from bigtree import Node, list_to_tree, tree_to_dot, dataframe_to_tree, tree_to_pillow

for disease in frequency1.index.get_level_values('first'):
    df_ = df1[df1['first'] == disease]
    # df_.set_index(['patientunitstayid', 'pasthistoryoffset'], inplace = True)
    
    paths_mult_ = df_.groupby('pasthistorypath', dropna = True)['pasthistorypath'].size().to_frame('noAnnotations')
    paths_mult_.reset_index(inplace=True)
    paths_mult_.sort_values('noAnnotations', ascending = False, inplace = True)

    paths_ = list(pd.unique(df_['pasthistorypath']))
    root_ = dataframe_to_tree(paths_mult_, sep = '/')
    root_.show(attr_list=["noAnnotations"])
    pillow_image_ = tree_to_pillow(root_)
    pillow_image_.save(porcesseddir2  + str(disease) + "selected_pastHistoryTree.jpg")
# Out:
#  Cardiovascular (R)
# ├── Hypertension Requiring Treatment
# │   └── hypertension requiring treatment [noAnnotations=56983]
# ├── Congestive Heart Failure
# │   ├── CHF [noAnnotations=14251]
# │   ├── CHF - severity unknown [noAnnotations=2524]
# │   ├── CHF - class III [noAnnotations=570]
# │   ├── CHF - class IV [noAnnotations=452]
# │   ├── CHF - class II [noAnnotations=443]
# │   └── CHF - class I [noAnnotations=233]
# ├── Arrhythmias
# │   ├── atrial fibrillation - chronic [noAnnotations=10881]
# │   ├── atrial fibrillation - intermittent [noAnnotations=3017]
# │   ├── ventricular tachycardia [noAnnotations=602]
# │   ├── SVT- other [noAnnotations=464]
# │   ├── sick sinus syndrome [noAnnotations=438]
# │   ├── ventricular fibrillation [noAnnotations=128]
# │   ├── ventricular ectopy [noAnnotations=118]
# │   └── MAT [noAnnotations=28]
# ├── Myocardial Infarction
# │   ├── MI - date unknown [noAnnotations=5826]
# │   ├── MI - remote [noAnnotations=1931]
# │   ├── MI - within 6 months [noAnnotations=1029]
# │   ├── MI - within 2 years [noAnnotations=667]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=620]
# │   └── MI - within 5 years [noAnnotations=582]
# ├── Peripheral Vascular Disease
# │   └── peripheral vascular disease [noAnnotations=5149]
# ├── Procedural Coronary Intervention
# │   ├── procedural coronary intervention - date unknown [noAnnotations=3815]
# │   ├── procedural coronary intervention - remote [noAnnotations=1321]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=806]
# │   ├── procedural coronary intervention - within 6 months [noAnnotations=704]
# │   ├── procedural coronary intervention - within 2 years [noAnnotations=638]
# │   └── procedural coronary intervention - within 5 years [noAnnotations=613]
# ├── Coronary Artery Bypass
# │   ├── CABG - date unknown [noAnnotations=3424]
# │   ├── CABG - remote [noAnnotations=2199]
# │   ├── CABG - within 5 years [noAnnotations=469]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=415]
# │   ├── CABG - within 6 months [noAnnotations=376]
# │   └── CABG - within 2 years [noAnnotations=272]
# ├── Venous Thrombosis
# │   ├── DVT - date unknown [noAnnotations=2817]
# │   ├── DVT - within 6 months [noAnnotations=529]
# │   ├── DVT - within 2 years [noAnnotations=352]
# │   ├── DVT - remote [noAnnotations=339]
# │   ├── DVT - within 5 years [noAnnotations=161]
# │   └── multiple
# │       └── multiple [noAnnotations=94]
# ├── Pacemaker
# │   ├── unknown pacer [noAnnotations=2540]
# │   ├── A
# │   │   └── V paced [noAnnotations=796]
# │   ├── V paced [noAnnotations=515]
# │   └── A paced [noAnnotations=168]
# ├── AICD
# │   └── AICD [noAnnotations=2270]
# ├── Angina
# │   ├── angina [noAnnotations=1970]
# │   ├── angina - severity unknown [noAnnotations=410]
# │   ├── angina - class II [noAnnotations=64]
# │   ├── angina - class III [noAnnotations=54]
# │   ├── angina - class I [noAnnotations=24]
# │   └── angina - class IV [noAnnotations=11]
# ├── Valve disease
# │   ├── MR [noAnnotations=1418]
# │   ├── AS [noAnnotations=1327]
# │   ├── s
# │   │   ├── p AVR [noAnnotations=1286]
# │   │   ├── p MVR [noAnnotations=592]
# │   │   └── p TVR [noAnnotations=81]
# │   ├── TR [noAnnotations=687]
# │   ├── AR [noAnnotations=387]
# │   ├── MS [noAnnotations=181]
# │   └── PS [noAnnotations=14]
# ├── Pulmonary Embolism
# │   ├── pulmonary embolism - date unknown [noAnnotations=1231]
# │   ├── pulmonary embolism - within 6 months [noAnnotations=394]
# │   ├── pulmonary embolism - within 2 years [noAnnotations=290]
# │   ├── pulmonary embolism - remote [noAnnotations=287]
# │   ├── pulmonary embolism - within 5 years [noAnnotations=126]
# │   └── multiple
# │       └── multiple [noAnnotations=61]
# ├── Exercise Tolerance
# │   ├── limited - household activities (1-4 mets) [noAnnotations=354]
# │   ├── moderate - stairs
# │   │   └── brisk walking (5-10 mets) [noAnnotations=84]
# │   ├── none - bed-ridden [noAnnotations=51]
# │   ├── unknown [noAnnotations=23]
# │   └── excellent - strenuous exercise (>10 mets) [noAnnotations=14]
# └── s
#     └── p Heart Transplant
#         └── s
#             └── p heart transplant [noAnnotations=114]
#  Endocrine (R)
# ├── Insulin Dependent Diabetes
# │   └── insulin dependent diabetes [noAnnotations=16268]
# ├── Non-Insulin Dependent Diabetes
# │   ├── medication dependent [noAnnotations=13678]
# │   └── non-medication dependent [noAnnotations=4082]
# ├── Hypothyroidism
# │   └── hypothyroidism [noAnnotations=10649]
# ├── Recent Steroid Use (for > 10 days)
# │   └── recent steroid use for > 10 days [noAnnotations=559]
# ├── Hyperthyroidism
# │   └── hyperthyroidism [noAnnotations=452]
# ├── Hypercalcemia
# │   └── hypercalcemia [noAnnotations=64]
# └── Cushing's Syndrome
#     └── Cushing's syndrome [noAnnotations=22]
#  Pulmonary
# ├── COPD
# │   ├── COPD  - moderate [noAnnotations=9063]
# │   ├── COPD  - severe [noAnnotations=5135]
# │   └── COPD  - no limitations [noAnnotations=4869]
# ├── Asthma
# │   └── asthma [noAnnotations=8242]
# ├── Home Oxygen
# │   └── home oxygen [noAnnotations=4963]
# ├── Respiratory Failure
# │   ├── respiratory failure - within 6 months [noAnnotations=1533]
# │   ├── respiratory failure - date unknown [noAnnotations=933]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=537]
# │   ├── respiratory failure - within 2 years [noAnnotations=287]
# │   ├── respiratory failure - remote [noAnnotations=162]
# │   └── respiratory failure - within 5 years [noAnnotations=121]
# ├── Restrictive Disease
# │   └── restrictive pulmonary disease [noAnnotations=894]
# ├── Pulmonary Function Tests
# │   ├── FEV1
# │   │   └── FVC Ratio
# │   │       └── FEV1
# │   │           ├── FVC ratio >80 [noAnnotations=295]
# │   │           ├── FVC ratio 71-80 [noAnnotations=133]
# │   │           ├── FVC ratio 51-60 [noAnnotations=116]
# │   │           ├── FVC ratio 61-70 [noAnnotations=71]
# │   │           ├── FVC ratio 41-50 [noAnnotations=61]
# │   │           ├── FVC ratio 31-40 [noAnnotations=36]
# │   │           └── FVC ratio <30 [noAnnotations=3]
# │   ├── FVC (%)
# │   │   ├── FVC >80 [noAnnotations=263]
# │   │   ├── FVC 51-60 [noAnnotations=140]
# │   │   ├── FVC 41-50 [noAnnotations=126]
# │   │   ├── FVC 61-70 [noAnnotations=113]
# │   │   ├── FVC 71-80 [noAnnotations=59]
# │   │   ├── FVC 31-40 [noAnnotations=58]
# │   │   └── FVC <30 [noAnnotations=34]
# │   ├── FEV1 (%)
# │   │   ├── FEV1 41-50 [noAnnotations=257]
# │   │   ├── FEV1 31-40 [noAnnotations=195]
# │   │   ├── FEV1 >80 [noAnnotations=177]
# │   │   ├── FEV1 51-60 [noAnnotations=161]
# │   │   ├── FEV1 61-70 [noAnnotations=125]
# │   │   ├── FEV1 <30 [noAnnotations=97]
# │   │   └── FEV1 71-80 [noAnnotations=92]
# │   └── DLCO (%)
# │       ├── DLCO 31-40 [noAnnotations=52]
# │       ├── DLCO <30 [noAnnotations=46]
# │       ├── DLCO 51-60 [noAnnotations=43]
# │       ├── DLCO 71-80 [noAnnotations=33]
# │       ├── DLCO 41-50 [noAnnotations=17]
# │       ├── DLCO >80 [noAnnotations=15]
# │       └── DLCO 61-70 [noAnnotations=13]
# ├── Sarcoidosis
# │   └── sarcoidosis [noAnnotations=142]
# └── s
#     └── p Lung Transplant
#         └── s
#             └── p lung transplant [noAnnotations=32]
#  Neurologic
# ├── Strokes
# │   ├── stroke - date unknown [noAnnotations=6399]
# │   ├── stroke - remote [noAnnotations=1191]
# │   ├── stroke - within 6 months [noAnnotations=984]
# │   ├── stroke - within 2 years [noAnnotations=716]
# │   ├── stroke - within 5 years [noAnnotations=712]
# │   └── multiple
# │       └── multiple [noAnnotations=372]
# ├── Dementia
# │   └── dementia [noAnnotations=4536]
# ├── Seizures
# │   ├── generalized seizures [noAnnotations=3758]
# │   ├── other seizures [noAnnotations=3270]
# │   ├── focal seizures [noAnnotations=405]
# │   └── petite mal seizures [noAnnotations=287]
# ├── TIA(s)
# │   ├── TIA(s) - date unknown [noAnnotations=2188]
# │   ├── TIA(s) - remote [noAnnotations=297]
# │   ├── TIA(s) - within 6 months [noAnnotations=166]
# │   ├── TIA(s) - within 2 years [noAnnotations=139]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=130]
# │   └── TIA(s) - within 5 years [noAnnotations=83]
# ├── Neuromuscular Disease
# │   └── neuromuscular disease [noAnnotations=1127]
# └── Intracranial Mass
#     └── intracranial mass [noAnnotations=436]
#  Hematology
# └── Oncology (R)
#     ├── Cancer
#     │   ├── Cancer-Primary Site
#     │   │   ├── breast [noAnnotations=2259]
#     │   │   ├── lung [noAnnotations=1944]
#     │   │   ├── prostate [noAnnotations=1738]
#     │   │   ├── colon [noAnnotations=1484]
#     │   │   ├── other [noAnnotations=911]
#     │   │   ├── bladder [noAnnotations=650]
#     │   │   ├── kidney [noAnnotations=469]
#     │   │   ├── melanoma [noAnnotations=403]
#     │   │   ├── uterus [noAnnotations=370]
#     │   │   ├── head and neck [noAnnotations=349]
#     │   │   ├── esophagus [noAnnotations=290]
#     │   │   ├── pancreas - adenocarcinoma [noAnnotations=246]
#     │   │   ├── liver [noAnnotations=229]
#     │   │   ├── brain [noAnnotations=210]
#     │   │   ├── ovary [noAnnotations=206]
#     │   │   ├── unknown [noAnnotations=128]
#     │   │   ├── stomach [noAnnotations=113]
#     │   │   ├── testes [noAnnotations=90]
#     │   │   ├── bile duct [noAnnotations=49]
#     │   │   ├── bone [noAnnotations=48]
#     │   │   ├── sarcoma [noAnnotations=23]
#     │   │   ├── pancreas - islet cell [noAnnotations=21]
#     │   │   └── none [noAnnotations=16]
#     │   ├── Metastases
#     │   │   ├── lung [noAnnotations=636]
#     │   │   ├── other [noAnnotations=624]
#     │   │   ├── liver [noAnnotations=605]
#     │   │   ├── bone [noAnnotations=602]
#     │   │   ├── brain [noAnnotations=421]
#     │   │   ├── nodes [noAnnotations=270]
#     │   │   ├── intra-abdominal [noAnnotations=190]
#     │   │   └── carcinomatosis [noAnnotations=41]
#     │   └── Hematologic Malignancy
#     │       ├── non-Hodgkins lymphoma [noAnnotations=566]
#     │       ├── multiple myeloma [noAnnotations=369]
#     │       ├── CLL [noAnnotations=198]
#     │       ├── AML [noAnnotations=191]
#     │       ├── other hematologic malignancy [noAnnotations=185]
#     │       ├── Hodgkins disease [noAnnotations=162]
#     │       ├── leukemia - other [noAnnotations=123]
#     │       ├── CML [noAnnotations=67]
#     │       └── ALL [noAnnotations=36]
#     ├── Cancer Therapy
#     │   ├── Chemotherapy
#     │   │   ├── chemotherapy within past mo. [noAnnotations=1534]
#     │   │   ├── chemotherapy within past 6 mos. [noAnnotations=629]
#     │   │   ├── BMT within past 12 mos. [noAnnotations=39]
#     │   │   ├── Cis-platinum [noAnnotations=29]
#     │   │   ├── Alkylating agents (bleomycin, cytoxan, cyclophos.) [noAnnotations=26]
#     │   │   ├── Anthracyclines (adriamycin, daunorubicin) [noAnnotations=12]
#     │   │   └── Vincristine [noAnnotations=5]
#     │   └── Radiation Therapy within past 6 months
#     │       ├── primary site [noAnnotations=525]
#     │       ├── lung [noAnnotations=216]
#     │       ├── other [noAnnotations=137]
#     │       ├── brain [noAnnotations=136]
#     │       ├── bone [noAnnotations=68]
#     │       ├── liver [noAnnotations=18]
#     │       └── nodes [noAnnotations=13]
#     ├── Hemolytic Anemia
#     │   └── hemolytic anemia [noAnnotations=468]
#     ├── Hypercoagulable Condition
#     │   └── hypercoagulable condition [noAnnotations=214]
#     ├── ITP
#     │   └── ITP [noAnnotations=196]
#     ├── Clotting Disorder
#     │   └── clotting disorder [noAnnotations=173]
#     ├── Sickle Cell Disease
#     │   └── sickle cell disease [noAnnotations=167]
#     ├── Aplastic Anemia
#     │   └── aplastic anemia [noAnnotations=87]
#     └── Myeloproliferative Disease
#         ├── essential thrombocytosis [noAnnotations=52]
#         ├── myelofibrosis [noAnnotations=42]
#         └── polycythemia vera [noAnnotations=27]
#  Renal  (R)
# ├── Renal Failure
# │   ├── renal failure - hemodialysis [noAnnotations=4371]
# │   ├── renal failure- not currently dialyzed [noAnnotations=2539]
# │   └── renal failure - peritoneal dialysis [noAnnotations=369]
# ├── Renal Insufficiency
# │   ├── renal insufficiency - creatinine 1-2 [noAnnotations=3722]
# │   ├── renal insufficiency - baseline creatinine unknown [noAnnotations=2749]
# │   ├── renal insufficiency - creatinine 2-3 [noAnnotations=1372]
# │   ├── renal insufficiency - creatinine 3-4 [noAnnotations=371]
# │   ├── renal insufficiency - creatinine > 5 [noAnnotations=174]
# │   └── renal insufficiency - creatinine 4-5 [noAnnotations=147]
# ├── Chronic Stone Disease
# │   └── chronic kidney stones [noAnnotations=1019]
# ├── s
# │   └── p Renal Transplant
# │       └── s
# │           └── p renal transplant [noAnnotations=598]
# ├── Neurogenic Bladder
# │   └── neurogenic bladder [noAnnotations=270]
# └── RTA
#     └── renal tubular acidosis [noAnnotations=21]
#  Gastrointestinal (R)
# ├── Cirrhosis
# │   ├── clinical diagnosis [noAnnotations=2608]
# │   ├── UGI bleeding [noAnnotations=1084]
# │   ├── varices [noAnnotations=1067]
# │   ├── ascites [noAnnotations=982]
# │   ├── encephalopathy [noAnnotations=832]
# │   ├── jaundice [noAnnotations=347]
# │   ├── biopsy proven [noAnnotations=197]
# │   └── coma [noAnnotations=31]
# ├── Peptic Ulcer Disease
# │   ├── peptic ulcer disease [noAnnotations=2145]
# │   └── peptic ulcer disease with h
# │       └── o GI bleeding [noAnnotations=967]
# ├── s
# │   └── p Liver Transplant
# │       └── s
# │           └── p liver transplant [noAnnotations=255]
# └── Hypersplenism
#     └── splenomegaly [noAnnotations=106]
#  Rheumatic
# ├── Rheumatoid Arthritis
# │   └── rheumatoid arthritis [noAnnotations=1973]
# ├── SLE
# │   └── SLE [noAnnotations=525]
# ├── Vasculitis
# │   └── vasculitis [noAnnotations=110]
# ├── Scleroderma
# │   └── scleroderma [noAnnotations=33]
# └── Dermato
#     └── Polymyositis
#         └── dermatomyositis [noAnnotations=25]
#  Infectious Disease (R)
# ├── HIV (only)
# │   └── HIV positive [noAnnotations=676]
# ├── Immunosuppression within past 6 months
# │   ├── other immunosuppressive medications [noAnnotations=442]
# │   ├── >= 20 mg prednisone per day or equivalent [noAnnotations=429]
# │   └── both prednisone and other immunosuppressive medications [noAnnotations=182]
# └── AIDS
#     └── AIDS [noAnnotations=202]

# %% [markdown]
# ## graph structure to encode past history

# %%
df1= pd.read_csv(porcesseddir2 + 'selected_pastHistory.csv')
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)

df=df1.copy()

# %%
import networkx as nx
from node2vec import Node2Vec  

# Create the graph
G = nx.DiGraph()

# Adding edges based on 'first', 'second', and 'third' relationships
for _, row in df.iterrows():
    if pd.notna(row['first']) and pd.notna(row['second']):
        G.add_edge(row['first'], row['second'])
    if pd.notna(row['second']) and pd.notna(row['third']):
        G.add_edge(row['second'], row['third'])

# Generate embeddings using node2vec
node2vec = Node2Vec(G, dimensions=16, walk_length=10, num_walks=100,workers=4)
model = node2vec.fit(window=5,min_count=1, batch_words=4)

# Obtain node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes()}

# Map embeddings back to the dataset
def get_embedding(row):
    first_embed = node_embeddings.get(row['first'], [0]*16)
    second_embed = node_embeddings.get(row['second'], [0]*16)
    third_embed = node_embeddings.get(row['third'], [0]*16)
    # Combine embeddings, here by concatenation
    return first_embed + second_embed + third_embed

df['past_history_embedding'] = df.apply(get_embedding, axis=1)
# Out:
# Computing transition probabilities: 100%|██████████| 209/209 [00:00<00:00, 46076.72it/s]
# Generating walks (CPU: 1): 100%|██████████| 25/25 [00:00<00:00, 317.32it/s]
# Generating walks (CPU: 2): 100%|██████████| 25/25 [00:00<00:00, 321.77it/s]
# Generating walks (CPU: 3): 100%|██████████| 25/25 [00:00<00:00, 325.22it/s]
# Generating walks (CPU: 4): 100%|██████████| 25/25 [00:00<00:00, 321.56it/s]

# %%
node_embeddings
# Out:
# {' Pulmonary': array([ 0.03676878, -0.01850841,  0.01976099,  0.03122324,  0.05292767,
#          0.03513385,  0.05942842, -0.06029176, -0.04976672, -0.04223847,
#         -0.04667318, -0.04977261, -0.04867606, -0.01839142,  0.008726  ,
#         -0.01796743], dtype=float32),
#  'COPD': array([ 0.29238734, -0.4019603 , -0.12774564,  0.17460066,  0.25233665,
#         -0.1640202 ,  0.73615444,  0.12936051, -0.07475804, -0.00099248,
#         -0.08477809,  0.08813667, -0.00833007, -0.37394023, -0.42503622,
#          0.1399634 ], dtype=float32),
#  'COPD  - no limitations': array([ 1.0659351e-01, -1.8591116e-01, -1.1954455e-04,  8.3978586e-02,
#          6.8768203e-02, -5.2483819e-02,  3.3102617e-01, -2.2693705e-02,
#          6.7277737e-02,  7.3387071e-02, -8.5583389e-02,  1.4631544e-02,
#          4.3209422e-02, -1.8520169e-01, -2.5717363e-01,  3.5334253e-04],
#        dtype=float32),
#  ' Cardiovascular (R)': array([ 9.0889633e-05,  2.1456778e-03, -6.1658926e-02,  6.2104687e-02,
#         -1.2508377e-02, -3.0545756e-02,  1.7182752e-02,  6.4373240e-03,
#         -3.7072435e-02,  3.6204025e-02, -1.5646659e-02, -3.8614877e-02,
#          4.5223184e-02,  4.0396720e-02,  5.5126764e-02,  7.2712153e-03],
#        dtype=float32),
#  'Valve disease': array([ 0.30163318, -0.32356986, -0.0428254 ,  0.12677649,  0.15250899,
#         -0.1456757 ,  0.9012062 ,  0.21311206, -0.06181451, -0.03983558,
#          0.04830642,  0.12261057,  0.00656009, -0.3586176 , -0.52091026,
#          0.14709678], dtype=float32),
#  'AS': array([ 0.02506847, -0.05720334, -0.04376474,  0.02223449,  0.02517592,
#         -0.02800941,  0.11454413,  0.09386557, -0.03237803, -0.02625727,
#          0.02211202, -0.01208588, -0.05760003, -0.0932803 , -0.10677234,
#         -0.01782135], dtype=float32),
#  'Congestive Heart Failure': array([ 2.8948161e-01, -3.2420665e-01, -1.6293271e-02,  9.2390880e-02,
#          1.3033299e-01, -2.2315574e-01,  7.4932754e-01,  2.1365695e-01,
#         -4.8550204e-04, -7.9600168e-03, -2.0337049e-02, -7.3951758e-02,
#         -4.6367221e-02, -3.4259000e-01, -4.3999392e-01,  1.8025182e-01],
#        dtype=float32),
#  'CHF - class II': array([ 0.06463492, -0.09834465, -0.02938366,  0.01176626,  0.08490346,
#         -0.06271584,  0.16686139,  0.13280782,  0.05698614,  0.04895386,
#          0.01628022, -0.04508842,  0.04098806, -0.08807762, -0.08574418,
#          0.07058028], dtype=float32),
#  'Hypertension Requiring Treatment': array([ 0.20578898, -0.15010586,  0.00075407,  0.12916157, -0.02491739,
#         -0.09088887,  0.4615863 ,  0.18676639, -0.00061267,  0.11403   ,
#         -0.02024285,  0.1713971 ,  0.0347322 , -0.1944355 , -0.3198867 ,
#          0.24871801], dtype=float32),
#  'hypertension requiring treatment': array([ 0.25832084, -0.34608153,  0.10381819,  0.17592683,  0.01667891,
#         -0.10195595,  0.6896941 ,  0.14767165, -0.00467763,  0.01337735,
#         -0.03116159, -0.05254427, -0.14533246, -0.29736406, -0.35147545,
#          0.28300345], dtype=float32),
#  'AICD': array([ 1.8408207 , -1.7470814 , -0.42185587, -0.16088948,  1.341777  ,
#         -1.2307403 ,  1.5922407 , -0.40519705, -1.3920375 ,  0.8160403 ,
#         -1.2068675 , -0.7525978 , -0.21351933, -0.79301316, -2.031307  ,
#          1.4937035 ], dtype=float32),
#  ' Renal  (R)': array([ 2.0459294e-05,  4.2823553e-03, -5.3755857e-02, -5.9967071e-02,
#         -1.4466725e-02,  5.5801250e-02, -2.2797421e-02, -4.3613710e-02,
#          3.0496143e-02,  6.6819862e-03,  1.1568882e-02,  2.2830978e-02,
#          2.2004209e-02,  3.5788260e-02,  7.7143759e-03,  5.2778944e-03],
#        dtype=float32),
#  'Renal Failure': array([ 0.3046297 , -0.3861945 , -0.08008323,  0.0557216 ,  0.24085745,
#         -0.11219393,  0.66912884,  0.14006276,  0.00632352, -0.0832411 ,
#          0.01434666,  0.09904484,  0.01345995, -0.2201175 , -0.5049299 ,
#          0.12028342], dtype=float32),
#  'renal failure- not currently dialyzed': array([ 0.07030099, -0.18056054,  0.00441144,  0.00987155,  0.08404025,
#         -0.08007619,  0.24287201,  0.08910928,  0.04391386, -0.03677365,
#          0.02277968, -0.02804483, -0.08828051, -0.11919829, -0.23624139,
#          0.05357806], dtype=float32),
#  ' Rheumatic': array([ 0.0097306 , -0.01233695, -0.04121844,  0.04046189, -0.05668502,
#         -0.01185378,  0.04807749, -0.01616788,  0.0100387 , -0.04591322,
#          0.03111301,  0.04608167, -0.05817837, -0.02048659,  0.04932962,
#          0.01833639], dtype=float32),
#  'Rheumatoid Arthritis': array([ 3.9200418e-02, -1.6585298e-01, -1.8484294e-02,  1.0222982e-01,
#          2.2330375e-01, -2.5339550e-04,  4.8472109e-01,  1.3131239e-01,
#         -6.4494416e-02,  3.2876305e-02,  3.6168508e-02,  1.5618834e-01,
#         -5.1814809e-02, -1.5632674e-01, -3.8185471e-01,  8.6505704e-02],
#        dtype=float32),
#  'rheumatoid arthritis': array([ 0.29085666, -0.3221914 ,  0.04265016,  0.1087937 ,  0.06180901,
#         -0.01955652,  0.67333263,  0.03405491, -0.07081199, -0.05500221,
#         -0.11709395,  0.02717062, -0.05807123, -0.20008792, -0.367874  ,
#          0.11864592], dtype=float32),
#  'Arrhythmias': array([ 0.20772967, -0.33678833, -0.04011369,  0.03232451,  0.21564426,
#         -0.10675526,  0.7397154 ,  0.2340501 ,  0.01867005,  0.0440487 ,
#          0.01093942,  0.10843697, -0.0342261 , -0.34332356, -0.49067274,
#          0.23102906], dtype=float32),
#  'atrial fibrillation - chronic': array([ 0.10536227, -0.04973206, -0.04647214, -0.02826559,  0.06243484,
#         -0.05351168,  0.09976714,  0.04876062, -0.01554585, -0.03338553,
#         -0.01618921,  0.01785872,  0.006962  , -0.00872802, -0.1100654 ,
#          0.0513178 ], dtype=float32),
#  'CHF - severity unknown': array([ 0.11046452, -0.01694565, -0.02079196,  0.0509624 ,  0.08782222,
#         -0.04249143,  0.19575186,  0.07911321,  0.01389104, -0.01776181,
#         -0.03956983, -0.01607511,  0.04546415, -0.09466931, -0.10901304,
#          0.09765042], dtype=float32),
#  ' Endocrine (R)': array([ 0.00151882, -0.02050372, -0.05446609, -0.062488  ,  0.00195486,
#         -0.03591757, -0.00693537, -0.02628808, -0.05399266,  0.0066381 ,
#          0.03694431, -0.01381856, -0.0448176 ,  0.01970898, -0.00240429,
#         -0.03450714], dtype=float32),
#  'Non-Insulin Dependent Diabetes': array([ 0.12504712, -0.25334117,  0.09786048,  0.20028815,  0.0074913 ,
#         -0.08835407,  0.6142634 ,  0.10072364,  0.04644001, -0.03571653,
#         -0.01746299, -0.09293883, -0.06969255, -0.19460209, -0.3700999 ,
#          0.07267863], dtype=float32),
#  'medication dependent': array([ 0.20861414, -0.23374605,  0.00684784,  0.07069999,  0.18446183,
#         -0.09493496,  0.37746835, -0.02686104, -0.11202809, -0.0769657 ,
#         -0.01682948, -0.02105139,  0.00580184, -0.24321407, -0.2360284 ,
#          0.10148367], dtype=float32),
#  'Angina': array([ 0.14687513, -0.41635823, -0.06089713,  0.13831839,  0.15964428,
#         -0.05446475,  0.76991755,  0.18142764,  0.01791193,  0.05615034,
#         -0.03272499,  0.11285601, -0.11402684, -0.2728976 , -0.45212904,
#          0.16603826], dtype=float32),
#  'angina - severity unknown': array([-0.01465147, -0.0922363 ,  0.00681057, -0.00577978, -0.03891245,
#         -0.0256874 ,  0.16777098,  0.07017162, -0.06659893,  0.02249961,
#         -0.03848151, -0.05829412, -0.00449969, -0.04201557, -0.11433052,
#         -0.01284555], dtype=float32),
#  'Renal Insufficiency': array([ 0.32145336, -0.40688768, -0.06619842,  0.11545787,  0.1836513 ,
#         -0.14903599,  0.71158355,  0.14465885, -0.07648116,  0.06226227,
#          0.03921983, -0.01464979, -0.02152113, -0.26141796, -0.5022379 ,
#          0.1164433 ], dtype=float32),
#  'renal insufficiency - creatinine 1-2': array([ 0.0798505 , -0.039761  , -0.05420378,  0.01616931,  0.07361192,
#         -0.07140042,  0.1937119 ,  0.08898742, -0.01103401, -0.00184777,
#         -0.00842949, -0.03942252, -0.06237203, -0.07561231, -0.11299055,
#          0.06463373], dtype=float32),
#  'Insulin Dependent Diabetes': array([ 0.10859568, -0.23633274,  0.03760858,  0.13521919,  0.15196459,
#         -0.18238173,  0.42944717,  0.02281689, -0.09654602, -0.08006465,
#          0.00098397, -0.06112492, -0.08484802, -0.2040022 , -0.19086242,
#          0.08320054], dtype=float32),
#  'insulin dependent diabetes': array([ 0.17042966, -0.2931586 , -0.09824776,  0.02711756,  0.17576016,
#         -0.16511762,  0.67430866,  0.14266299, -0.10734505,  0.10111091,
#          0.09344479,  0.08915933, -0.12012924, -0.14802434, -0.30159688,
#          0.20399113], dtype=float32),
#  'Myocardial Infarction': array([ 0.2972294 , -0.32004592, -0.12166674,  0.10412342,  0.11512583,
#         -0.06878145,  0.7358431 ,  0.10255799,  0.01632165,  0.03344471,
#         -0.03937769,  0.02945507,  0.02670686, -0.19358444, -0.51097697,
#          0.21499513], dtype=float32),
#  'MI - date unknown': array([ 0.03202722, -0.10154435,  0.03196201,  0.04102001,  0.01357385,
#         -0.00232695,  0.09050557,  0.01784029,  0.07191031, -0.01982689,
#         -0.04118289, -0.04136247, -0.03257957, -0.06759617, -0.06457578,
#          0.09255971], dtype=float32),
#  'Coronary Artery Bypass': array([ 0.19008836, -0.40377963, -0.11509211,  0.03364458,  0.25619686,
#         -0.0837136 ,  0.6999959 ,  0.04395913,  0.0099907 ,  0.06190444,
#         -0.04741017, -0.06669927, -0.05097667, -0.27609506, -0.5120816 ,
#          0.20669453], dtype=float32),
#  'CABG - date unknown': array([ 0.04462129, -0.12046311, -0.09075178, -0.00417824,  0.08512782,
#          0.03012772,  0.3191309 , -0.00980779,  0.0289899 ,  0.01919272,
#         -0.02357085, -0.03415956, -0.0121771 , -0.17557138, -0.11135332,
#          0.01572395], dtype=float32),
#  ' Gastrointestinal (R)': array([ 0.05653282,  0.01738886, -0.02939285,  0.04088867,  0.0325832 ,
#          0.01794104, -0.01961146,  0.02085523,  0.03977686,  0.0442565 ,
#          0.00588229, -0.05332354,  0.00161101,  0.00231513,  0.02464364,
#         -0.059181  ], dtype=float32),
#  'Peptic Ulcer Disease': array([ 0.29843524, -0.31960037,  0.05670499,  0.16609696,  0.1706161 ,
#         -0.08754028,  0.6400485 ,  0.18461141,  0.07394329,  0.12408904,
#          0.0516711 ,  0.10135989,  0.07640316, -0.24127337, -0.39348778,
#          0.17538953], dtype=float32),
#  'peptic ulcer disease with h': array([ 0.10109847, -0.23614947,  0.07280624,  0.12302212,  0.05690736,
#         -0.04268803,  0.39673287,  0.12974088, -0.07781004,  0.0243933 ,
#          0.01728645,  0.04324245, -0.02188481, -0.1163144 , -0.19892995,
#          0.01511474], dtype=float32),
#  'Peripheral Vascular Disease': array([ 0.27174875, -0.27308017, -0.06760017, -0.09920128,  0.02748521,
#          0.05577724,  0.4520545 ,  0.15342835, -0.05813055, -0.02782855,
#         -0.13165984,  0.14210287,  0.05691086, -0.17035542, -0.23035476,
#          0.09759032], dtype=float32),
#  'peripheral vascular disease': array([ 0.21299964, -0.22042646,  0.08762749, -0.01952888,  0.1787685 ,
#         -0.1759954 ,  0.6370923 ,  0.11552145,  0.07509711,  0.12629631,
#          0.06811962,  0.14474681,  0.07225929, -0.3435701 , -0.5262403 ,
#          0.1725129 ], dtype=float32),
#  'COPD  - moderate': array([ 0.08189234, -0.17139749,  0.05079855,  0.0579651 ,  0.05840668,
#          0.0068515 ,  0.27915654,  0.03714476,  0.06857923,  0.05707354,
#         -0.0040908 , -0.0583854 , -0.01012509, -0.13693736, -0.14624551,
#          0.05298173], dtype=float32),
#  ' Infectious Disease (R)': array([-0.00693776,  0.05903737,  0.05022836, -0.0329631 , -0.05085942,
#         -0.01410872, -0.05791739, -0.03167337, -0.03717379,  0.01890701,
#         -0.04730652,  0.00781616,  0.01429313,  0.03320822, -0.01262747,
#         -0.06107288], dtype=float32),
#  'Immunosuppression within past 6 months': array([ 0.23221497, -0.2203309 ,  0.0044489 , -0.01603354,  0.25911573,
#         -0.220933  ,  0.6988074 ,  0.13626172, -0.03051301, -0.02793838,
#          0.05815796, -0.03034006,  0.03265075, -0.3167048 , -0.32226253,
#          0.14535475], dtype=float32),
#  '>= 20 mg prednisone per day or equivalent': array([ 0.08326975, -0.06438991,  0.04145135, -0.04408865,  0.00908354,
#         -0.12384082,  0.2547036 ,  0.12422547,  0.05508063,  0.01714077,
#          0.03717744,  0.00519948,  0.04495716, -0.15528487, -0.21594888,
#          0.02210028], dtype=float32),
#  'Venous Thrombosis': array([ 0.29303437, -0.31346568, -0.10391626,  0.10030194,  0.08468226,
#         -0.04254635,  0.65648973,  0.16727316,  0.0432165 ,  0.0011035 ,
#         -0.0375717 ,  0.04086747,  0.04245993, -0.3211344 , -0.4186868 ,
#          0.13040169], dtype=float32),
#  'DVT - within 6 months': array([ 0.05646173, -0.038882  , -0.05517514,  0.08352232,  0.06443395,
#         -0.00528863,  0.17352515,  0.07251684, -0.01525836, -0.01235157,
#         -0.00205291, -0.06184378,  0.05030715, -0.08707703, -0.03424384,
#          0.00805013], dtype=float32),
#  'Procedural Coronary Intervention': array([ 0.27230385, -0.35894907, -0.08747204,  0.13663231,  0.24276981,
#         -0.07252701,  0.71112704,  0.15415435,  0.00292233,  0.04787583,
#         -0.05887368,  0.05173914, -0.00590943, -0.3047384 , -0.4229435 ,
#          0.19055988], dtype=float32),
#  'procedural coronary intervention - date unknown': array([ 0.03423808, -0.11082767,  0.0335083 , -0.0223741 ,  0.06561705,
#          0.04132886,  0.1801428 ,  0.05705668,  0.03294243, -0.02694125,
#          0.0174336 ,  0.02579285,  0.02540058, -0.01852208, -0.08901162,
#          0.0764815 ], dtype=float32),
#  'Asthma': array([ 0.19444126, -0.1169909 ,  0.0007186 ,  0.11918038,  0.18175592,
#         -0.18731453,  0.41066465,  0.12661496, -0.00880275,  0.02802438,
#          0.00221128,  0.1513483 , -0.0841534 , -0.19908772, -0.22237192,
#          0.12973583], dtype=float32),
#  'asthma': array([ 0.23372436, -0.31908727,  0.01248873,  0.14888273,  0.21557203,
#         -0.1925828 ,  0.66766524,  0.1666828 ,  0.06014193, -0.08326885,
#          0.10078766, -0.0052933 ,  0.09086122, -0.3004456 , -0.42772716,
#          0.21764764], dtype=float32),
#  'Respiratory Failure': array([ 0.28722432, -0.36538017,  0.02251071, -0.00591902,  0.23084633,
#         -0.05755196,  0.6391087 ,  0.10099093, -0.00580517,  0.00784189,
#         -0.07875872,  0.08231364, -0.01633058, -0.22660452, -0.46289805,
#          0.21707255], dtype=float32),
#  'multiple': array([ 0.24506272, -0.22363698, -0.07548381,  0.11922157,  0.1357567 ,
#         -0.10405164,  0.75449926,  0.11467227,  0.02526859, -0.06539062,
#         -0.03072836,  0.10419612, -0.04904358, -0.25319773, -0.4479264 ,
#          0.10626823], dtype=float32),
#  'Home Oxygen': array([ 0.12836416, -0.20327272, -0.15527391,  0.13368951,  0.1812806 ,
#          0.05596719,  0.43046588,  0.02552666, -0.01558593, -0.05417661,
#         -0.08647809, -0.05037381, -0.05807707, -0.18382636, -0.45404807,
#          0.03108496], dtype=float32),
#  'home oxygen': array([ 0.08274088, -0.39684373, -0.03331644,  0.11973395,  0.07300704,
#         -0.04040391,  0.6308244 ,  0.16317974,  0.10630341, -0.0541797 ,
#         -0.03694409,  0.12265934, -0.05298951, -0.36811712, -0.38801992,
#          0.04919314], dtype=float32),
#  'COPD  - severe': array([ 1.3583112e-01, -1.6908459e-01,  4.8815805e-02, -2.5861431e-02,
#          9.4817489e-02,  4.9712170e-02,  2.3945835e-01, -3.6640886e-02,
#          2.5232140e-02, -1.8553954e-04, -1.5323652e-02, -2.5624370e-02,
#         -6.6196047e-02, -1.1909150e-01, -2.3698004e-01, -1.5447000e-02],
#        dtype=float32),
#  'respiratory failure - within 6 months': array([ 0.03219374, -0.02880019,  0.05271082,  0.0185898 , -0.011362  ,
#         -0.07125532,  0.2028355 ,  0.00344975,  0.01870269, -0.05299916,
#          0.04839627,  0.06504565, -0.0518304 , -0.14366738, -0.10768542,
#         -0.00616969], dtype=float32),
#  'CHF': array([ 0.09987823, -0.0524659 , -0.0016503 , -0.00849081, -0.0085353 ,
#          0.00926039,  0.12370715, -0.03180009,  0.00108943,  0.00860316,
#         -0.01653483,  0.06100745, -0.02325901, -0.09218768, -0.02982708,
#         -0.00703846], dtype=float32),
#  'DVT - within 2 years': array([ 0.09869631, -0.06631026,  0.04030988,  0.05855601,  0.05900632,
#          0.01985688,  0.12232319,  0.02078147,  0.00662939,  0.01242784,
#          0.02620848,  0.04305091,  0.0216357 , -0.10391934, -0.11436076,
#         -0.0192831 ], dtype=float32),
#  'Hypothyroidism': array([ 0.11160445, -0.3378192 ,  0.02723304, -0.0647976 ,  0.04610778,
#         -0.12227371,  0.59002185,  0.02038516,  0.05027379,  0.00589251,
#          0.01666455,  0.10568907, -0.01612465, -0.08069758, -0.32404774,
#          0.02079421], dtype=float32),
#  'hypothyroidism': array([ 1.53034404e-01, -4.01739955e-01,  5.98423034e-02,  4.52014990e-02,
#          1.13476835e-01,  1.66044527e-04,  6.44739151e-01,  1.11966699e-01,
#         -6.30492643e-02,  7.26029351e-02, -4.31538410e-02,  7.41193593e-02,
#         -1.39746353e-01, -1.42947301e-01, -3.56869310e-01,  1.53251335e-01],
#        dtype=float32),
#  'Cirrhosis': array([ 0.26288724, -0.38177112, -0.05588129,  0.04725386,  0.20790675,
#         -0.18111135,  0.8275332 ,  0.15505862,  0.09157518,  0.03063724,
#         -0.04737717,  0.09049406, -0.06660832, -0.39801046, -0.43075246,
#          0.24945696], dtype=float32),
#  'encephalopathy': array([ 0.06708349,  0.01995085, -0.01668539,  0.0237205 , -0.02776444,
#         -0.04506104,  0.1498776 ,  0.00690997,  0.06240177, -0.00256992,
#         -0.00607561,  0.03567485, -0.03583257, -0.04315843, -0.03756573,
#          0.03933423], dtype=float32),
#  'clinical diagnosis': array([ 0.08784481, -0.0819999 , -0.06240523, -0.01957672,  0.00904897,
#         -0.04253904,  0.11418229,  0.01453804, -0.01694338, -0.03602727,
#          0.04658886, -0.02647432, -0.05414991, -0.00088244, -0.0527848 ,
#          0.08116439], dtype=float32),
#  'varices': array([ 0.02571838, -0.09622198, -0.06862904,  0.009877  ,  0.08787345,
#         -0.01299305,  0.1336382 ,  0.02835935,  0.05724501, -0.04597543,
#         -0.00382828, -0.04267066,  0.01224082,  0.00303051, -0.03367051,
#          0.07307892], dtype=float32),
#  'ascites': array([ 0.07141309, -0.00082064, -0.04284174,  0.0585263 ,  0.0628794 ,
#          0.03811236,  0.11059258, -0.01252949, -0.03342925,  0.00103164,
#         -0.02118112,  0.0509727 ,  0.00498724, -0.00451901, -0.03279443,
#         -0.02848755], dtype=float32),
#  ' Neurologic': array([-0.01371766,  0.05677976,  0.03363952, -0.05303161, -0.01034778,
#         -0.05523888, -0.01026174,  0.03534761, -0.04636436,  0.03443793,
#          0.03806287, -0.02356549, -0.06034884, -0.01574261, -0.01595639,
#          0.02349085], dtype=float32),
#  'TIA(s)': array([ 0.18536578, -0.30069116, -0.06682347,  0.07482306,  0.11715253,
#         -0.19505604,  0.7532748 ,  0.14974616,  0.07478885, -0.07421192,
#          0.03116935, -0.0287131 ,  0.03569381, -0.24083333, -0.47505212,
#          0.20907356], dtype=float32),
#  'TIA(s) - date unknown': array([-0.00074491, -0.08427214, -0.02312715, -0.01832418,  0.04946639,
#          0.04247621,  0.1683835 ,  0.07984719,  0.0017482 , -0.00751814,
#         -0.02133217, -0.04676949,  0.00856683, -0.03656965, -0.15286508,
#          0.00047753], dtype=float32),
#  'non-medication dependent': array([ 0.16640821, -0.10367268, -0.00693741,  0.06025536,  0.00880469,
#         -0.04587668,  0.28836784, -0.01952578, -0.09964397, -0.04655768,
#          0.03532828,  0.04221345, -0.07782149, -0.18154503, -0.22823267,
#          0.04275274], dtype=float32),
#  'renal failure - hemodialysis': array([ 0.09418669, -0.14070106, -0.01116964, -0.00688411,  0.06454257,
#         -0.09156797,  0.30758747,  0.12066367, -0.03111755,  0.02215795,
#         -0.04049207,  0.01410149, -0.07448007, -0.1793712 , -0.21576993,
#         -0.00904089], dtype=float32),
#  ' Hematology': array([ 0.06180031, -0.01775106,  0.01537091, -0.01752094,  0.05403403,
#         -0.00177052,  0.03522693,  0.0575806 ,  0.02568904, -0.04450244,
#         -0.01203644,  0.00611266,  0.01271298,  0.01846384,  0.05905849,
#          0.02750688], dtype=float32),
#  'Oncology (R)': array([ 0.19029279, -0.41500795,  0.00526731,  0.14758465,  0.08581655,
#         -0.23327094,  0.8280856 ,  0.19255975, -0.02149402,  0.00210569,
#         -0.01723788,  0.03571572, -0.02531647, -0.20634873, -0.51582676,
#          0.17936419], dtype=float32),
#  'Cancer': array([-0.01257782, -0.03385342,  0.01413892, -0.03388717, -0.0437394 ,
#         -0.06671903,  0.11424993,  0.04276928, -0.03012623, -0.05242265,
#          0.007456  ,  0.02102045, -0.01115674, -0.01425303, -0.06418016,
#          0.04543135], dtype=float32),
#  'DVT - date unknown': array([ 0.10064439, -0.01367608,  0.00193522,  0.07853671,  0.01853279,
#          0.00569789,  0.21018402, -0.02120339, -0.02013358,  0.00551556,
#          0.00729096, -0.00361826, -0.00947917, -0.07721474, -0.11029664,
#          0.05898282], dtype=float32),
#  'Strokes': array([ 0.2848076 , -0.29294115,  0.05895043,  0.06346042,  0.15517752,
#         -0.15912527,  0.64250004,  0.17045343, -0.04261081, -0.05951647,
#          0.03530442,  0.09483662, -0.08168528, -0.32111424, -0.4455346 ,
#          0.20241612], dtype=float32),
#  'stroke - date unknown': array([ 0.10583201, -0.04855037,  0.04175841,  0.03495183,  0.02993086,
#          0.00386367,  0.17363518,  0.05129617,  0.06135844, -0.04360614,
#          0.02442124, -0.0305222 ,  0.03403521, -0.01271747, -0.11478178,
#          0.07516661], dtype=float32),
#  'procedural coronary intervention - within 5 years': array([ 0.02596573, -0.01636995, -0.0508526 , -0.00115738, -0.00682511,
#         -0.02575775,  0.13449417,  0.09503025, -0.00051186, -0.06309173,
#         -0.03915332, -0.02732953,  0.00570195,  0.02204576, -0.12725689,
#          0.09045141], dtype=float32),
#  'Neurogenic Bladder': array([ 0.05360543, -0.14973299, -0.02920334,  0.22265923,  0.16106811,
#         -0.17343393,  0.44735086,  0.10014077, -0.00947178, -0.09447058,
#          0.0250527 , -0.12474889,  0.09781752, -0.2103568 , -0.22156905,
#          0.05632504], dtype=float32),
#  'neurogenic bladder': array([ 0.10528959, -0.23907627, -0.12358604, -0.02016301,  0.19915028,
#         -0.02701629,  0.71235186,  0.05403323,  0.09260506,  0.08113352,
#         -0.07400058, -0.06713071, -0.00289145, -0.16304103, -0.396404  ,
#          0.05098142], dtype=float32),
#  'angina': array([ 0.05393246, -0.06852339, -0.02725635,  0.03019544, -0.00492064,
#         -0.03692757,  0.17558573,  0.0807948 , -0.06822712,  0.05465397,
#          0.01875226, -0.02178041,  0.04678522, -0.11932292, -0.04257566,
#          0.06966077], dtype=float32),
#  'Pacemaker': array([ 0.20042044, -0.37184513, -0.07871916,  0.01638046,  0.20318834,
#         -0.17892304,  0.70914876,  0.11756358,  0.05363745,  0.03257949,
#          0.00563037, -0.02703565, -0.01020531, -0.27444255, -0.33117473,
#          0.1917293 ], dtype=float32),
#  'unknown pacer': array([ 0.0387767 , -0.12455172, -0.03282154,  0.04790179,  0.02015013,
#         -0.05652209,  0.21978211,  0.0706269 ,  0.04327683, -0.03795715,
#         -0.02869568,  0.04074581,  0.03719161, -0.11076524, -0.09801748,
#          0.12509997], dtype=float32),
#  's': array([ 0.31545058, -0.4115717 , -0.07656202,  0.02753918,  0.12234282,
#         -0.3059128 ,  0.8656076 ,  0.20684385, -0.11141241,  0.09942473,
#         -0.04174995, -0.01607304, -0.13756143, -0.41431606, -0.4640245 ,
#          0.16278954], dtype=float32),
#  'Cancer Therapy': array([ 0.08298934, -0.03115241, -0.06071298,  0.06767801,  0.08380949,
#          0.02538568,  0.14460301, -0.04798614,  0.00019543, -0.05067425,
#         -0.03374106,  0.00608661, -0.00359137, -0.03749183, -0.04413037,
#          0.04055931], dtype=float32),
#  'Recent Steroid Use (for > 10 days)': array([ 0.0760151 , -0.1425784 , -0.00962494,  0.10465521,  0.08549339,
#         -0.1752251 ,  0.3830572 ,  0.07604321, -0.09055382, -0.02840487,
#          0.09092472, -0.10030922, -0.10205546, -0.2956032 , -0.40407816,
#         -0.00971144], dtype=float32),
#  'recent steroid use for > 10 days': array([ 0.06096032, -0.19522539, -0.08133943,  0.05207847,  0.22217192,
#         -0.12155546,  0.72723436,  0.09033661,  0.05613175,  0.11301258,
#         -0.0875672 , -0.03115506, -0.1614082 , -0.27207026, -0.42014614,
#         -0.01167809], dtype=float32),
#  'MI - remote': array([ 0.0183498 , -0.12109419,  0.00050345,  0.03727498,  0.02130222,
#         -0.07796638,  0.21650429,  0.04175871,  0.01134863, -0.01683472,
#          0.05194209, -0.04829901, -0.06966748, -0.09250771, -0.05267023,
#          0.01799406], dtype=float32),
#  'Seizures': array([ 0.29791942, -0.28846872,  0.00721241,  0.00886009,  0.21955812,
#         -0.06068691,  0.7472521 ,  0.06011211,  0.02890955,  0.00446671,
#         -0.05162986, -0.01192926,  0.0061251 , -0.33790794, -0.48192325,
#          0.22143175], dtype=float32),
#  'generalized seizures': array([ 0.04618795, -0.11566228, -0.05087448,  0.09300578, -0.01073453,
#         -0.10728941,  0.1880157 ,  0.03755523, -0.07304182,  0.01768738,
#         -0.05002314, -0.01377402, -0.07716472, -0.07604076, -0.11049879,
#          0.04650401], dtype=float32),
#  'SVT- other': array([ 0.03015747, -0.00784576, -0.06252778,  0.05872149,  0.02539534,
#         -0.00423856,  0.1976845 ,  0.0636861 , -0.01452205,  0.02029349,
#          0.02877621,  0.05637101, -0.0087029 , -0.08851652, -0.07892564,
#         -0.00547135], dtype=float32),
#  'MR': array([ 0.02051794, -0.03118926, -0.06245154,  0.06122449, -0.03148734,
#          0.029717  ,  0.11493865, -0.02387042, -0.03023266, -0.04992399,
#         -0.03093092,  0.055103  ,  0.05131299, -0.02298198, -0.05393478,
#          0.07753848], dtype=float32),
#  'Exercise Tolerance': array([ 0.26512304, -0.29709628, -0.05726168,  0.05906817,  0.12085895,
#         -0.14721802,  0.710447  ,  0.10397632,  0.06788038, -0.02600017,
#          0.02720437,  0.07301135, -0.06397565, -0.23641749, -0.43336752,
#          0.1678787 ], dtype=float32),
#  'limited - household activities (1-4 mets)': array([ 0.01631298, -0.07091338,  0.0624789 ,  0.01484341, -0.02546125,
#         -0.03313563,  0.19613926,  0.068029  ,  0.0113882 , -0.02909122,
#         -0.00768319, -0.01097849,  0.03416953, -0.11616017, -0.1436277 ,
#          0.0404444 ], dtype=float32),
#  'MS': array([-0.0281582 ,  0.00030107, -0.01709819, -0.01111141,  0.05202499,
#         -0.06275575,  0.12529403,  0.02420916, -0.05340966, -0.00196776,
#          0.03958751,  0.05890543,  0.0077175 , -0.0024939 , -0.0915908 ,
#          0.01398894], dtype=float32),
#  'CHF - class III': array([ 0.03868176, -0.12526785,  0.06362396,  0.07638835, -0.01582055,
#         -0.09020775,  0.20848435,  0.07260833, -0.0972705 ,  0.04166426,
#         -0.06370279, -0.0706751 ,  0.02487723, -0.08723598, -0.10365226,
#          0.11760397], dtype=float32),
#  'renal insufficiency - creatinine > 5': array([ 0.09718397, -0.13550125, -0.02622672,  0.05067607,  0.03050724,
#         -0.07413214,  0.241457  ,  0.06344943, -0.0120625 , -0.00666032,
#          0.02945271, -0.02347721, -0.04392735, -0.13476978, -0.1724675 ,
#         -0.00052144], dtype=float32),
#  'procedural coronary intervention - remote': array([ 0.04882645, -0.04907516,  0.03103906,  0.00716893, -0.0045552 ,
#         -0.02016513,  0.19178478,  0.11544576,  0.00325203,  0.02428996,
#         -0.04429969,  0.0770255 , -0.02752136,  0.01404778, -0.15998454,
#          0.05301634], dtype=float32),
#  'CABG - within 2 years': array([ 0.07771856, -0.0009328 , -0.05803503,  0.0655707 ,  0.05770439,
#         -0.04539279,  0.09687702,  0.06549099, -0.05429253, -0.04363031,
#          0.03170189,  0.0540347 ,  0.04342375, -0.07052286, -0.13546696,
#          0.07867237], dtype=float32),
#  'renal insufficiency - baseline creatinine unknown': array([-0.00835661, -0.05873434, -0.02629008, -0.05110231,  0.0927524 ,
#          0.01995164,  0.15859756,  0.06389072,  0.01927397,  0.05689243,
#          0.04724385, -0.04484513, -0.04425804, -0.07644027, -0.07190961,
#         -0.00213483], dtype=float32),
#  'stroke - within 2 years': array([ 0.07076111, -0.0325153 ,  0.0445533 ,  0.05981537,  0.08537999,
#         -0.06926969,  0.19903754,  0.00301896, -0.07657115,  0.06095424,
#         -0.00112638, -0.01605476, -0.02471336, -0.07557125, -0.06671707,
#          0.07420954], dtype=float32),
#  'TR': array([ 0.04440164, -0.04562176, -0.01124909,  0.08247767,  0.02373182,
#         -0.01125997,  0.10212227,  0.0428853 ,  0.02658902, -0.00653207,
#          0.03090027, -0.00566626,  0.02755181, -0.01330848, -0.04832616,
#         -0.01532118], dtype=float32),
#  'CABG - remote': array([ 0.02333478, -0.06094138,  0.01687352, -0.01645335,  0.06777448,
#         -0.07582392,  0.20011264, -0.00726601, -0.0426623 ,  0.02979395,
#          0.04366435,  0.04105148, -0.06519492, -0.124732  , -0.0641643 ,
#          0.05859907], dtype=float32),
#  'renal insufficiency - creatinine 3-4': array([ 0.05182743, -0.03168178,  0.04022603,  0.08908787, -0.03468559,
#         -0.08342508,  0.1774037 ,  0.05668144, -0.05421844, -0.00039054,
#          0.03092442, -0.02008188, -0.0494907 , -0.00851853, -0.02135902,
#         -0.02529337], dtype=float32),
#  'V paced': array([ 0.0632598 , -0.02357423,  0.02431945, -0.0021236 , -0.01192159,
#         -0.06798055,  0.13100831,  0.11498182,  0.00371354, -0.0599054 ,
#         -0.02080581,  0.05335901, -0.03102712, -0.09078709, -0.09372037,
#          0.02147825], dtype=float32),
#  'HIV (only)': array([ 0.18034752, -0.14400786, -0.00076535, -0.11793587,  0.26727098,
#         -0.00317769,  0.44871277,  0.23134322,  0.07139367,  0.12768613,
#         -0.0237982 ,  0.22328055,  0.00380544, -0.32917342, -0.37717953,
#          0.2502522 ], dtype=float32),
#  'HIV positive': array([ 0.17370133, -0.25945565, -0.02278944,  0.1676637 ,  0.08230305,
#         -0.11533628,  0.73001134,  0.26654878, -0.04168238, -0.15636984,
#          0.07528707,  0.02378982,  0.07132363, -0.2643639 , -0.42795217,
#          0.00882754], dtype=float32),
#  'p Renal Transplant': array([ 0.1485719 , -0.1218934 ,  0.06294458, -0.03356343,  0.10297117,
#         -0.04180784,  0.2650715 ,  0.06720515, -0.07478146, -0.07583214,
#         -0.00137514,  0.07184527,  0.05227329, -0.05710594, -0.17695834,
#          0.14289664], dtype=float32),
#  'both prednisone and other immunosuppressive medications': array([ 0.02129426, -0.12891379,  0.06990778,  0.04583491,  0.02685004,
#         -0.14416505,  0.32365313,  0.04955801,  0.08179646, -0.0558021 ,
#          0.02137108,  0.04226302, -0.01462575, -0.11082744, -0.15968853,
#          0.03182649], dtype=float32),
#  'UGI bleeding': array([ 0.01315097, -0.05561844, -0.01330804,  0.0014737 , -0.01489246,
#          0.03346123,  0.16157484,  0.016518  , -0.02899475,  0.04291604,
#         -0.04285622,  0.01913583, -0.00196772,  0.00084786, -0.03250032,
#          0.0047389 ], dtype=float32),
#  'Pulmonary Embolism': array([ 0.27855647, -0.37019998, -0.01100955,  0.08754643,  0.24800287,
#         -0.10643695,  0.67653716,  0.20079836, -0.03336986, -0.07589262,
#          0.01953563,  0.03311956, -0.07721016, -0.3191836 , -0.53559524,
#          0.16455612], dtype=float32),
#  'pulmonary embolism - within 6 months': array([ 0.02951905, -0.07260273,  0.00270757,  0.02833991,  0.09246265,
#         -0.04218353,  0.21181576,  0.06937834,  0.03210889,  0.0562085 ,
#          0.04557664,  0.02516341, -0.00604944, -0.08484399, -0.18422838,
#          0.05230871], dtype=float32),
#  'procedural coronary intervention - within 2 years': array([ 0.01162011, -0.03754656, -0.05572316, -0.03922837,  0.09310904,
#          0.03000249,  0.14515422,  0.05976712, -0.0445723 , -0.06025641,
#         -0.04496773,  0.05762331,  0.02575479,  0.01058072, -0.06215156,
#          0.09201802], dtype=float32),
#  'Restrictive Disease': array([ 0.23659626, -0.15724155, -0.03777041, -0.04255395,  0.14622411,
#         -0.24714531,  0.5301449 ,  0.00361258,  0.01470016, -0.14110017,
#          0.1289594 , -0.04554855,  0.12796514, -0.3752971 , -0.38660643,
#          0.15376899], dtype=float32),
#  'restrictive pulmonary disease': array([ 0.05806904, -0.40982166, -0.14304571,  0.03132817,  0.17030737,
#          0.05155833,  0.6866404 ,  0.06863074,  0.04073569,  0.06550977,
#          0.11588456,  0.0536782 ,  0.02737971, -0.3524534 , -0.3814689 ,
#          0.24719372], dtype=float32),
#  'stroke - remote': array([ 0.02918226, -0.10117121,  0.03722792,  0.02762179,  0.0720917 ,
#          0.01979852,  0.12093811, -0.02761574, -0.01150135,  0.05904389,
#         -0.05550487,  0.05732849, -0.04783621, -0.02093505, -0.0558982 ,
#          0.08567283], dtype=float32),
#  'Neuromuscular Disease': array([ 0.28333998, -0.30088496,  0.06982667,  0.04973911, -0.04230715,
#         -0.23606735,  0.59694344,  0.1352356 ,  0.00749359, -0.16406526,
#         -0.04598377, -0.0743458 ,  0.0810295 , -0.30420294, -0.232101  ,
#          0.0867113 ], dtype=float32),
#  'neuromuscular disease': array([ 0.08556947, -0.28256288, -0.0939156 ,  0.09622583,  0.16352646,
#         -0.05774631,  0.6444176 ,  0.18260776, -0.10113051,  0.11915044,
#         -0.0979287 ,  0.0732097 , -0.13215141, -0.20927666, -0.4364002 ,
#          0.08601111], dtype=float32),
#  'CHF - class IV': array([ 0.04596903, -0.1274553 ,  0.05926856,  0.05457659,  0.07316186,
#          0.0281019 ,  0.10749886,  0.07121979,  0.00122932,  0.04458055,
#         -0.00934369,  0.02024611,  0.03344069, -0.03458714, -0.12097271,
#          0.02395652], dtype=float32),
#  'Dementia': array([ 0.28487253, -0.40784618, -0.14535972,  0.04433107,  0.19108452,
#         -0.12466151,  0.45778918,  0.16153467,  0.10539909, -0.06819212,
#          0.12459536,  0.12030131, -0.11427743, -0.28146914, -0.2969583 ,
#          0.25722733], dtype=float32),
#  'dementia': array([ 0.12709194, -0.2806734 , -0.04189945,  0.15879406,  0.20496069,
#         -0.04533121,  0.6656101 ,  0.10855559, -0.06759958, -0.02212882,
#          0.00849915,  0.00125055, -0.14361547, -0.3764925 , -0.5326052 ,
#          0.06683435], dtype=float32),
#  'other immunosuppressive medications': array([ 0.04229675, -0.10917827,  0.03623993, -0.01020586,  0.00631736,
#         -0.12221035,  0.24161093,  0.05375674,  0.03523957, -0.01914461,
#          0.00098106,  0.0315711 ,  0.02740359, -0.10778672, -0.20633847,
#         -0.01650697], dtype=float32),
#  'other seizures': array([ 0.05791246, -0.10555261,  0.0124237 ,  0.09895072,  0.07764095,
#         -0.06068805,  0.22406046,  0.03003559, -0.05774256,  0.03833574,
#         -0.01464142,  0.00641641, -0.0462972 , -0.11174493, -0.1069548 ,
#          0.00914133], dtype=float32),
#  'stroke - within 5 years': array([ 0.08787414, -0.07063451,  0.00135727, -0.00824166,  0.0117832 ,
#         -0.07374442,  0.12999682,  0.04092355, -0.06191312,  0.05130696,
#         -0.05568402, -0.05493576, -0.06510554,  0.00748608, -0.03929592,
#          0.08569364], dtype=float32),
#  'Sarcoidosis': array([ 0.20569794, -0.09650011, -0.18344197, -0.01098484,  0.09390713,
#         -0.06588752,  0.563345  ,  0.00378551,  0.01124902,  0.0167625 ,
#         -0.09377063,  0.17089589,  0.01514731, -0.3332073 , -0.38904998,
#          0.179409  ], dtype=float32),
#  'sarcoidosis': array([ 0.33668965, -0.36278975, -0.13054076,  0.2096607 ,  0.17251903,
#         -0.06896559,  0.7055776 ,  0.09066781,  0.06607366,  0.04218755,
#          0.02621482,  0.00091335, -0.06349889, -0.2565996 , -0.32065952,
#          0.15198718], dtype=float32),
#  'pulmonary embolism - date unknown': array([ 0.01308281, -0.05204661,  0.02976473,  0.10650659,  0.10113697,
#         -0.03730204,  0.3246851 ,  0.03184651, -0.05407358,  0.0391173 ,
#          0.02751961, -0.03017161,  0.05345644, -0.11796491, -0.08991617,
#          0.06195912], dtype=float32),
#  'CHF - class I': array([ 0.05540564, -0.13312967,  0.01985467,  0.00909063,  0.08907752,
#          0.0002602 ,  0.14560087,  0.090746  ,  0.03205456,  0.00520057,
#         -0.03389997, -0.03406571, -0.05303727, -0.02090262, -0.15081117,
#          0.09560207], dtype=float32),
#  'pulmonary embolism - remote': array([ 0.03009862, -0.06027156, -0.0410619 ,  0.01420253, -0.01032291,
#          0.03159868,  0.09681074,  0.06697687, -0.00229546,  0.0196921 ,
#          0.02168276,  0.07249723, -0.01017977, -0.0763869 , -0.08606117,
#          0.03433725], dtype=float32),
#  'atrial fibrillation - intermittent': array([ 0.00845333, -0.07963176, -0.03857597, -0.02911005,  0.05534456,
#          0.00896946,  0.13451716,  0.06280737, -0.04043282,  0.01696978,
#          0.05718109,  0.01299217,  0.01470744,  0.00585516, -0.10679943,
#          0.07670287], dtype=float32),
#  'renal insufficiency - creatinine 2-3': array([ 0.11196778, -0.13151225,  0.05998901, -0.023526  , -0.01661932,
#         -0.10929576,  0.1270944 ,  0.09535109,  0.0451408 , -0.01758415,
#          0.02980795, -0.02548496,  0.0279856 , -0.01704751, -0.09547474,
#          0.00838026], dtype=float32),
#  'Intracranial Mass': array([ 0.267437  , -0.1388847 , -0.02449621, -0.11271611,  0.28967246,
#         -0.19847757,  0.39709225, -0.04084274, -0.01751247,  0.04132416,
#         -0.11316717,  0.07332858,  0.08230114, -0.15871266, -0.36503664,
#          0.26989052], dtype=float32),
#  'intracranial mass': array([ 0.17617163, -0.23161708,  0.05614303,  0.15988891,  0.0601529 ,
#         -0.09936167,  0.69356537,  0.06919779, -0.04779118,  0.06613058,
#          0.02707969,  0.03375752,  0.03256414, -0.23346472, -0.24205096,
#          0.19087471], dtype=float32),
#  'Hypercoagulable Condition': array([ 0.02273527, -0.06299807,  0.06030303,  0.04310054,  0.03233145,
#          0.02819214,  0.21116486,  0.08042426, -0.0574093 ,  0.06238598,
#          0.03191778,  0.05450725, -0.02213749, -0.03025522, -0.04985923,
#          0.00914558], dtype=float32),
#  'peptic ulcer disease': array([ 0.06155549, -0.25709173,  0.01811641,  0.02515111,  0.05449243,
#         -0.12635358,  0.46100262,  0.09352566, -0.10524639, -0.02227631,
#          0.01006864, -0.0224864 ,  0.02377259, -0.20013882, -0.21163246,
#          0.01165123], dtype=float32),
#  'ventricular tachycardia': array([ 0.07875885, -0.02467176,  0.01993635, -0.04492746, -0.03967133,
#          0.04982849,  0.07979858,  0.0359712 ,  0.04728021,  0.00191722,
#          0.06797462,  0.00250585, -0.05791085, -0.0903912 , -0.05781637,
#         -0.03570599], dtype=float32),
#  'respiratory failure - date unknown': array([ 0.0288449 , -0.02472016,  0.02061877, -0.00181931,  0.03649944,
#         -0.07024968,  0.21940851,  0.07578129,  0.01578927,  0.01799891,
#          0.06872477,  0.05772391, -0.02590727, -0.10526492, -0.03458674,
#          0.07964707], dtype=float32),
#  'MI - within 5 years': array([ 0.06069173, -0.14158575,  0.03846601, -0.05323039,  0.09123628,
#         -0.00186268,  0.17577018,  0.07620846,  0.06333902, -0.03075094,
#         -0.05751169, -0.04754914, -0.06656349, -0.10885436, -0.16294856,
#          0.00212662], dtype=float32),
#  'biopsy proven': array([ 0.12195887, -0.09299435,  0.03211686, -0.04287291,  0.05696401,
#         -0.03009961,  0.23154034, -0.02227163,  0.06050798, -0.03991712,
#         -0.04310254, -0.02471126, -0.03391437, -0.09321772, -0.12210533,
#         -0.01452696], dtype=float32),
#  'procedural coronary intervention - within 6 months': array([ 0.04877053, -0.06382952, -0.05620662,  0.00484433,  0.02814499,
#          0.00977932,  0.15886034,  0.08053005, -0.07433405,  0.03953742,
#         -0.044306  , -0.01637692,  0.00348265,  0.02099163, -0.03589976,
#          0.06073859], dtype=float32),
#  'DVT - within 5 years': array([ 0.0829872 , -0.12179127, -0.00094382,  0.04623789,  0.07960599,
#         -0.04020075,  0.11902319, -0.03659827,  0.00353422, -0.04999366,
#         -0.05430995,  0.05396634,  0.03691576, -0.06100628, -0.16393314,
#          0.0032579 ], dtype=float32),
#  'pulmonary embolism - within 5 years': array([ 0.0702108 , -0.02423576,  0.02493718, -0.03689815,  0.05090314,
#         -0.03615009,  0.11666755,  0.07378947,  0.03362799, -0.01050091,
#         -0.05474853, -0.01234072, -0.01300048, -0.01888234, -0.05327405,
#         -0.02018465], dtype=float32),
#  'MI - within 6 months': array([-0.02584053, -0.07889257, -0.05425796,  0.04247908,  0.03030221,
#          0.02009799,  0.14821906, -0.00968666,  0.05997205, -0.05063739,
#          0.0645651 ,  0.02208037, -0.04071036, -0.07430773, -0.10390723,
#         -0.01930467], dtype=float32),
#  'MI - within 2 years': array([ 0.04006778, -0.13697697, -0.05466597, -0.01567557, -0.02894695,
#         -0.03406134,  0.10980988,  0.00866756, -0.03046982, -0.04015183,
#          0.05784658,  0.02579794,  0.04194472, -0.0127658 , -0.1257943 ,
#          0.0679028 ], dtype=float32),
#  'stroke - within 6 months': array([ 0.11191891, -0.05122519, -0.02908188, -0.013444  ,  0.036448  ,
#         -0.0228646 ,  0.18126488,  0.05599681, -0.05587691, -0.06168213,
#         -0.04822348, -0.0024505 ,  0.01302908, -0.01998001, -0.08934785,
#          0.08118669], dtype=float32),
#  'Hemolytic Anemia': array([ 0.02539789,  0.02197608, -0.06522126, -0.01904121, -0.04672138,
#         -0.01212284,  0.0440001 ,  0.05928366, -0.03370131, -0.04871371,
#          0.04252033, -0.04240585,  0.00303537, -0.07541943,  0.01361307,
#          0.06311897], dtype=float32),
#  'jaundice': array([ 0.10539328, -0.11339194, -0.06164755,  0.08269195,  0.07284094,
#         -0.06151751,  0.11837611,  0.09117412,  0.02279355,  0.03985475,
#         -0.04237296, -0.0564051 , -0.00694448, -0.11060033, -0.11894671,
#          0.00348557], dtype=float32),
#  'Chronic Stone Disease': array([ 0.17335464, -0.21149316,  0.1096094 , -0.03488263,  0.06617728,
#         -0.22585665,  0.46168154, -0.0018453 ,  0.0850789 ,  0.03572103,
#          0.09470671,  0.09992547, -0.00094221, -0.14944708, -0.35101235,
#          0.16659161], dtype=float32),
#  'chronic kidney stones': array([ 0.17700963, -0.2351476 ,  0.03978775, -0.00487597,  0.19192299,
#         -0.25706345,  0.7332693 ,  0.219733  , -0.08058951,  0.06038449,
#         -0.04620489,  0.0903524 , -0.1532116 , -0.2572126 , -0.30700994,
#          0.20894273], dtype=float32),
#  'sick sinus syndrome': array([ 0.05616884, -0.08829629, -0.03935772, -0.00857788,  0.04580706,
#         -0.00244564,  0.17352399,  0.08504842,  0.05552652, -0.01644944,
#          0.05697947,  0.00527029,  0.03146774, -0.04163799, -0.0866954 ,
#          0.05758261], dtype=float32),
#  'DVT - remote': array([ 0.0895301 , -0.0743858 ,  0.03697357,  0.07064948,  0.011549  ,
#         -0.02359126,  0.15942869, -0.01949633,  0.07161375, -0.07115281,
#         -0.04056485,  0.03083075,  0.03514452, -0.0920774 , -0.06951984,
#          0.07635997], dtype=float32),
#  'CABG - within 5 years': array([ 0.08236373, -0.06996653, -0.07429348,  0.06381479,  0.08813711,
#         -0.0443848 ,  0.20034683,  0.01959375, -0.02635433, -0.00280378,
#         -0.00124531, -0.01359446,  0.00441949, -0.0210548 , -0.03743307,
#         -0.02842244], dtype=float32),
#  'renal failure - peritoneal dialysis': array([ 0.04365896, -0.22818571, -0.02522508, -0.01888182,  0.02217621,
#         -0.13189825,  0.29169065,  0.0784795 , -0.0838991 , -0.01644685,
#          0.06170945,  0.05184743, -0.08898353, -0.150287  , -0.18199983,
#         -0.0202065 ], dtype=float32),
#  'AR': array([ 0.05613319, -0.08742807, -0.04017344, -0.00230634, -0.03085392,
#         -0.07190352,  0.17741607,  0.09607251, -0.04966332, -0.00947448,
#          0.06004219, -0.00898142, -0.01921969, -0.00200863, -0.08615997,
#          0.0016958 ], dtype=float32),
#  'petite mal seizures': array([ 0.056629  , -0.18534109, -0.05656151,  0.01108905,  0.03629748,
#         -0.10607428,  0.2760588 ,  0.06192312, -0.06861543,  0.06059189,
#         -0.06385463, -0.04713368, -0.07530785, -0.12608713, -0.16817054,
#          0.10183246], dtype=float32),
#  'Sickle Cell Disease': array([-0.02189366, -0.09761305,  0.01983685,  0.0734631 ,  0.05419227,
#         -0.00740048,  0.16551904,  0.00998475, -0.02421503, -0.04800942,
#         -0.01033364, -0.01576006,  0.00100299,  0.00343959, -0.11548885,
#          0.00650561], dtype=float32),
#  'renal insufficiency - creatinine 4-5': array([ 0.04665672, -0.02228046, -0.00558192,  0.07346044,  0.08786841,
#         -0.08089748,  0.18231857,  0.08710619,  0.05867708,  0.052913  ,
#          0.04727389,  0.07559342, -0.07241354, -0.06990293, -0.15314612,
#          0.05576808], dtype=float32),
#  'TIA(s) - within 6 months': array([ 0.00842482, -0.10980418,  0.05370607,  0.06441264,  0.1118315 ,
#          0.00192636,  0.1917841 , -0.00770378,  0.04387392,  0.01070445,
#          0.03076868,  0.04488161,  0.03994493, -0.01789586, -0.18645853,
#          0.0118189 ], dtype=float32),
#  'SLE': array([ 0.54834294, -0.97282976,  0.53475964,  1.2067932 , -0.7759747 ,
#         -1.6694707 ,  3.0570064 ,  1.8213699 , -0.7320553 , -0.811358  ,
#          0.8998877 , -0.2347901 , -0.8156755 ,  0.25802884, -1.7843194 ,
#          0.21659172], dtype=float32),
#  'Hyperthyroidism': array([ 0.1741901 , -0.11834037, -0.06342413, -0.02373325,  0.13667211,
#         -0.01052527,  0.5712758 ,  0.01082622, -0.02348905,  0.09298513,
#         -0.1173948 ,  0.07260605, -0.06803717, -0.16200794, -0.2188613 ,
#          0.17401992], dtype=float32),
#  'hyperthyroidism': array([ 0.08755461, -0.2867212 ,  0.06046377,  0.04986585, -0.01948537,
#         -0.07551692,  0.6662257 ,  0.08042813, -0.00315583, -0.05509672,
#          0.02470564, -0.09113628, -0.00825006, -0.28461012, -0.347415  ,
#          0.10435883], dtype=float32),
#  'respiratory failure - remote': array([ 0.0977814 , -0.05446732, -0.04068403,  0.02735734,  0.04241259,
#         -0.01001629,  0.14520787,  0.00555086, -0.01933428,  0.01743096,
#          0.00341299, -0.02529823, -0.041779  , -0.02037046, -0.03949286,
#          0.10662585], dtype=float32),
#  'respiratory failure - within 5 years': array([ 0.02648454, -0.10039357, -0.0277652 ,  0.01512114,  0.05927741,
#         -0.05201441,  0.14845921,  0.04333467, -0.05382596,  0.0042273 ,
#          0.00334031,  0.03104865,  0.01067803, -0.05649464, -0.09776966,
#          0.08756661], dtype=float32),
#  'p Liver Transplant': array([ 0.03736838, -0.11833818,  0.01652766,  0.077944  ,  0.10772593,
#         -0.10632789,  0.35788473,  0.03057471, -0.02645998, -0.08206859,
#         -0.03049714,  0.09177539, -0.01256596, -0.08874413, -0.13170595,
#          0.13912326], dtype=float32),
#  'A': array([ 0.13242257, -0.1598748 , -0.04337168,  0.11513177, -0.02884075,
#         -0.02783126,  0.2322508 ,  0.11639614,  0.04459763, -0.03295163,
#         -0.03040189,  0.06590661, -0.00294943, -0.04163285, -0.2014772 ,
#          0.1255013 ], dtype=float32),
#  'Clotting Disorder': array([ 0.0778133 , -0.04452827,  0.05012042, -0.00283191,  0.01442243,
#          0.02621249,  0.06341358, -0.02795032, -0.03865206, -0.00163701,
#         -0.02243885,  0.04727585,  0.05492219, -0.06069163, -0.06721453,
#          0.04102156], dtype=float32),
#  "Cushing's Syndrome": array([ 0.24707992, -0.2778636 , -0.00134404,  0.12649728,  0.17356153,
#         -0.08318129,  0.6573447 ,  0.18978281, -0.14850597, -0.01525873,
#         -0.14008321, -0.09295902, -0.05902027, -0.34826383, -0.12126892,
#          0.14391701], dtype=float32),
#  "Cushing's syndrome": array([ 0.22459906, -0.43149745,  0.12439004, -0.02037993,  0.09612583,
#         -0.07571474,  0.5703065 ,  0.13304715, -0.02533427, -0.10246167,
#         -0.17523009,  0.13843384,  0.09644186, -0.33669394, -0.30619428,
#          0.15757899], dtype=float32),
#  'ITP': array([ 0.01561155, -0.10854565, -0.04611432,  0.04880691,  0.0019058 ,
#          0.03381698,  0.14324753, -0.02610458, -0.03719413,  0.03742556,
#         -0.04637496, -0.02581467, -0.0530825 , -0.02180657, -0.07973592,
#          0.05633239], dtype=float32),
#  'CABG - within 6 months': array([ 0.00655133, -0.10505156, -0.04786631, -0.00639899,  0.05494276,
#          0.03808274,  0.17992733,  0.01756136,  0.00590334,  0.06324431,
#          0.04761217,  0.04181884,  0.03467982, -0.11402703, -0.10735373,
#         -0.00345003], dtype=float32),
#  'TIA(s) - within 2 years': array([ 0.08849504, -0.02803481,  0.01829605,  0.06654739,  0.10059261,
#         -0.0190577 ,  0.23002318,  0.05932875,  0.053308  , -0.01662447,
#         -0.02105198, -0.0083353 , -0.06454237, -0.05128401, -0.05864365,
#          0.09916305], dtype=float32),
#  'respiratory failure - within 2 years': array([ 0.03084478, -0.07999175, -0.05759048,  0.03848446, -0.02458097,
#         -0.02309011,  0.13385415,  0.07369838, -0.04181316,  0.01820251,
#          0.06190375, -0.02575081, -0.04122835, -0.01261415, -0.03559629,
#          0.04227768], dtype=float32),
#  'Pulmonary Function Tests': array([ 0.22760247, -0.37190542,  0.0044746 ,  0.15762681,  0.15416649,
#         -0.15522547,  0.57885575,  0.10782707, -0.10377625,  0.0745284 ,
#         -0.01818618,  0.0903353 , -0.10680848, -0.3118978 , -0.46093574,
#          0.09720132], dtype=float32),
#  'FEV1': array([ 0.07788078, -0.08377953,  0.03245257, -0.04145046,  0.11982166,
#          0.00357526,  0.21689102,  0.07241194,  0.03005232, -0.03301293,
#         -0.06844473,  0.00270879, -0.01732107, -0.16398947, -0.09464121,
#          0.03792631], dtype=float32),
#  'FEV1 (%)': array([ 0.09124225, -0.03698463,  0.05505352, -0.04159726,  0.00352993,
#          0.01287187,  0.25095955,  0.06003483,  0.05391172, -0.01454346,
#          0.04420432, -0.05378589, -0.06222741, -0.13730188, -0.14548084,
#          0.07604067], dtype=float32),
#  'p Lung Transplant': array([ 0.09087948, -0.12650208,  0.04489383,  0.01602053,  0.09573173,
#         -0.06050952,  0.18502992,  0.07759842, -0.02260695, -0.03406763,
#         -0.07669143,  0.02017002,  0.04996827, -0.05217142, -0.18719226,
#          0.12707932], dtype=float32),
#  'moderate - stairs': array([ 0.02321429, -0.14428204,  0.00625801, -0.0345398 , -0.02231562,
#         -0.09776727,  0.14684072,  0.07951313,  0.02245702,  0.00134194,
#         -0.02316998, -0.04850629,  0.00149613, -0.08059079, -0.1184757 ,
#          0.04743148], dtype=float32),
#  'focal seizures': array([-0.00972342, -0.10260884, -0.0400438 ,  0.08333667, -0.03268524,
#         -0.03661902,  0.1479385 ,  0.06138938,  0.0226875 ,  0.04926186,
#         -0.05627295, -0.04051571, -0.06808703, -0.13128605, -0.1855251 ,
#          0.02165695], dtype=float32),
#  'Vasculitis': array([ 0.17801178, -0.35694695, -0.10439993,  0.18298931,  0.00338303,
#         -0.22401534,  0.55337375,  0.09021813, -0.10675848, -0.04149928,
#         -0.0449114 ,  0.04787007, -0.08517124, -0.25244507, -0.37849465,
#          0.07828615], dtype=float32),
#  'vasculitis': array([ 0.26086417, -0.25756353, -0.0724076 ,  0.19172917,  0.2682199 ,
#         -0.06558136,  0.5893355 ,  0.13857813, -0.01180108, -0.11590686,
#         -0.12733342,  0.02276926, -0.01384227, -0.28700733, -0.44795662,
#          0.05709448], dtype=float32),
#  'Scleroderma': array([ 0.30554783, -0.2948962 ,  0.0916926 ,  0.10192971,  0.07238486,
#          0.01952066,  0.57910216,  0.05617395, -0.10305633, -0.04128516,
#         -0.09984038,  0.06651235, -0.15697102, -0.32103544, -0.2943706 ,
#          0.13711675], dtype=float32),
#  'scleroderma': array([ 0.31273887, -0.2709179 , -0.09863704,  0.13996208,  0.30221832,
#         -0.16680358,  0.76916146,  0.22874603,  0.12890528, -0.01459919,
#          0.13254273, -0.02466851, -0.14826182, -0.12199378, -0.39213565,
#          0.10594195], dtype=float32),
#  'pulmonary embolism - within 2 years': array([-0.02072089, -0.04942872, -0.02691595,  0.02023465,  0.04088385,
#         -0.04339124,  0.05544137,  0.02865775,  0.03917821,  0.03454996,
#         -0.01562074, -0.01735297, -0.04055867, -0.0325461 , -0.03575338,
#          0.02564417], dtype=float32),
#  'coma': array([ 0.0893374 , -0.04209074,  0.03055636, -0.01203065,  0.0627303 ,
#         -0.07797719,  0.13381805, -0.03764024, -0.02562127, -0.05732537,
#         -0.0160428 , -0.03824205, -0.03416662, -0.03003778, -0.04834423,
#          0.01632484], dtype=float32),
#  'ventricular fibrillation': array([ 0.09660642, -0.01889392,  0.04536327,  0.08854718, -0.01296323,
#          0.02163866,  0.16207156,  0.02241854,  0.03114608,  0.03522831,
#          0.06691879,  0.01318484,  0.06134879, -0.03600939, -0.02268269,
#          0.05799795], dtype=float32),
#  'angina - class III': array([ 0.08470783, -0.0731333 , -0.02330496, -0.03112463,  0.0922703 ,
#         -0.01440858,  0.17148226,  0.05390017, -0.05146198,  0.01638915,
#          0.01278062, -0.04878288,  0.02217354, -0.04704187, -0.0450235 ,
#          0.064344  ], dtype=float32),
#  'A paced': array([ 0.06371198, -0.06359469, -0.039706  ,  0.05144233,  0.07049285,
#          0.02144132,  0.17009096,  0.0824873 , -0.00321768,  0.05544156,
#          0.00102292, -0.0342542 , -0.03122788, -0.08435207, -0.07517753,
#          0.05332099], dtype=float32),
#  'p Heart Transplant': array([ 7.6362997e-02, -7.0279479e-02,  1.6744429e-02, -2.3581307e-02,
#          1.0586922e-02,  7.1037840e-04,  2.2983292e-01,  1.0147642e-01,
#         -5.5409063e-02,  3.6730681e-02, -4.6102107e-02,  5.0778527e-02,
#          1.7880868e-04, -1.4424905e-01, -1.6191691e-01,  6.1585497e-02],
#        dtype=float32),
#  'angina - class IV': array([ 0.05146817, -0.14928617,  0.05278178,  0.05476542,  0.06554772,
#         -0.04206417,  0.23611237,  0.02491955, -0.03868385,  0.03383466,
#         -0.02709925, -0.00115529,  0.00969789, -0.07623725, -0.05648834,
#          0.09750022], dtype=float32),
#  'Hypersplenism': array([ 0.10711987, -0.3829792 , -0.02888141, -0.02938399,  0.1145884 ,
#         -0.15335675,  0.43984336,  0.01076057, -0.14821018,  0.01761101,
#         -0.01897897, -0.05093805, -0.11122325, -0.24399795, -0.43662575,
#          0.1260498 ], dtype=float32),
#  'splenomegaly': array([ 0.14303681, -0.19792216, -0.00574502,  0.13982846,  0.24010286,
#         -0.03361001,  0.5633205 ,  0.10482645,  0.00842264, -0.05104236,
#          0.07533115, -0.10210488,  0.04572872, -0.22494036, -0.46025193,
#          0.209906  ], dtype=float32),
#  'FVC (%)': array([ 0.05182583, -0.09888925, -0.07128684,  0.00926876,  0.13940036,
#         -0.0366598 ,  0.21544875,  0.06264989,  0.06996036, -0.04342264,
#         -0.05969306, -0.01034052,  0.04051301, -0.10945323, -0.19937925,
#          0.0414694 ], dtype=float32),
#  'unknown': array([-0.00967016, -0.048339  ,  0.00219753,  0.08539109,  0.00263624,
#         -0.05005803,  0.19003323, -0.00518745, -0.05613405,  0.02503321,
#         -0.00174002, -0.03515203,  0.0482999 , -0.11322194, -0.06807826,
#          0.0472834 ], dtype=float32),
#  'Myeloproliferative Disease': array([-0.02818837, -0.06661519, -0.04664212,  0.03091681,  0.02321122,
#         -0.04475773,  0.05636192,  0.01990083, -0.02742747,  0.02498447,
#          0.04929772,  0.02681663,  0.0519023 , -0.08196228,  0.00322875,
#          0.00882908], dtype=float32),
#  'angina - class II': array([ 0.01381387, -0.08443271, -0.02744874,  0.09045517,  0.06528383,
#         -0.0127685 ,  0.22293493,  0.08794601, -0.06051321,  0.06167162,
#         -0.02831926, -0.03801157, -0.02136258, -0.01677143, -0.1646738 ,
#          0.03466256], dtype=float32),
#  'MAT': array([ 0.04210883, -0.03018885, -0.06139485, -0.00537259, -0.01420651,
#          0.01071194,  0.11255086, -0.03520932,  0.01576883,  0.06813749,
#         -0.02622832, -0.03191275,  0.0204844 , -0.0620621 , -0.15287106,
#          0.09278496], dtype=float32),
#  'Hypercalcemia': array([ 0.02994092, -0.10496096, -0.02921059,  0.07003531,  0.07857357,
#         -0.15706329,  0.5476799 ,  0.18353255, -0.08569597, -0.04665203,
#          0.02095016,  0.08283055,  0.08190373, -0.23226236, -0.2016747 ,
#          0.02244955], dtype=float32),
#  'hypercalcemia': array([ 0.17737535, -0.30593812,  0.08628678,  0.13973023,  0.11045089,
#         -0.2570582 ,  0.4964025 ,  0.1306319 , -0.0208987 , -0.04658527,
#          0.13524076,  0.00991058,  0.03501303, -0.32058188, -0.39809442,
#          0.06161766], dtype=float32),
#  'TIA(s) - remote': array([ 0.1047697 , -0.04125096,  0.04593097,  0.08749899, -0.0156923 ,
#          0.0262936 ,  0.13024473,  0.01919091, -0.0366005 , -0.03913042,
#         -0.05476749, -0.05037663, -0.03491281, -0.06774627, -0.14664927,
#          0.07655239], dtype=float32),
#  'ventricular ectopy': array([ 0.04304506, -0.03996243, -0.02043225,  0.03889529,  0.03136697,
#          0.04012429,  0.14430925,  0.04698635,  0.01552767, -0.01920541,
#         -0.03925193,  0.05472568, -0.01566347, -0.10800663, -0.1220267 ,
#          0.00068723], dtype=float32),
#  'TIA(s) - within 5 years': array([-9.3182665e-05, -4.8201233e-02,  1.9238552e-02,  3.5187338e-02,
#          7.6229781e-02, -5.9944246e-02,  1.5382564e-01,  4.5261614e-02,
#          7.0416140e-03, -6.9049694e-02, -2.2408107e-02, -5.0248284e-02,
#          4.6186637e-02, -1.0969373e-02, -1.1690166e-01,  7.7350922e-02],
#        dtype=float32),
#  'DLCO (%)': array([ 0.07676985, -0.06352077, -0.01932924, -0.00600685,  0.07462063,
#          0.00595912,  0.1858918 ,  0.02913748, -0.06423481,  0.00728732,
#          0.05888265, -0.04143226, -0.05382664, -0.08423399, -0.11225934,
#          0.00749693], dtype=float32),
#  'Aplastic Anemia': array([ 0.00789034, -0.09603275,  0.00702741,  0.01329555, -0.04232601,
#         -0.03714683,  0.12709294,  0.06492411,  0.03059398,  0.01939019,
#         -0.02959117, -0.01147424, -0.03270685,  0.00318251, -0.10325498,
#          0.03957782], dtype=float32),
#  'Dermato': array([ 0.01114897, -0.35243973,  0.09786534,  0.18100612,  0.02027201,
#         -0.20476928,  0.49440482,  0.08263647,  0.14716016,  0.0301007 ,
#         -0.04956532, -0.02528303, -0.16399762, -0.18230481, -0.33912906,
#          0.04119658], dtype=float32),
#  'Polymyositis': array([ 0.16864254, -0.15134995,  0.07329625,  0.0674633 ,  0.14270473,
#         -0.12465639,  0.6792323 ,  0.01204966, -0.03704562,  0.04897752,
#         -0.01169889,  0.12631115,  0.09290971, -0.1257144 , -0.36853734,
#          0.24957661], dtype=float32),
#  'AIDS': array([ 1.0814974 , -0.3237427 , -1.275864  , -1.086595  ,  0.9856073 ,
#          0.47260562,  2.8196785 ,  0.58670294,  1.3617043 , -0.54470336,
#         -0.01684593,  1.3474299 , -0.97969496, -1.2242866 , -2.1021981 ,
#          0.38233274], dtype=float32),
#  'excellent - strenuous exercise (>10 mets)': array([ 0.02277904, -0.1299087 ,  0.04104923, -0.01850518,  0.09776918,
#         -0.06441065,  0.18599209,  0.05538768,  0.01603663, -0.0069025 ,
#          0.00074918, -0.04791804, -0.02080982, -0.0931963 , -0.05671808,
#          0.02056034], dtype=float32),
#  'none - bed-ridden': array([ 0.04885155, -0.09813865, -0.03370081,  0.057056  ,  0.092983  ,
#         -0.09540179,  0.23736593, -0.02198286,  0.00655944,  0.0478744 ,
#         -0.06110727, -0.01442353,  0.0567298 , -0.13733193, -0.17535256,
#          0.11622899], dtype=float32),
#  'angina - class I': array([ 0.12552266, -0.05176905, -0.01507422,  0.02988979,  0.00928688,
#         -0.06173513,  0.18593165,  0.06216652,  0.01074325,  0.06031567,
#         -0.03639903, -0.02448421, -0.00155639, -0.09781152, -0.13810305,
#          0.00044196], dtype=float32),
#  'RTA': array([ 0.07717708, -0.22143063, -0.06878939,  0.04178802,  0.19595695,
#          0.00467056,  0.69688904,  0.18531677, -0.16351074, -0.11639267,
#          0.0537737 , -0.1380828 , -0.14420193, -0.15663347, -0.36588594,
#         -0.03624604], dtype=float32),
#  'renal tubular acidosis': array([ 0.27087387, -0.37741196, -0.13524264,  0.02775309,  0.30136374,
#         -0.07511418,  0.5219631 ,  0.15233046,  0.08643499,  0.0459883 ,
#         -0.14447711,  0.09774513,  0.07756138, -0.23607652, -0.47985741,
#          0.19663215], dtype=float32),
#  'PS': array([-0.00985301, -0.02593043,  0.05163822, -0.01055134,  0.03941313,
#         -0.06840374,  0.14876635,  0.05016505,  0.03578677,  0.00811766,
#          0.01626717,  0.00951446,  0.04412626, -0.08713116, -0.13174094,
#          0.00918627], dtype=float32)}

# %%
df['past_history_embedding'].head(n=10)
# Out:
# patientunitstayid  hospitaladmitoffset  pasthistoryoffset
# 141168             0                    60                   [0.43574962, -0.60637987, -0.1081042, 0.289802...
#                                         60                   [0.32679254, -0.37862754, -0.14824907, 0.21111...
#                                         60                   [0.35420743, -0.42040563, -0.10733586, 0.16626...
#                                         60                   [0.4642007, -0.4940417, 0.042913333, 0.3671931...
#                                         60                   [3.6817322, -3.4920173, -0.90537065, -0.259674...
#                                         60                   [0.37495118, -0.5624727, -0.12942764, 0.005626...
#                                         60                   [0.33978766, -0.50038135, -0.017052568, 0.2514...
#                                         60                   [0.31318283, -0.3843747, -0.14824475, 0.066163...
#                                         115                  [0.32679254, -0.37862754, -0.14824907, 0.21111...
#                                         115                  [0.4642007, -0.4940417, 0.042913333, 0.3671931...
# Name: past_history_embedding, dtype: object

# %%
df.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                COPD  - no limitations
#                                       60                                                    AS
#                                       60                                        CHF - class II
#                                       60                      hypertension requiring treatment
#                                       60                                                  AICD
#                                       60                 renal failure- not currently dialyzed
#                                       60                                  rheumatoid arthritis
#                                       60                         atrial fibrillation - chronic
#                                       115                                                   AS
#                                       115                     hypertension requiring treatment
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       115                  NaN
#                                       115                  NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#                                       115                               Death
#
#                                                         unitdischargestatus  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired
#                                       115                           Expired
#
#                                                                                     past_history_embedding
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 [0.43574962, -0.60637987, -0.1081042, 0.289802...
#                                       60                 [0.32679254, -0.37862754, -0.14824907, 0.21111...
#                                       60                 [0.35420743, -0.42040563, -0.10733586, 0.16626...
#                                       60                 [0.4642007, -0.4940417, 0.042913333, 0.3671931...
#                                       60                 [3.6817322, -3.4920173, -0.90537065, -0.259674...
#                                       60                 [0.37495118, -0.5624727, -0.12942764, 0.005626...
#                                       60                 [0.33978766, -0.50038135, -0.017052568, 0.2514...
#                                       60                 [0.31318283, -0.3843747, -0.14824475, 0.066163...
#                                       115                [0.32679254, -0.37862754, -0.14824907, 0.21111...
#                                       115                [0.4642007, -0.4940417, 0.042913333, 0.3671931...

# %%
# df.to_csv(porcesseddir2 + 'embedded_pastHistory.csv')

df=pd.read_csv(porcesseddir2 + 'embedded_pastHistory.csv')

# %%
df2=df.copy()

# %%
df2['past_history_embedding']=np.array( df2['past_history_embedding'],dtype=object)

# %%
df2.head()
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#
#                                                                                     third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           COPD  - no limitations
#                                       60                                               AS
#                                       60                                   CHF - class II
#                                       60                 hypertension requiring treatment
#                                       60                                             AICD
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#
#                                                         unitdischargestatus  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#
#                                                                                     past_history_embedding
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 [0.43574962, -0.60637987, -0.1081042, 0.289802...
#                                       60                 [0.32679254, -0.37862754, -0.14824907, 0.21111...
#                                       60                 [0.35420743, -0.42040563, -0.10733586, 0.16626...
#                                       60                 [0.4642007, -0.4940417, 0.042913333, 0.3671931...
#                                       60                 [3.6817322, -3.4920173, -0.90537065, -0.259674...

# %% [markdown]
# ## max pooling Aggregation

# %%
# df1['past_history_embedding'] = df1['past_history_embedding'].apply(np.array)

def max_pooling(embeddings):
    # Stack embeddings and take the maximum across each dimension
    return np.max(np.vstack(embeddings), axis=0)

df_max_pooled = df2.groupby('patientunitstayid')['past_history_embedding'].apply(max_pooling).reset_index()

df_max_pooled.rename(columns={'past_history_embedding': 'max_pooled_embedding'}, inplace=True)

print(df_max_pooled.head())
# Out:
#    patientunitstayid                               max_pooled_embedding
# 0             141168  [3.6817322, -0.33900663, 0.042913333, 0.367193...
# 1             141265  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 2             141266  [0.4642007, -0.33900663, 0.100118384, 0.367193...
# 3             141276  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 4             141284  [0.4848393, -0.49136096, 0.042913333, 0.367193...

# %%
df_max = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_max = df_max.groupby('patientunitstayid').first().reset_index()
df_max.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [3.6817322, -0.33900663, 0.042913333, 0.367193...
# 1  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 2  [0.4642007, -0.33900663, 0.100118384, 0.367193...
# 3  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 4  [0.4848393, -0.49136096, 0.042913333, 0.367193...

# %% [markdown]
# ## sum aggregation

# %%
def sum_aggregation(embeddings):
    return np.sum(np.vstack(embeddings), axis=0)

# Group by 'patientunitstayid' and apply sum aggregation
df_sum_aggregated = df.groupby('patientunitstayid')['past_history_embedding'].apply(sum_aggregation).reset_index()

# Rename the column to indicate sum-aggregated embeddings
df_sum_aggregated.rename(columns={'past_history_embedding': 'sum_aggregated_embedding'}, inplace=True)

# Display the result
print(df_sum_aggregated.head())
# Out:
#    patientunitstayid                           sum_aggregated_embedding
# 0             141168  [7.9882274, -7.4432325, -1.9430639, 2.9261658,...
# 1             141265  [0.14762807, -0.4765364, -0.08805785, 0.215569...
# 2             141266  [4.5776143, -4.4374404, -1.2511735, 2.3237233,...
# 3             141276  [0.14762807, -0.4765364, -0.08805785, 0.215569...
# 4             141284  [1.8346597, -1.7714701, -0.44224504, 0.8185866...

# %%
df_sum = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_sum = df_sum.groupby('patientunitstayid').first().reset_index()
df_sum.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [3.6817322, -0.33900663, 0.042913333, 0.367193...
# 1  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 2  [0.4642007, -0.33900663, 0.100118384, 0.367193...
# 3  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 4  [0.4848393, -0.49136096, 0.042913333, 0.367193...

# %% [markdown]
# ## avg aggregation

# %%
def average_aggregation(embeddings):
    return np.mean(np.vstack(embeddings), axis=0)

# Group by 'patientunitstayid' and apply average aggregation
df_avg_aggregated = df.groupby('patientunitstayid')['past_history_embedding'].apply(average_aggregation).reset_index()

# Rename the column to indicate average-aggregated embeddings
df_avg_aggregated.rename(columns={'past_history_embedding': 'avg_aggregated_embedding'}, inplace=True)

# Display the result
print(df_avg_aggregated.head())
# Out:
#    patientunitstayid                           avg_aggregated_embedding
# 0             141168  [0.5705877, -0.5316595, -0.13879028, 0.2090118...
# 1             141265  [0.14762807, -0.4765364, -0.08805785, 0.215569...
# 2             141266  [0.3051743, -0.29582936, -0.08341157, 0.154914...
# 3             141276  [0.14762807, -0.4765364, -0.08805785, 0.215569...
# 4             141284  [0.45866492, -0.44286752, -0.11056126, 0.20464...

# %%
df_avg = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_avg = df_avg.groupby('patientunitstayid').first().reset_index()
df_avg.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [3.6817322, -0.33900663, 0.042913333, 0.367193...
# 1  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 2  [0.4642007, -0.33900663, 0.100118384, 0.367193...
# 3  [0.33518007, -0.50759095, 0.050242223, 0.20850...
# 4  [0.4848393, -0.49136096, 0.042913333, 0.367193...
