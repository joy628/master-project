# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
import getpass
import pdvega
import seaborn as sns
# for configuring connection 
from configobj import ConfigObj
import os

# %matplotlib inline

# %%
datadir = '/home/mei/nas/docker/dataset/EICU/eicu-collaborative-research-database-2.0/'
porcesseddir2 = '/home/mei/nas/docker/processedData_2/'

# %%
# Create a database connection using settings from config file
config='../db/config.ini'

# connection info
conn_info = dict()
if os.path.isfile(config):
    config = ConfigObj(config)
    conn_info["sqluser"] = config['username']
    conn_info["sqlpass"] = config['password']
    conn_info["sqlhost"] = config['host']
    conn_info["sqlport"] = config['port']
    conn_info["dbname"] = config['dbname']
    conn_info["schema_name"] = config['schema_name']
else:
    conn_info["sqluser"] = 'postgres'
    conn_info["sqlpass"] = ''
    conn_info["sqlhost"] = '192.168.60.144'
    conn_info["sqlport"] = 6432
    conn_info["dbname"] = 'eicu'
    conn_info["schema_name"] = 'public,eicu_crd'
    
# Connect to the eICU database
print('Database: {}'.format(conn_info['dbname']))
print('Username: {}'.format(conn_info["sqluser"]))
if conn_info["sqlpass"] == '':
    # try connecting without password, i.e. peer or OS authentication
    try:
        if (conn_info["sqlhost"] == '192.168.60.144') & (conn_info["sqlport"]=='6432'):
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   user=conn_info["sqluser"])            
        else:
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   host=conn_info["sqlhost"],
                                   port=conn_info["sqlport"],
                                   user=conn_info["sqluser"])
    except:
        conn_info["sqlpass"] = getpass.getpass('Password: ')

        con = psycopg2.connect(dbname=conn_info["dbname"],
                               host=conn_info["sqlhost"],
                               port=conn_info["sqlport"],
                               user=conn_info["sqluser"],
                               password=conn_info["sqlpass"])
query_schema = 'set search_path to ' + conn_info['schema_name'] + ';'
# Out:
# Database: eicu
# Username: postgres

# %%
from sqlalchemy import create_engine,text
con= create_engine('postgresql://eicu@192.168.60.144:6432/eicu')

# %%
def round_up(x, base=5):
    return base * round(x/base)

# %%
query = query_schema + """
select p.patientunitstayid, p.hospitaladmitOffset,ph.pasthistoryoffset,p.gender, p.age, 
      p.apacheadmissiondx,ph.pasthistorypath,p.unitadmitsource, p.admissionweight,	
      p.dischargeweight, p.unitdischargeoffset, p.unitdischargelocation,	
      p.unitdischargestatus
from pasthistory ph
join patient_2 p
  on ph.patientunitstayid = p.patientunitstayid
  
order by p.patientunitstayid, p.hospitaladmitOffset,ph.pasthistoryoffset
"""

# %%
df_past= pd.read_sql_query(query,con)
df_past.head(n=20)
# Out:
#     patientunitstayid  hospitaladmitoffset  pasthistoryoffset  gender age  \
# 0              141168                    0                 60  Female  70
# 1              141168                    0                 60  Female  70
# 2              141168                    0                 60  Female  70
# 3              141168                    0                 60  Female  70
# 4              141168                    0                 60  Female  70
# 5              141168                    0                 60  Female  70
# 6              141168                    0                 60  Female  70
# 7              141168                    0                 60  Female  70
# 8              141168                    0                 60  Female  70
# 9              141168                    0                114  Female  70
# 10             141168                    0                114  Female  70
# 11             141168                    0                114  Female  70
# 12             141168                    0                114  Female  70
# 13             141168                    0                114  Female  70
# 14             141168                    0                114  Female  70
# 15             141168                    0                114  Female  70
# 16             141265                   -1                 23    Male  67
# 17             141265                   -1                 23    Male  67
# 18             141266                  -18                 40    Male  73
# 19             141266                  -18                 40    Male  73
#
#                                 apacheadmissiondx  \
# 0   Rhythm disturbance (atrial, supraventricular)
# 1   Rhythm disturbance (atrial, supraventricular)
# 2   Rhythm disturbance (atrial, supraventricular)
# 3   Rhythm disturbance (atrial, supraventricular)
# 4   Rhythm disturbance (atrial, supraventricular)
# 5   Rhythm disturbance (atrial, supraventricular)
# 6   Rhythm disturbance (atrial, supraventricular)
# 7   Rhythm disturbance (atrial, supraventricular)
# 8   Rhythm disturbance (atrial, supraventricular)
# 9   Rhythm disturbance (atrial, supraventricular)
# 10  Rhythm disturbance (atrial, supraventricular)
# 11  Rhythm disturbance (atrial, supraventricular)
# 12  Rhythm disturbance (atrial, supraventricular)
# 13  Rhythm disturbance (atrial, supraventricular)
# 14  Rhythm disturbance (atrial, supraventricular)
# 15  Rhythm disturbance (atrial, supraventricular)
# 16           CVA, cerebrovascular accident/stroke
# 17           CVA, cerebrovascular accident/stroke
# 18          Sepsis, renal/UTI (including bladder)
# 19          Sepsis, renal/UTI (including bladder)
#
#                                       pasthistorypath       unitadmitsource  \
# 0   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 1   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 2   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 3   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 4   notes/Progress Notes/Past History/Past History...          Direct Admit
# 5   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 6   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 7   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 8   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 9   notes/Progress Notes/Past History/Organ System...          Direct Admit
# 10  notes/Progress Notes/Past History/Past History...          Direct Admit
# 11  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 12  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 13  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 14  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 15  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 16  notes/Progress Notes/Past History/Past History...          Direct Admit
# 17  notes/Progress Notes/Past History/Organ System...          Direct Admit
# 18  notes/Progress Notes/Past History/Organ System...  Emergency Department
# 19  notes/Progress Notes/Past History/Past History...  Emergency Department
#
#     admissionweight  dischargeweight  unitdischargeoffset  \
# 0              84.3             85.8                 3596
# 1              84.3             85.8                 3596
# 2              84.3             85.8                 3596
# 3              84.3             85.8                 3596
# 4              84.3             85.8                 3596
# 5              84.3             85.8                 3596
# 6              84.3             85.8                 3596
# 7              84.3             85.8                 3596
# 8              84.3             85.8                 3596
# 9              84.3             85.8                 3596
# 10             84.3             85.8                 3596
# 11             84.3             85.8                 3596
# 12             84.3             85.8                 3596
# 13             84.3             85.8                 3596
# 14             84.3             85.8                 3596
# 15             84.3             85.8                 3596
# 16            100.0             91.8                 6068
# 17            100.0             91.8                 6068
# 18            120.4            112.9                 1501
# 19            120.4            112.9                 1501
#
#    unitdischargelocation unitdischargestatus
# 0                  Death             Expired
# 1                  Death             Expired
# 2                  Death             Expired
# 3                  Death             Expired
# 4                  Death             Expired
# 5                  Death             Expired
# 6                  Death             Expired
# 7                  Death             Expired
# 8                  Death             Expired
# 9                  Death             Expired
# 10                 Death             Expired
# 11                 Death             Expired
# 12                 Death             Expired
# 13                 Death             Expired
# 14                 Death             Expired
# 15                 Death             Expired
# 16                 Floor               Alive
# 17                 Floor               Alive
# 18                 Floor               Alive
# 19                 Floor               Alive

# %%
df=df_past.copy()
# Set indices
df = df.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df = df.drop(df.index[np.where(df.index.get_level_values('pasthistoryoffset') < 0)])
df.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
# Resample every 5 mins
df.rename(round_up, level = 'pasthistoryoffset', inplace = True)
df.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Past History...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       60                 notes/Progress Notes/Past History/Organ System...
#                                       115                notes/Progress Notes/Past History/Organ System...
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired

# %%
df1 = df[df['pasthistorypath'].str.contains('Organ Systems')]
df1 = df1.reset_index()
df1['pasthistorypath'] = df1['pasthistorypath'].str.replace('notes/Progress Notes/Past History/Organ Systems/', ' ')
df1['pasthistorypath'] = df1['pasthistorypath'].str.replace('|', '/')
split = df1['pasthistorypath'].str.split('/')
df1['first'] = split.str[0]
df1['second'] = split.str[1]
df1['third'] = split.str[2]
df1['fourth'] = split.str[3]

df1.head()
# Out:
#    patientunitstayid  hospitaladmitoffset  pasthistoryoffset  gender age  \
# 0             141168                    0                 60  Female  70
# 1             141168                    0                 60  Female  70
# 2             141168                    0                 60  Female  70
# 3             141168                    0                 60  Female  70
# 4             141168                    0                 60  Female  70
#
#                                apacheadmissiondx  \
# 0  Rhythm disturbance (atrial, supraventricular)
# 1  Rhythm disturbance (atrial, supraventricular)
# 2  Rhythm disturbance (atrial, supraventricular)
# 3  Rhythm disturbance (atrial, supraventricular)
# 4  Rhythm disturbance (atrial, supraventricular)
#
#                                      pasthistorypath unitadmitsource  \
# 0              Pulmonary/COPD/COPD  - no limitations    Direct Admit
# 1                Cardiovascular (R)/Valve disease/AS    Direct Admit
# 2   Cardiovascular (R)/Congestive Heart Failure/C...    Direct Admit
# 3   Cardiovascular (R)/Hypertension Requiring Tre...    Direct Admit
# 4                       Cardiovascular (R)/AICD/AICD    Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1             84.3             85.8                 3596
# 2             84.3             85.8                 3596
# 3             84.3             85.8                 3596
# 4             84.3             85.8                 3596
#
#   unitdischargelocation unitdischargestatus                first  \
# 0                 Death             Expired            Pulmonary
# 1                 Death             Expired   Cardiovascular (R)
# 2                 Death             Expired   Cardiovascular (R)
# 3                 Death             Expired   Cardiovascular (R)
# 4                 Death             Expired   Cardiovascular (R)
#
#                              second                             third fourth
# 0                              COPD            COPD  - no limitations    NaN
# 1                     Valve disease                                AS    NaN
# 2          Congestive Heart Failure                    CHF - class II    NaN
# 3  Hypertension Requiring Treatment  hypertension requiring treatment    NaN
# 4                              AICD                              AICD    NaN

# %%
columns = df1.columns.tolist()
index = columns.index('pasthistorypath')
new_order = columns[:index + 1] + ['first', 'second', 'third', 'fourth'] + columns[index + 1:-4]
df1 = df1.reindex(columns=new_order)
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
# df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
df1.head()
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#
#                                                                                     third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           COPD  - no limitations
#                                       60                                               AS
#                                       60                                   CHF - class II
#                                       60                 hypertension requiring treatment
#                                       60                                             AICD
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired

# %%
# df1.to_csv(porcesseddir2 + 'selected_pastHistory.csv',  index=True)

# %%
n=len(list(df1.index.get_level_values('patientunitstayid').unique()))
r=len(df1)
print("There are {} unique patientunitstayid in the selected patients with the total {} records.".format(n,r))
# Out:
# There are 53612 unique patientunitstayid in the selected patients with the total 312103 records.

# %%
df1= pd.read_csv(porcesseddir2 + 'selected_pastHistory.csv')
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)
df1.head(n=20)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
#                                       115                Female  70
# 141265            -1                  25                   Male  67
# 141266            -18                 40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#                                       40                   Male  73
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
# 141265            -1                  25                          CVA, cerebrovascular accident/stroke
# 141266            -18                 40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#                                       40                         Sepsis, renal/UTI (including bladder)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#                                       115                 Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                            Pulmonary/COPD/COPD  - no limitations
#                                       115                 Cardiovascular (R)/Congestive Heart Failure/C...
#                                       115                 Renal  (R)/Renal Failure/renal failure- not c...
# 141265            -1                  25                  Endocrine (R)/Non-Insulin Dependent Diabetes/...
# 141266            -18                 40                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       40                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       40                  Cardiovascular (R)/Angina/angina - severity u...
#                                       40                  Renal  (R)/Renal Insufficiency/renal insuffic...
#                                       40                  Endocrine (R)/Insulin Dependent Diabetes/insu...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                          Pulmonary
#                                       115                 Cardiovascular (R)
#                                       115                         Renal  (R)
# 141265            -1                  25                       Endocrine (R)
# 141266            -18                 40                  Cardiovascular (R)
#                                       40                  Cardiovascular (R)
#                                       40                  Cardiovascular (R)
#                                       40                          Renal  (R)
#                                       40                       Endocrine (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#                                       115                                     Arrhythmias
#                                       115                                            COPD
#                                       115                        Congestive Heart Failure
#                                       115                                   Renal Failure
# 141265            -1                  25                   Non-Insulin Dependent Diabetes
# 141266            -18                 40                 Hypertension Requiring Treatment
#                                       40                         Congestive Heart Failure
#                                       40                                           Angina
#                                       40                              Renal Insufficiency
#                                       40                       Insulin Dependent Diabetes
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168             0                  60
freq['%'] = (df_unique['apacheadmissiondx'].value_counts() / len(df_unique)) * 100
freq.head(n=10)
# Out:
#                                                     noAnnotations         %
# apacheadmissiondx
# Sepsis, pulmonary                                            3972  7.408789
# CVA, cerebrovascular accident/stroke                         2923  5.452138
# Infarction, acute myocardial (MI)                            2867  5.347683
# CHF, congestive heart failure                                2773  5.172349
# Sepsis, renal/UTI (including bladder)                        2552  4.760128
# Diabetic ketoacidosis                                        2316  4.319928
# Emphysema/bronchitis                                         1944  3.626054
# Cardiac arrest (with or without respiratory arr...           1599  2.982541
# Pneumonia, bacterial                                         1576  2.939640
# Rhythm disturbance (atrial, supraventricular)                1560  2.909796

# %%
# freq.to_csv(porcesseddir2 + 'selected_pastHistory_apacheaddx_freq.csv',  index=True)

# %% [markdown]
# ## nan 值统计

# %%
missing_ratio = pd.DataFrame(df1.isna().sum() / len(df1.index), columns = ['missing ratio %']) * 100
missing_ratio.sort_values('missing ratio %', inplace = True, ascending = False) 
missing_ratio
# Out:
#                        missing ratio %
# fourth                       89.413431
# dischargeweight              34.968264
# admissionweight               1.186788
# gender                        0.000000
# age                           0.000000
# apacheadmissiondx             0.000000
# pasthistorypath               0.000000
# first                         0.000000
# second                        0.000000
# third                         0.000000
# unitadmitsource               0.000000
# unitdischargeoffset           0.000000
# unitdischargelocation         0.000000
# unitdischargestatus           0.000000

# %% [markdown]
# ## frequency of past dx history

# %% [markdown]
# ### first

# %%
frequency1 = pd.DataFrame()
frequency1['noAnnotations'] = df1['first'].value_counts() 
frequency1['%'] = df1['first'].value_counts() / len(df1.index) * 100
frequency1
# Out:
#                         noAnnotations          %
# first
# Cardiovascular (R)             144104  46.171937
# Endocrine (R)                   45774  14.666312
# Pulmonary                       39744  12.734258
# Neurologic                      27196   8.713790
# Hematology                      22345   7.159495
# Renal  (R)                      17722   5.678254
# Gastrointestinal (R)            10621   3.403043
# Rheumatic                        2666   0.854205
# Infectious Disease (R)           1931   0.618706

# %%
frequency2 = pd.DataFrame()
frequency2['noAnnotations'] = df1['second'].value_counts() 
frequency2['%'] = df1['second'].value_counts() / len(df1.index) * 100
frequency2
# Out:
#                                         noAnnotations          %
# second
# Hypertension Requiring Treatment                56983  18.257755
# Oncology (R)                                    22345   7.159495
# COPD                                            19067   6.109201
# Congestive Heart Failure                        18473   5.918879
# Non-Insulin Dependent Diabetes                  17760   5.690429
# Insulin Dependent Diabetes                      16268   5.212382
# Arrhythmias                                     15676   5.022701
# Myocardial Infarction                           10655   3.413937
# Hypothyroidism                                  10649   3.412015
# Strokes                                         10374   3.323903
# Renal Insufficiency                              8535   2.734674
# Asthma                                           8242   2.640795
# Procedural Coronary Intervention                 7897   2.530254
# Seizures                                         7720   2.473542
# Renal Failure                                    7279   2.332243
# Coronary Artery Bypass                           7155   2.292512
# Cirrhosis                                        7148   2.290270
# Valve disease                                    5973   1.913791
# Peripheral Vascular Disease                      5149   1.649776
# Home Oxygen                                      4963   1.590180
# Dementia                                         4536   1.453366
# Venous Thrombosis                                4292   1.375187
# Pacemaker                                        4019   1.287716
# Respiratory Failure                              3573   1.144814
# Peptic Ulcer Disease                             3112   0.997107
# TIA(s)                                           3003   0.962182
# Pulmonary Function Tests                         2831   0.907072
# Angina                                           2533   0.811591
# Pulmonary Embolism                               2389   0.765452
# AICD                                             2270   0.727324
# Rheumatoid Arthritis                             1973   0.632163
# Neuromuscular Disease                            1127   0.361099
# Immunosuppression within past 6 months           1053   0.337389
# Chronic Stone Disease                            1019   0.326495
# s                                                 999   0.320087
# Restrictive Disease                               894   0.286444
# HIV (only)                                        676   0.216595
# Recent Steroid Use (for > 10 days)                559   0.179108
# Exercise Tolerance                                526   0.168534
# SLE                                               525   0.168214
# Hyperthyroidism                                   452   0.144824
# Intracranial Mass                                 436   0.139697
# Neurogenic Bladder                                270   0.086510
# AIDS                                              202   0.064722
# Sarcoidosis                                       142   0.045498
# Vasculitis                                        110   0.035245
# Hypersplenism                                     106   0.033963
# Hypercalcemia                                      64   0.020506
# Scleroderma                                        33   0.010573
# Dermato                                            25   0.008010
# Cushing's Syndrome                                 22   0.007049
# RTA                                                21   0.006729

# %%
frequency3 = pd.DataFrame()
frequency3['noAnnotations'] = df1['third'].value_counts() 
frequency3['%'] = df1['third'].value_counts() / len(df1.index) * 100
frequency3.head(n=10)
# Out:
#                                   noAnnotations          %
# third
# hypertension requiring treatment          56983  18.257755
# Cancer                                    17532   5.617376
# insulin dependent diabetes                16268   5.212382
# CHF                                       14251   4.566121
# medication dependent                      13678   4.382528
# atrial fibrillation - chronic             10881   3.486349
# hypothyroidism                            10649   3.412015
# COPD  - moderate                           9063   2.903849
# asthma                                     8242   2.640795
# stroke - date unknown                      6399   2.050285

# %%
frequency4 = pd.DataFrame()
frequency4['noAnnotations'] = df1['fourth'].value_counts() 
frequency4['%'] = df1['fourth'].value_counts() / len(df1.index) * 100
frequency4
# Out:
#                                         noAnnotations         %
# fourth
# Cancer-Primary Site                             12246  3.923705
# Metastases                                       3389  1.085859
# multiple                                         3035  0.972435
# Chemotherapy                                     2274  0.728606
# Hematologic Malignancy                           1897  0.607812
# p AVR                                            1286  0.412043
# Radiation Therapy within past 6 months           1113  0.356613
# s                                                 999  0.320087
# o GI bleeding                                     967  0.309834
# V paced                                           796  0.255044
# FVC Ratio                                         715  0.229091
# p MVR                                             592  0.189681
# hemolytic anemia                                  468  0.149950
# FVC >80                                           263  0.084267
# FEV1 41-50                                        257  0.082345
# hypercoagulable condition                         214  0.068567
# ITP                                               196  0.062800
# FEV1 31-40                                        195  0.062479
# FEV1 >80                                          177  0.056712
# clotting disorder                                 173  0.055430
# sickle cell disease                               167  0.053508
# FEV1 51-60                                        161  0.051586
# FVC 51-60                                         140  0.044857
# FVC 41-50                                         126  0.040371
# FEV1 61-70                                        125  0.040051
# FVC 61-70                                         113  0.036206
# FEV1 <30                                           97  0.031079
# FEV1 71-80                                         92  0.029477
# aplastic anemia                                    87  0.027875
# brisk walking (5-10 mets)                          84  0.026914
# p TVR                                              81  0.025953
# FVC 71-80                                          59  0.018904
# FVC 31-40                                          58  0.018584
# DLCO 31-40                                         52  0.016661
# essential thrombocytosis                           52  0.016661
# DLCO <30                                           46  0.014739
# DLCO 51-60                                         43  0.013778
# myelofibrosis                                      42  0.013457
# FVC <30                                            34  0.010894
# DLCO 71-80                                         33  0.010573
# polycythemia vera                                  27  0.008651
# dermatomyositis                                    25  0.008010
# DLCO 41-50                                         17  0.005447
# DLCO >80                                           15  0.004806
# DLCO 61-70                                         13  0.004165

# %%
df_past_dx=df1.copy()
frequency_table_1 =df_past_dx.groupby(['apacheadmissiondx','first']).size().reset_index(name='count')
frequency_table_1 = frequency_table_1.sort_values(by='count', ascending=False)
frequency_table_1.head(n=20)
# Out:
#                                       apacheadmissiondx                first  \
# 309                       CHF, congestive heart failure   Cardiovascular (R)
# 1603                                  Sepsis, pulmonary   Cardiovascular (R)
# 318                CVA, cerebrovascular accident/stroke   Cardiovascular (R)
# 1110                  Infarction, acute myocardial (MI)   Cardiovascular (R)
# 1612              Sepsis, renal/UTI (including bladder)   Cardiovascular (R)
# 677                                Emphysema/bronchitis            Pulmonary
# 389   Cardiac arrest (with or without respiratory ar...   Cardiovascular (R)
# 671                                Emphysema/bronchitis   Cardiovascular (R)
# 1413                               Pneumonia, bacterial   Cardiovascular (R)
# 1534      Rhythm disturbance (atrial, supraventricular)   Cardiovascular (R)
# 1609                                  Sepsis, pulmonary            Pulmonary
# 1621                                    Sepsis, unknown   Cardiovascular (R)
# 1507                       Respiratory - medical, other   Cardiovascular (R)
# 1604                                  Sepsis, pulmonary        Endocrine (R)
# 607                               Diabetic ketoacidosis        Endocrine (R)
# 260                                  Bleeding, upper GI   Cardiovascular (R)
# 251                                  Bleeding, lower GI   Cardiovascular (R)
# 1474                               Renal failure, acute   Cardiovascular (R)
# 242                       Bleeding, GI-location unknown   Cardiovascular (R)
# 310                       CHF, congestive heart failure        Endocrine (R)
#
#       count
# 309   11868
# 1603  10688
# 318    7596
# 1110   7308
# 1612   6442
# 677    5130
# 389    4985
# 671    4823
# 1413   4509
# 1534   4405
# 1609   4161
# 1621   3941
# 1507   3879
# 1604   3390
# 607    3338
# 260    3244
# 251    3185
# 1474   3120
# 242    2847
# 310    2746

# %%
frequency_table_2 =df_past_dx.groupby(['apacheadmissiondx','second']).size().reset_index(name='count')
frequency_table_2 = frequency_table_2.sort_values(by='count', ascending=False)
frequency_table_2.head(n=20)
# Out:
#                                       apacheadmissiondx  \
# 5294                                  Sepsis, pulmonary
# 1023               CVA, cerebrovascular accident/stroke
# 974                       CHF, congestive heart failure
# 965                       CHF, congestive heart failure
# 3564                  Infarction, acute myocardial (MI)
# 2135                               Emphysema/bronchitis
# 5344              Sepsis, renal/UTI (including bladder)
# 1904                              Diabetic ketoacidosis
# 5304                                  Sepsis, pulmonary
# 5283                                  Sepsis, pulmonary
# 1193  Cardiac arrest (with or without respiratory ar...
# 2147                               Emphysema/bronchitis
# 4518                               Pneumonia, bacterial
# 5286                                  Sepsis, pulmonary
# 3171                  Hemorrhage/hematoma, intracranial
# 4974      Rhythm disturbance (atrial, supraventricular)
# 842                                  Bleeding, upper GI
# 4856                       Respiratory - medical, other
# 5281                                  Sepsis, pulmonary
# 5354              Sepsis, renal/UTI (including bladder)
#
#                                 second  count
# 5294  Hypertension Requiring Treatment   3941
# 1023  Hypertension Requiring Treatment   3595
# 974   Hypertension Requiring Treatment   3101
# 965           Congestive Heart Failure   2856
# 3564  Hypertension Requiring Treatment   2841
# 2135                              COPD   2599
# 5344  Hypertension Requiring Treatment   2585
# 1904        Insulin Dependent Diabetes   2573
# 5304                      Oncology (R)   2436
# 5283                              COPD   2203
# 1193  Hypertension Requiring Treatment   1903
# 2147  Hypertension Requiring Treatment   1858
# 4518  Hypertension Requiring Treatment   1757
# 5286          Congestive Heart Failure   1673
# 3171  Hypertension Requiring Treatment   1529
# 4974  Hypertension Requiring Treatment   1517
# 842   Hypertension Requiring Treatment   1379
# 4856  Hypertension Requiring Treatment   1367
# 5281                       Arrhythmias   1329
# 5354                      Oncology (R)   1313

# %%
df1.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                COPD  - no limitations
#                                       60                                                    AS
#                                       60                                        CHF - class II
#                                       60                      hypertension requiring treatment
#                                       60                                                  AICD
#                                       60                 renal failure- not currently dialyzed
#                                       60                                  rheumatoid arthritis
#                                       60                         atrial fibrillation - chronic
#                                       115                                                   AS
#                                       115                     hypertension requiring treatment
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       115                  NaN
#                                       115                  NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#                                       115                               Death
#
#                                                         unitdischargestatus
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired
#                                       115                           Expired

# %%
df1['first'].unique()
# Out:
# array(['Pulmonary', 'Cardiovascular (R)', 'Renal  (R)', 'Rheumatic',
#        'Endocrine (R)', 'Gastrointestinal (R)', 'Infectious Disease (R)',
#        'Neurologic', 'Hematology'], dtype=object)

# %%
# 去除 first 列中的多余空格
df1['first'] = df1['first'].str.strip()

# 然后运行你的代码
from tabulate import tabulate

diseases = ['Cardiovascular (R)', 'Endocrine (R)', 'Pulmonary', 'Neurologic', 'Hematology', 'Renal  (R)', 'Gastrointestinal (R)', 'Rheumatic', 'Infectious Disease (R)']

for disease in diseases:
    # 筛选出特定疾病的数据
    df_disease = df1[df1['first'] == disease].copy()
    # 统计疾病的频率
    freq = pd.DataFrame()
    freq['noAnnotations'] = df_disease['second'].value_counts()
    freq['%'] = round(df_disease['second'].value_counts() / len(df_disease.index) * 100, 2)

    # 格式化输出
    table = tabulate(freq, headers="keys", tablefmt="psql", showindex=True)
    print(f"The frequency of {disease}:")
    print(table)
    print("------------------------------")
# Out:
# The frequency of Cardiovascular (R):
# +----------------------------------+-----------------+-------+
# | second                           |   noAnnotations |     % |
# |----------------------------------+-----------------+-------|
# | Hypertension Requiring Treatment |           56983 | 39.54 |
# | Congestive Heart Failure         |           18473 | 12.82 |
# | Arrhythmias                      |           15676 | 10.88 |
# | Myocardial Infarction            |           10655 |  7.39 |
# | Procedural Coronary Intervention |            7897 |  5.48 |
# | Coronary Artery Bypass           |            7155 |  4.97 |
# | Valve disease                    |            5973 |  4.14 |
# | Peripheral Vascular Disease      |            5149 |  3.57 |
# | Venous Thrombosis                |            4292 |  2.98 |
# | Pacemaker                        |            4019 |  2.79 |
# | Angina                           |            2533 |  1.76 |
# | Pulmonary Embolism               |            2389 |  1.66 |
# | AICD                             |            2270 |  1.58 |
# | Exercise Tolerance               |             526 |  0.37 |
# | s                                |             114 |  0.08 |
# +----------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Endocrine (R):
# +------------------------------------+-----------------+-------+
# | second                             |   noAnnotations |     % |
# |------------------------------------+-----------------+-------|
# | Non-Insulin Dependent Diabetes     |           17760 | 38.8  |
# | Insulin Dependent Diabetes         |           16268 | 35.54 |
# | Hypothyroidism                     |           10649 | 23.26 |
# | Recent Steroid Use (for > 10 days) |             559 |  1.22 |
# | Hyperthyroidism                    |             452 |  0.99 |
# | Hypercalcemia                      |              64 |  0.14 |
# | Cushing's Syndrome                 |              22 |  0.05 |
# +------------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Pulmonary:
# +--------------------------+-----------------+-------+
# | second                   |   noAnnotations |     % |
# |--------------------------+-----------------+-------|
# | COPD                     |           19067 | 47.97 |
# | Asthma                   |            8242 | 20.74 |
# | Home Oxygen              |            4963 | 12.49 |
# | Respiratory Failure      |            3573 |  8.99 |
# | Pulmonary Function Tests |            2831 |  7.12 |
# | Restrictive Disease      |             894 |  2.25 |
# | Sarcoidosis              |             142 |  0.36 |
# | s                        |              32 |  0.08 |
# +--------------------------+-----------------+-------+
# ------------------------------
# The frequency of Neurologic:
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Strokes               |           10374 | 38.15 |
# | Seizures              |            7720 | 28.39 |
# | Dementia              |            4536 | 16.68 |
# | TIA(s)                |            3003 | 11.04 |
# | Neuromuscular Disease |            1127 |  4.14 |
# | Intracranial Mass     |             436 |  1.6  |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Hematology:
# +--------------+-----------------+-----+
# | second       |   noAnnotations |   % |
# |--------------+-----------------+-----|
# | Oncology (R) |           22345 | 100 |
# +--------------+-----------------+-----+
# ------------------------------
# The frequency of Renal  (R):
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Renal Insufficiency   |            8535 | 48.16 |
# | Renal Failure         |            7279 | 41.07 |
# | Chronic Stone Disease |            1019 |  5.75 |
# | s                     |             598 |  3.37 |
# | Neurogenic Bladder    |             270 |  1.52 |
# | RTA                   |              21 |  0.12 |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Gastrointestinal (R):
# +----------------------+-----------------+------+
# | second               |   noAnnotations |    % |
# |----------------------+-----------------+------|
# | Cirrhosis            |            7148 | 67.3 |
# | Peptic Ulcer Disease |            3112 | 29.3 |
# | s                    |             255 |  2.4 |
# | Hypersplenism        |             106 |  1   |
# +----------------------+-----------------+------+
# ------------------------------
# The frequency of Rheumatic:
# +----------------------+-----------------+-------+
# | second               |   noAnnotations |     % |
# |----------------------+-----------------+-------|
# | Rheumatoid Arthritis |            1973 | 74.01 |
# | SLE                  |             525 | 19.69 |
# | Vasculitis           |             110 |  4.13 |
# | Scleroderma          |              33 |  1.24 |
# | Dermato              |              25 |  0.94 |
# +----------------------+-----------------+-------+
# ------------------------------
# The frequency of Infectious Disease (R):
# +----------------------------------------+-----------------+-------+
# | second                                 |   noAnnotations |     % |
# |----------------------------------------+-----------------+-------|
# | Immunosuppression within past 6 months |            1053 | 54.53 |
# | HIV (only)                             |             676 | 35.01 |
# | AIDS                                   |             202 | 10.46 |
# +----------------------------------------+-----------------+-------+
# ------------------------------

# %%
from bigtree import Node, list_to_tree, tree_to_dot, dataframe_to_tree, tree_to_pillow

for disease in frequency1.index.get_level_values('first'):
    df_ = df1[df1['first'] == disease]
    # df_.set_index(['patientunitstayid', 'pasthistoryoffset'], inplace = True)
    
    paths_mult_ = df_.groupby('pasthistorypath', dropna = True)['pasthistorypath'].size().to_frame('noAnnotations')
    paths_mult_.reset_index(inplace=True)
    paths_mult_.sort_values('noAnnotations', ascending = False, inplace = True)

    paths_ = list(pd.unique(df_['pasthistorypath']))
    root_ = dataframe_to_tree(paths_mult_, sep = '/')
    root_.show(attr_list=["noAnnotations"])
    pillow_image_ = tree_to_pillow(root_)
    pillow_image_.save(porcesseddir2  + str(disease) + "selected_pastHistoryTree.jpg")
# Out:
#  Cardiovascular (R)
# ├── Hypertension Requiring Treatment
# │   └── hypertension requiring treatment [noAnnotations=56983]
# ├── Congestive Heart Failure
# │   ├── CHF [noAnnotations=14251]
# │   ├── CHF - severity unknown [noAnnotations=2524]
# │   ├── CHF - class III [noAnnotations=570]
# │   ├── CHF - class IV [noAnnotations=452]
# │   ├── CHF - class II [noAnnotations=443]
# │   └── CHF - class I [noAnnotations=233]
# ├── Arrhythmias
# │   ├── atrial fibrillation - chronic [noAnnotations=10881]
# │   ├── atrial fibrillation - intermittent [noAnnotations=3017]
# │   ├── ventricular tachycardia [noAnnotations=602]
# │   ├── SVT- other [noAnnotations=464]
# │   ├── sick sinus syndrome [noAnnotations=438]
# │   ├── ventricular fibrillation [noAnnotations=128]
# │   ├── ventricular ectopy [noAnnotations=118]
# │   └── MAT [noAnnotations=28]
# ├── Myocardial Infarction
# │   ├── MI - date unknown [noAnnotations=5826]
# │   ├── MI - remote [noAnnotations=1931]
# │   ├── MI - within 6 months [noAnnotations=1029]
# │   ├── MI - within 2 years [noAnnotations=667]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=620]
# │   └── MI - within 5 years [noAnnotations=582]
# ├── Peripheral Vascular Disease
# │   └── peripheral vascular disease [noAnnotations=5149]
# ├── Procedural Coronary Intervention
# │   ├── procedural coronary intervention - date unknown [noAnnotations=3815]
# │   ├── procedural coronary intervention - remote [noAnnotations=1321]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=806]
# │   ├── procedural coronary intervention - within 6 months [noAnnotations=704]
# │   ├── procedural coronary intervention - within 2 years [noAnnotations=638]
# │   └── procedural coronary intervention - within 5 years [noAnnotations=613]
# ├── Coronary Artery Bypass
# │   ├── CABG - date unknown [noAnnotations=3424]
# │   ├── CABG - remote [noAnnotations=2199]
# │   ├── CABG - within 5 years [noAnnotations=469]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=415]
# │   ├── CABG - within 6 months [noAnnotations=376]
# │   └── CABG - within 2 years [noAnnotations=272]
# ├── Venous Thrombosis
# │   ├── DVT - date unknown [noAnnotations=2817]
# │   ├── DVT - within 6 months [noAnnotations=529]
# │   ├── DVT - within 2 years [noAnnotations=352]
# │   ├── DVT - remote [noAnnotations=339]
# │   ├── DVT - within 5 years [noAnnotations=161]
# │   └── multiple
# │       └── multiple [noAnnotations=94]
# ├── Pacemaker
# │   ├── unknown pacer [noAnnotations=2540]
# │   ├── A
# │   │   └── V paced [noAnnotations=796]
# │   ├── V paced [noAnnotations=515]
# │   └── A paced [noAnnotations=168]
# ├── AICD
# │   └── AICD [noAnnotations=2270]
# ├── Angina
# │   ├── angina [noAnnotations=1970]
# │   ├── angina - severity unknown [noAnnotations=410]
# │   ├── angina - class II [noAnnotations=64]
# │   ├── angina - class III [noAnnotations=54]
# │   ├── angina - class I [noAnnotations=24]
# │   └── angina - class IV [noAnnotations=11]
# ├── Valve disease
# │   ├── MR [noAnnotations=1418]
# │   ├── AS [noAnnotations=1327]
# │   ├── s
# │   │   ├── p AVR [noAnnotations=1286]
# │   │   ├── p MVR [noAnnotations=592]
# │   │   └── p TVR [noAnnotations=81]
# │   ├── TR [noAnnotations=687]
# │   ├── AR [noAnnotations=387]
# │   ├── MS [noAnnotations=181]
# │   └── PS [noAnnotations=14]
# ├── Pulmonary Embolism
# │   ├── pulmonary embolism - date unknown [noAnnotations=1231]
# │   ├── pulmonary embolism - within 6 months [noAnnotations=394]
# │   ├── pulmonary embolism - within 2 years [noAnnotations=290]
# │   ├── pulmonary embolism - remote [noAnnotations=287]
# │   ├── pulmonary embolism - within 5 years [noAnnotations=126]
# │   └── multiple
# │       └── multiple [noAnnotations=61]
# ├── Exercise Tolerance
# │   ├── limited - household activities (1-4 mets) [noAnnotations=354]
# │   ├── moderate - stairs
# │   │   └── brisk walking (5-10 mets) [noAnnotations=84]
# │   ├── none - bed-ridden [noAnnotations=51]
# │   ├── unknown [noAnnotations=23]
# │   └── excellent - strenuous exercise (>10 mets) [noAnnotations=14]
# └── s
#     └── p Heart Transplant
#         └── s
#             └── p heart transplant [noAnnotations=114]
#  Endocrine (R)
# ├── Insulin Dependent Diabetes
# │   └── insulin dependent diabetes [noAnnotations=16268]
# ├── Non-Insulin Dependent Diabetes
# │   ├── medication dependent [noAnnotations=13678]
# │   └── non-medication dependent [noAnnotations=4082]
# ├── Hypothyroidism
# │   └── hypothyroidism [noAnnotations=10649]
# ├── Recent Steroid Use (for > 10 days)
# │   └── recent steroid use for > 10 days [noAnnotations=559]
# ├── Hyperthyroidism
# │   └── hyperthyroidism [noAnnotations=452]
# ├── Hypercalcemia
# │   └── hypercalcemia [noAnnotations=64]
# └── Cushing's Syndrome
#     └── Cushing's syndrome [noAnnotations=22]
#  Pulmonary
# ├── COPD
# │   ├── COPD  - moderate [noAnnotations=9063]
# │   ├── COPD  - severe [noAnnotations=5135]
# │   └── COPD  - no limitations [noAnnotations=4869]
# ├── Asthma
# │   └── asthma [noAnnotations=8242]
# ├── Home Oxygen
# │   └── home oxygen [noAnnotations=4963]
# ├── Respiratory Failure
# │   ├── respiratory failure - within 6 months [noAnnotations=1533]
# │   ├── respiratory failure - date unknown [noAnnotations=933]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=537]
# │   ├── respiratory failure - within 2 years [noAnnotations=287]
# │   ├── respiratory failure - remote [noAnnotations=162]
# │   └── respiratory failure - within 5 years [noAnnotations=121]
# ├── Restrictive Disease
# │   └── restrictive pulmonary disease [noAnnotations=894]
# ├── Pulmonary Function Tests
# │   ├── FEV1
# │   │   └── FVC Ratio
# │   │       └── FEV1
# │   │           ├── FVC ratio >80 [noAnnotations=295]
# │   │           ├── FVC ratio 71-80 [noAnnotations=133]
# │   │           ├── FVC ratio 51-60 [noAnnotations=116]
# │   │           ├── FVC ratio 61-70 [noAnnotations=71]
# │   │           ├── FVC ratio 41-50 [noAnnotations=61]
# │   │           ├── FVC ratio 31-40 [noAnnotations=36]
# │   │           └── FVC ratio <30 [noAnnotations=3]
# │   ├── FVC (%)
# │   │   ├── FVC >80 [noAnnotations=263]
# │   │   ├── FVC 51-60 [noAnnotations=140]
# │   │   ├── FVC 41-50 [noAnnotations=126]
# │   │   ├── FVC 61-70 [noAnnotations=113]
# │   │   ├── FVC 71-80 [noAnnotations=59]
# │   │   ├── FVC 31-40 [noAnnotations=58]
# │   │   └── FVC <30 [noAnnotations=34]
# │   ├── FEV1 (%)
# │   │   ├── FEV1 41-50 [noAnnotations=257]
# │   │   ├── FEV1 31-40 [noAnnotations=195]
# │   │   ├── FEV1 >80 [noAnnotations=177]
# │   │   ├── FEV1 51-60 [noAnnotations=161]
# │   │   ├── FEV1 61-70 [noAnnotations=125]
# │   │   ├── FEV1 <30 [noAnnotations=97]
# │   │   └── FEV1 71-80 [noAnnotations=92]
# │   └── DLCO (%)
# │       ├── DLCO 31-40 [noAnnotations=52]
# │       ├── DLCO <30 [noAnnotations=46]
# │       ├── DLCO 51-60 [noAnnotations=43]
# │       ├── DLCO 71-80 [noAnnotations=33]
# │       ├── DLCO 41-50 [noAnnotations=17]
# │       ├── DLCO >80 [noAnnotations=15]
# │       └── DLCO 61-70 [noAnnotations=13]
# ├── Sarcoidosis
# │   └── sarcoidosis [noAnnotations=142]
# └── s
#     └── p Lung Transplant
#         └── s
#             └── p lung transplant [noAnnotations=32]
#  Neurologic
# ├── Strokes
# │   ├── stroke - date unknown [noAnnotations=6399]
# │   ├── stroke - remote [noAnnotations=1191]
# │   ├── stroke - within 6 months [noAnnotations=984]
# │   ├── stroke - within 2 years [noAnnotations=716]
# │   ├── stroke - within 5 years [noAnnotations=712]
# │   └── multiple
# │       └── multiple [noAnnotations=372]
# ├── Dementia
# │   └── dementia [noAnnotations=4536]
# ├── Seizures
# │   ├── generalized seizures [noAnnotations=3758]
# │   ├── other seizures [noAnnotations=3270]
# │   ├── focal seizures [noAnnotations=405]
# │   └── petite mal seizures [noAnnotations=287]
# ├── TIA(s)
# │   ├── TIA(s) - date unknown [noAnnotations=2188]
# │   ├── TIA(s) - remote [noAnnotations=297]
# │   ├── TIA(s) - within 6 months [noAnnotations=166]
# │   ├── TIA(s) - within 2 years [noAnnotations=139]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=130]
# │   └── TIA(s) - within 5 years [noAnnotations=83]
# ├── Neuromuscular Disease
# │   └── neuromuscular disease [noAnnotations=1127]
# └── Intracranial Mass
#     └── intracranial mass [noAnnotations=436]
#  Hematology
# └── Oncology (R)
#     ├── Cancer
#     │   ├── Cancer-Primary Site
#     │   │   ├── breast [noAnnotations=2259]
#     │   │   ├── lung [noAnnotations=1944]
#     │   │   ├── prostate [noAnnotations=1738]
#     │   │   ├── colon [noAnnotations=1484]
#     │   │   ├── other [noAnnotations=911]
#     │   │   ├── bladder [noAnnotations=650]
#     │   │   ├── kidney [noAnnotations=469]
#     │   │   ├── melanoma [noAnnotations=403]
#     │   │   ├── uterus [noAnnotations=370]
#     │   │   ├── head and neck [noAnnotations=349]
#     │   │   ├── esophagus [noAnnotations=290]
#     │   │   ├── pancreas - adenocarcinoma [noAnnotations=246]
#     │   │   ├── liver [noAnnotations=229]
#     │   │   ├── brain [noAnnotations=210]
#     │   │   ├── ovary [noAnnotations=206]
#     │   │   ├── unknown [noAnnotations=128]
#     │   │   ├── stomach [noAnnotations=113]
#     │   │   ├── testes [noAnnotations=90]
#     │   │   ├── bile duct [noAnnotations=49]
#     │   │   ├── bone [noAnnotations=48]
#     │   │   ├── sarcoma [noAnnotations=23]
#     │   │   ├── pancreas - islet cell [noAnnotations=21]
#     │   │   └── none [noAnnotations=16]
#     │   ├── Metastases
#     │   │   ├── lung [noAnnotations=636]
#     │   │   ├── other [noAnnotations=624]
#     │   │   ├── liver [noAnnotations=605]
#     │   │   ├── bone [noAnnotations=602]
#     │   │   ├── brain [noAnnotations=421]
#     │   │   ├── nodes [noAnnotations=270]
#     │   │   ├── intra-abdominal [noAnnotations=190]
#     │   │   └── carcinomatosis [noAnnotations=41]
#     │   └── Hematologic Malignancy
#     │       ├── non-Hodgkins lymphoma [noAnnotations=566]
#     │       ├── multiple myeloma [noAnnotations=369]
#     │       ├── CLL [noAnnotations=198]
#     │       ├── AML [noAnnotations=191]
#     │       ├── other hematologic malignancy [noAnnotations=185]
#     │       ├── Hodgkins disease [noAnnotations=162]
#     │       ├── leukemia - other [noAnnotations=123]
#     │       ├── CML [noAnnotations=67]
#     │       └── ALL [noAnnotations=36]
#     ├── Cancer Therapy
#     │   ├── Chemotherapy
#     │   │   ├── chemotherapy within past mo. [noAnnotations=1534]
#     │   │   ├── chemotherapy within past 6 mos. [noAnnotations=629]
#     │   │   ├── BMT within past 12 mos. [noAnnotations=39]
#     │   │   ├── Cis-platinum [noAnnotations=29]
#     │   │   ├── Alkylating agents (bleomycin, cytoxan, cyclophos.) [noAnnotations=26]
#     │   │   ├── Anthracyclines (adriamycin, daunorubicin) [noAnnotations=12]
#     │   │   └── Vincristine [noAnnotations=5]
#     │   └── Radiation Therapy within past 6 months
#     │       ├── primary site [noAnnotations=525]
#     │       ├── lung [noAnnotations=216]
#     │       ├── other [noAnnotations=137]
#     │       ├── brain [noAnnotations=136]
#     │       ├── bone [noAnnotations=68]
#     │       ├── liver [noAnnotations=18]
#     │       └── nodes [noAnnotations=13]
#     ├── Hemolytic Anemia
#     │   └── hemolytic anemia [noAnnotations=468]
#     ├── Hypercoagulable Condition
#     │   └── hypercoagulable condition [noAnnotations=214]
#     ├── ITP
#     │   └── ITP [noAnnotations=196]
#     ├── Clotting Disorder
#     │   └── clotting disorder [noAnnotations=173]
#     ├── Sickle Cell Disease
#     │   └── sickle cell disease [noAnnotations=167]
#     ├── Aplastic Anemia
#     │   └── aplastic anemia [noAnnotations=87]
#     └── Myeloproliferative Disease
#         ├── essential thrombocytosis [noAnnotations=52]
#         ├── myelofibrosis [noAnnotations=42]
#         └── polycythemia vera [noAnnotations=27]
#  Renal  (R)
# ├── Renal Failure
# │   ├── renal failure - hemodialysis [noAnnotations=4371]
# │   ├── renal failure- not currently dialyzed [noAnnotations=2539]
# │   └── renal failure - peritoneal dialysis [noAnnotations=369]
# ├── Renal Insufficiency
# │   ├── renal insufficiency - creatinine 1-2 [noAnnotations=3722]
# │   ├── renal insufficiency - baseline creatinine unknown [noAnnotations=2749]
# │   ├── renal insufficiency - creatinine 2-3 [noAnnotations=1372]
# │   ├── renal insufficiency - creatinine 3-4 [noAnnotations=371]
# │   ├── renal insufficiency - creatinine > 5 [noAnnotations=174]
# │   └── renal insufficiency - creatinine 4-5 [noAnnotations=147]
# ├── Chronic Stone Disease
# │   └── chronic kidney stones [noAnnotations=1019]
# ├── s
# │   └── p Renal Transplant
# │       └── s
# │           └── p renal transplant [noAnnotations=598]
# ├── Neurogenic Bladder
# │   └── neurogenic bladder [noAnnotations=270]
# └── RTA
#     └── renal tubular acidosis [noAnnotations=21]
#  Gastrointestinal (R)
# ├── Cirrhosis
# │   ├── clinical diagnosis [noAnnotations=2608]
# │   ├── UGI bleeding [noAnnotations=1084]
# │   ├── varices [noAnnotations=1067]
# │   ├── ascites [noAnnotations=982]
# │   ├── encephalopathy [noAnnotations=832]
# │   ├── jaundice [noAnnotations=347]
# │   ├── biopsy proven [noAnnotations=197]
# │   └── coma [noAnnotations=31]
# ├── Peptic Ulcer Disease
# │   ├── peptic ulcer disease [noAnnotations=2145]
# │   └── peptic ulcer disease with h
# │       └── o GI bleeding [noAnnotations=967]
# ├── s
# │   └── p Liver Transplant
# │       └── s
# │           └── p liver transplant [noAnnotations=255]
# └── Hypersplenism
#     └── splenomegaly [noAnnotations=106]
#  Rheumatic
# ├── Rheumatoid Arthritis
# │   └── rheumatoid arthritis [noAnnotations=1973]
# ├── SLE
# │   └── SLE [noAnnotations=525]
# ├── Vasculitis
# │   └── vasculitis [noAnnotations=110]
# ├── Scleroderma
# │   └── scleroderma [noAnnotations=33]
# └── Dermato
#     └── Polymyositis
#         └── dermatomyositis [noAnnotations=25]
#  Infectious Disease (R)
# ├── HIV (only)
# │   └── HIV positive [noAnnotations=676]
# ├── Immunosuppression within past 6 months
# │   ├── other immunosuppressive medications [noAnnotations=442]
# │   ├── >= 20 mg prednisone per day or equivalent [noAnnotations=429]
# │   └── both prednisone and other immunosuppressive medications [noAnnotations=182]
# └── AIDS
#     └── AIDS [noAnnotations=202]

# %% [markdown]
# ## graph structure to encode past history

# %%
df1= pd.read_csv(porcesseddir2 + 'selected_pastHistory.csv')
df1 = df1.set_index(['patientunitstayid', 'hospitaladmitoffset','pasthistoryoffset'])
df1.sort_index(level = ['patientunitstayid','hospitaladmitoffset', 'pasthistoryoffset'], inplace = True)

df=df1.copy()

# %%
import networkx as nx
from node2vec import Node2Vec  

# Create the graph
G = nx.DiGraph()

# Adding edges based on 'first', 'second', and 'third' relationships
for _, row in df.iterrows():
    if pd.notna(row['first']) and pd.notna(row['second']):
        G.add_edge(row['first'], row['second'])
    if pd.notna(row['second']) and pd.notna(row['third']):
        G.add_edge(row['second'], row['third'])

# Generate embeddings using node2vec
node2vec = Node2Vec(G, dimensions=16, walk_length=10, num_walks=100,workers=4)
model = node2vec.fit(window=5,min_count=1, batch_words=4)


# Obtain node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes()}

# Map embeddings back to the dataset
def get_embedding(row):
    first_embed = node_embeddings.get(row['first'], [0]*16)
    second_embed = node_embeddings.get(row['second'], [0]*16)
    third_embed = node_embeddings.get(row['third'], [0]*16)
    # Combine embeddings, here by concatenation
    return first_embed + second_embed + third_embed

df['past_history_embedding'] = df.apply(get_embedding, axis=1)
# Out:
# Computing transition probabilities: 100%|██████████| 209/209 [00:00<00:00, 53812.74it/s]
# Generating walks (CPU: 1): 100%|██████████| 25/25 [00:00<00:00, 319.47it/s]
# Generating walks (CPU: 2): 100%|██████████| 25/25 [00:00<00:00, 329.21it/s]
# Generating walks (CPU: 3): 100%|██████████| 25/25 [00:00<00:00, 325.69it/s]
# Generating walks (CPU: 4): 100%|██████████| 25/25 [00:00<00:00, 329.53it/s]

#         -0.08275615,  0.10243377, -0.01614547, -0.22877292, -0.22866608,
#          0.12816161], dtype=float32),
#  'renal tubular acidosis': array([ 0.10924044, -0.38886133,  0.18677987,  0.08665012,  0.18335336,
#          0.07382744,  0.43141177, -0.01744661, -0.30577603,  0.10238698,
#         -0.05587232,  0.02427624, -0.17846261, -0.12329269, -0.22510369,
#          0.06216182], dtype=float32),
#  'PS': array([ 0.09277117, -0.05457261, -0.02806034, -0.03748728,  0.09823506,
#         -0.03785843,  0.0606197 ,  0.01552643, -0.05929358, -0.02015761,
#         -0.02493944,  0.00629064,  0.00219477, -0.01951869, -0.08345849,
#          0.03154034], dtype=float32)}

# %%
df['past_history_embedding'].head(n=10)
# Out:
# patientunitstayid  hospitaladmitoffset  pasthistoryoffset
# 141168             0                    60                   [0.2933618, -0.49751872, 0.22474355, 0.0679363...
#                                         60                   [0.3326282, -0.48305237, 0.13405658, 0.1085471...
#                                         60                   [0.29043144, -0.40905985, 0.14089367, 0.125428...
#                                         60                   [0.45944792, -0.67532706, 0.07522632, 0.301377...
#                                         60                   [1.2620435, -1.8737543, 2.139895, 3.0927072, -...
#                                         60                   [0.24295178, -0.4183576, 0.062236793, 0.236971...
#                                         60                   [0.28360644, -0.6707699, 0.09989484, 0.2075078...
#                                         60                   [0.3910076, -0.48419255, 0.05271908, 0.2797892...
#                                         115                  [0.3326282, -0.48305237, 0.13405658, 0.1085471...
#                                         115                  [0.45944792, -0.67532706, 0.07522632, 0.301377...
# Name: past_history_embedding, dtype: object

# %%
df.head(n=10)
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       115                Female  70
#                                       115                Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#                                       115                Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#                                       60                  Renal  (R)/Renal Failure/renal failure- not c...
#                                       60                  Rheumatic/Rheumatoid Arthritis/rheumatoid art...
#                                       60                  Cardiovascular (R)/Arrhythmias/atrial fibrill...
#                                       115                              Cardiovascular (R)/Valve disease/AS
#                                       115                 Cardiovascular (R)/Hypertension Requiring Tre...
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                          Renal  (R)
#                                       60                           Rheumatic
#                                       60                  Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#                                       115                 Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#                                       60                                    Renal Failure
#                                       60                             Rheumatoid Arthritis
#                                       60                                      Arrhythmias
#                                       115                                   Valve disease
#                                       115                Hypertension Requiring Treatment
#
#                                                                                          third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                COPD  - no limitations
#                                       60                                                    AS
#                                       60                                        CHF - class II
#                                       60                      hypertension requiring treatment
#                                       60                                                  AICD
#                                       60                 renal failure- not currently dialyzed
#                                       60                                  rheumatoid arthritis
#                                       60                         atrial fibrillation - chronic
#                                       115                                                   AS
#                                       115                     hypertension requiring treatment
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       115                  NaN
#                                       115                  NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       115                  Direct Admit
#                                       115                  Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       115                           84.3
#                                       115                           84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       115                           85.8
#                                       115                           85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       115                               3596
#                                       115                               3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       115                               Death
#                                       115                               Death
#
#                                                         unitdischargestatus  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       115                           Expired
#                                       115                           Expired
#
#                                                                                     past_history_embedding
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 [0.2933618, -0.49751872, 0.22474355, 0.0679363...
#                                       60                 [0.3326282, -0.48305237, 0.13405658, 0.1085471...
#                                       60                 [0.29043144, -0.40905985, 0.14089367, 0.125428...
#                                       60                 [0.45944792, -0.67532706, 0.07522632, 0.301377...
#                                       60                 [1.2620435, -1.8737543, 2.139895, 3.0927072, -...
#                                       60                 [0.24295178, -0.4183576, 0.062236793, 0.236971...
#                                       60                 [0.28360644, -0.6707699, 0.09989484, 0.2075078...
#                                       60                 [0.3910076, -0.48419255, 0.05271908, 0.2797892...
#                                       115                [0.3326282, -0.48305237, 0.13405658, 0.1085471...
#                                       115                [0.45944792, -0.67532706, 0.07522632, 0.301377...

# %%
# df.to_csv(porcesseddir2 + 'embedded_pastHistory.csv')

df=pd.read_csv(porcesseddir2 + 'embedded_pastHistory.csv')

# %%
df2=df.copy()

# %%
df2['past_history_embedding']=np.array( df2['past_history_embedding'],dtype=object)

# %%
df2.head()
# Out:
#                                                          gender age  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#                                       60                 Female  70
#
#                                                                                      apacheadmissiondx  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#                                       60                 Rhythm disturbance (atrial, supraventricular)
#
#                                                                                            pasthistorypath  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                             Pulmonary/COPD/COPD  - no limitations
#                                       60                               Cardiovascular (R)/Valve disease/AS
#                                       60                  Cardiovascular (R)/Congestive Heart Failure/C...
#                                       60                  Cardiovascular (R)/Hypertension Requiring Tre...
#                                       60                                      Cardiovascular (R)/AICD/AICD
#
#                                                                        first  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           Pulmonary
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#                                       60                  Cardiovascular (R)
#
#                                                                                    second  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                             COPD
#                                       60                                    Valve disease
#                                       60                         Congestive Heart Failure
#                                       60                 Hypertension Requiring Treatment
#                                       60                                             AICD
#
#                                                                                     third  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                           COPD  - no limitations
#                                       60                                               AS
#                                       60                                   CHF - class II
#                                       60                 hypertension requiring treatment
#                                       60                                             AICD
#
#                                                         fourth  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#                                       60                   NaN
#
#                                                         unitadmitsource  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#                                       60                   Direct Admit
#
#                                                          admissionweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#                                       60                            84.3
#
#                                                          dischargeweight  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#                                       60                            85.8
#
#                                                          unitdischargeoffset  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#                                       60                                3596
#
#                                                         unitdischargelocation  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#                                       60                                Death
#
#                                                         unitdischargestatus  \
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#                                       60                            Expired
#
#                                                                                     past_history_embedding
# patientunitstayid hospitaladmitoffset pasthistoryoffset
# 141168            0                   60                 [0.2933618, -0.49751872, 0.22474355, 0.0679363...
#                                       60                 [0.3326282, -0.48305237, 0.13405658, 0.1085471...
#                                       60                 [0.29043144, -0.40905985, 0.14089367, 0.125428...
#                                       60                 [0.45944792, -0.67532706, 0.07522632, 0.301377...
#                                       60                 [1.2620435, -1.8737543, 2.139895, 3.0927072, -...

# %% [markdown]
# ## max pooling Aggregation

# %%
# df1['past_history_embedding'] = df1['past_history_embedding'].apply(np.array)

def max_pooling(embeddings):
    # Stack embeddings and take the maximum across each dimension
    return np.max(np.vstack(embeddings), axis=0)

df_max_pooled = df2.groupby('patientunitstayid')['past_history_embedding'].apply(max_pooling).reset_index()

df_max_pooled.rename(columns={'past_history_embedding': 'max_pooled_embedding'}, inplace=True)

print(df_max_pooled.head())
# Out:
#    patientunitstayid                               max_pooled_embedding
# 0             141168  [1.2620435, -0.40905985, 2.139895, 3.0927072, ...
# 1             141265  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2             141266  [0.45944792, -0.32571676, 0.28904593, 0.498963...
# 3             141276  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4             141284  [0.45944792, -0.62813926, 0.16925086, 0.403259...

# %%
df_max = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_max = df_max.groupby('patientunitstayid').first().reset_index()
df_max.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [1.2620435, -0.40905985, 2.139895, 3.0927072, ...
# 1  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2  [0.45944792, -0.32571676, 0.28904593, 0.498963...
# 3  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4  [0.45944792, -0.62813926, 0.16925086, 0.403259...

# %%
# df_max.to_csv(porcesseddir2 + 'embedded_pastHistory_max.csv')

# %% [markdown]
# ## sum aggregation

# %%
def sum_aggregation(embeddings):
    return np.sum(np.vstack(embeddings), axis=0)

# Group by 'patientunitstayid' and apply sum aggregation
df_sum_aggregated = df.groupby('patientunitstayid')['past_history_embedding'].apply(sum_aggregation).reset_index()

# Rename the column to indicate sum-aggregated embeddings
df_sum_aggregated.rename(columns={'past_history_embedding': 'sum_aggregated_embedding'}, inplace=True)

# Display the result
print(df_sum_aggregated.head())
# Out:
#    patientunitstayid                           sum_aggregated_embedding
# 0             141168  [5.618785, -8.485628, 3.641164, 5.667907, 5.22...
# 1             141265  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2             141266  [4.754561, -6.8487663, 2.0775619, 3.9187584, 6...
# 3             141276  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4             141284  [1.4101926, -2.6069326, 0.48895437, 1.4092741,...

# %%
df_sum = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_sum = df_sum.groupby('patientunitstayid').first().reset_index()
df_sum.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [1.2620435, -0.40905985, 2.139895, 3.0927072, ...
# 1  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2  [0.45944792, -0.32571676, 0.28904593, 0.498963...
# 3  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4  [0.45944792, -0.62813926, 0.16925086, 0.403259...

# %%
# df_sum.to_csv(porcesseddir2 + 'embedded_pastHistory_sum.csv')

# %% [markdown]
# ## avg aggregation

# %%
def average_aggregation(embeddings):
    return np.mean(np.vstack(embeddings), axis=0)

# Group by 'patientunitstayid' and apply average aggregation
df_avg_aggregated = df.groupby('patientunitstayid')['past_history_embedding'].apply(average_aggregation).reset_index()

# Rename the column to indicate average-aggregated embeddings
df_avg_aggregated.rename(columns={'past_history_embedding': 'avg_aggregated_embedding'}, inplace=True)

# Display the result
print(df_avg_aggregated.head())
# Out:
#    patientunitstayid                           avg_aggregated_embedding
# 0             141168  [0.40134177, -0.6061163, 0.26008314, 0.4048505...
# 1             141265  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2             141266  [0.31697074, -0.45658442, 0.13850412, 0.261250...
# 3             141276  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4             141284  [0.35254815, -0.65173316, 0.12223859, 0.352318...

# %%
df_avg = df2.drop(columns=['past_history_embedding','pasthistorypath','first','second','third','fourth']).merge(df_max_pooled, on='patientunitstayid', how='left')
df_avg = df_avg.groupby('patientunitstayid').first().reset_index()
df_avg.head()
# Out:
#    patientunitstayid  gender age  \
# 0             141168  Female  70
# 1             141265    Male  67
# 2             141266    Male  73
# 3             141276  Female  59
# 4             141284    Male  63
#
#                                apacheadmissiondx       unitadmitsource  \
# 0  Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1           CVA, cerebrovascular accident/stroke          Direct Admit
# 2          Sepsis, renal/UTI (including bladder)  Emergency Department
# 3   Arrest, respiratory (without cardiac arrest)          Direct Admit
# 4                                         Anemia          Direct Admit
#
#    admissionweight  dischargeweight  unitdischargeoffset  \
# 0             84.3             85.8                 3596
# 1            100.0             91.8                 6068
# 2            120.4            112.9                 1501
# 3            156.6            156.6                 1684
# 4              NaN             88.5                 2076
#
#   unitdischargelocation unitdischargestatus  \
# 0                 Death             Expired
# 1                 Floor               Alive
# 2                 Floor               Alive
# 3                  Home               Alive
# 4                 Floor               Alive
#
#                                 max_pooled_embedding
# 0  [1.2620435, -0.40905985, 2.139895, 3.0927072, ...
# 1  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 2  [0.45944792, -0.32571676, 0.28904593, 0.498963...
# 3  [0.2664819, -0.5805186, 0.06527747, 0.2963526,...
# 4  [0.45944792, -0.62813926, 0.16925086, 0.403259...

# %%
df_avg.to_csv(porcesseddir2 + 'embedded_pastHistory_avg.csv')
