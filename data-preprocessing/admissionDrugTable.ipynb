# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
datadir = '/home/mei/nas/docker/dataset/EICU/eicu-collaborative-research-database-2.0/'
porcesseddir = '/home/mei/nas/docker/processedData/'

# %%
def round_up(x, base=5):
    return base * round(x/base)

# %%
df = pd.read_csv(datadir + 'admissionDrug.csv.gz', compression='gzip')

# %%
df.head()
# Out:
#    admissiondrugid  patientunitstayid  drugoffset  drugenteredoffset  \
# 0          1589228             242954          64                 79
# 1          2063596             243285          29                 39
# 2          2063595             243285          29                 39
# 3          2063590             243285          29                 39
# 4          2063594             243285          29                 39
#
#   drugnotetype specialtytype   usertype  rxincluded  writtenineicu  \
# 0    Admission   eCM Primary  THC Nurse        True           True
# 1    Admission   eCM Primary  THC Nurse       False           True
# 2    Admission   eCM Primary  THC Nurse       False           True
# 3    Admission   eCM Primary  THC Nurse       False           True
# 4    Admission   eCM Primary  THC Nurse       False           True
#
#                                             drugname  drugdosage drugunit  \
# 0  ELIQUIS                                       ...         0.0
# 1  VICTOZA 2-PAK                                 ...         0.0
# 2  POTASSIUM CHLORIDE                            ...         0.0
# 3  CITALOPRAM HBR                                ...         0.0
# 4  OMEPRAZOLE                                    ...         0.0
#
#   drugadmitfrequency  drughiclseqno
# 0                             37792
# 1                             36436
# 2                               549
# 3                             10321
# 4                              4673

# %%
df_patient = pd.read_csv(porcesseddir + 'selected_patients.csv')

# %%
df_patient.head()
# Out:
#    patientunitstayid  hospitaladmitoffset  gender   age  \
# 0             141168                    0  Female    70
# 1             141178                  -14  Female    52
# 2             141197                  -25    Male    71
# 3             141208                   -1  Female    25
# 4             141229                   -4  Female  > 89
#
#                                    apacheadmissiondx       unitadmitsource  \
# 0      Rhythm disturbance (atrial, supraventricular)          Direct Admit
# 1                                                NaN  Emergency Department
# 2                                  Sepsis, pulmonary  Emergency Department
# 3  Overdose, sedatives, hypnotics, antipsychotics...  Emergency Department
# 4                      CHF, congestive heart failure  Emergency Department
#
#    admissionweight  dischargeweight unitdischargelocation unitdischargestatus
# 0             84.3             85.8                 Death             Expired
# 1             54.4             54.4  Step-Down Unit (SDU)               Alive
# 2            102.1            102.1  Step-Down Unit (SDU)               Alive
# 3             95.3             95.3                  Home               Alive
# 4             89.8             86.6                 Floor               Alive

# %%
df_selected_addissionDrug = pd.merge(df_patient, df, on='patientunitstayid')

# %%
df_selected_addissionDrug.head()
# Out:
#    patientunitstayid  hospitaladmitoffset gender age  \
# 0             242954                    0   Male  84
# 1             243285                 -157   Male  67
# 2             243285                 -157   Male  67
# 3             243285                 -157   Male  67
# 4             243285                 -157   Male  67
#
#                    apacheadmissiondx       unitadmitsource  admissionweight  \
# 0  Hemorrhage/hematoma, intracranial          Direct Admit            106.3
# 1              Diabetic ketoacidosis  Emergency Department             96.7
# 2              Diabetic ketoacidosis  Emergency Department             96.7
# 3              Diabetic ketoacidosis  Emergency Department             96.7
# 4              Diabetic ketoacidosis  Emergency Department             96.7
#
#    dischargeweight unitdischargelocation unitdischargestatus  ...  \
# 0            106.8                 Floor               Alive  ...
# 1             98.8                 Floor               Alive  ...
# 2             98.8                 Floor               Alive  ...
# 3             98.8                 Floor               Alive  ...
# 4             98.8                 Floor               Alive  ...
#
#    drugnotetype  specialtytype   usertype rxincluded writtenineicu  \
# 0     Admission    eCM Primary  THC Nurse       True          True
# 1     Admission    eCM Primary  THC Nurse      False          True
# 2     Admission    eCM Primary  THC Nurse      False          True
# 3     Admission    eCM Primary  THC Nurse      False          True
# 4     Admission    eCM Primary  THC Nurse      False          True
#
#                                             drugname  drugdosage  drugunit  \
# 0  ELIQUIS                                       ...         0.0
# 1  VICTOZA 2-PAK                                 ...         0.0
# 2  POTASSIUM CHLORIDE                            ...         0.0
# 3  CITALOPRAM HBR                                ...         0.0
# 4  OMEPRAZOLE                                    ...         0.0
#
#   drugadmitfrequency  drughiclseqno
# 0                             37792
# 1                             36436
# 2                               549
# 3                             10321
# 4                              4673
#
# [5 rows x 23 columns]

# %%
# Set indices
df = df_selected_addissionDrug.set_index(['patientunitstayid', 'drugoffset'])
df = df.drop(df.index[np.where(df.index.get_level_values('drugoffset') < 0)])
df = df.drop(columns = ['admissiondrugid'])
df.sort_index(level = ['patientunitstayid', 'drugoffset'], inplace = True)
df = df[['drugname', 'drugdosage', 'drugunit', 'drughiclseqno','gender','age','apacheadmissiondx','unitadmitsource','admissionweight','dischargeweight','unitdischargelocation','unitdischargestatus']]
# Resample every 5 mins
df.rename(round_up, level = 'drugoffset', inplace = True)
df['drugname'] = df['drugname'].str.split(' ').str[0].str.lower()

# %%
df.head()
# Out:
#                                 drugname  drugdosage drugunit  drughiclseqno  \
# patientunitstayid drugoffset
# 242954            65             eliquis         0.0                   37792
# 243285            30             victoza         0.0                   36436
#                   30           potassium         0.0                     549
#                   30          citalopram         0.0                   10321
#                   30          omeprazole         0.0                    4673
#
#                              gender age                  apacheadmissiondx  \
# patientunitstayid drugoffset
# 242954            65           Male  84  Hemorrhage/hematoma, intracranial
# 243285            30           Male  67              Diabetic ketoacidosis
#                   30           Male  67              Diabetic ketoacidosis
#                   30           Male  67              Diabetic ketoacidosis
#                   30           Male  67              Diabetic ketoacidosis
#
#                                    unitadmitsource  admissionweight  \
# patientunitstayid drugoffset
# 242954            65                  Direct Admit            106.3
# 243285            30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#
#                               dischargeweight unitdischargelocation  \
# patientunitstayid drugoffset
# 242954            65                    106.8                 Floor
# 243285            30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#
#                              unitdischargestatus
# patientunitstayid drugoffset
# 242954            65                       Alive
# 243285            30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive

# %%
# df.to_csv(porcesseddir + 'selected_admissionDrug.csv',  index=True)
# print("Data exported successfully to 'selected_admissionDrug.csv'.")
# Out:
# Data exported successfully to 'selected_admissionDrug.csv'.

# %%
selected_addDx_p=len(list(df.index.get_level_values('patientunitstayid').unique()))
selected_addDx_x=len(df)
print("There are {} unique patientunitstayid in the selected patients with the total {} records.".format(selected_addDx_p,selected_addDx_x))
# Out:
# There are 22031 unique patientunitstayid in the selected patients with the total 455903 records.

# %%
freq_addrug = pd.DataFrame()
freq_addrug['noAnnotations'] = df['drugname'].value_counts() 
freq_addrug['%'] = df['drugname'].value_counts() / len(df.index) * 100

freq_addrug
# Out:
#                   noAnnotations         %
# drugname
# aspirin                   14503  3.181159
# lisinopril                 9676  2.122381
# vitamin                    8341  1.829556
# lasix                      7801  1.711110
# albuterol                  7763  1.702774
# ...                         ...       ...
# oregano                       1  0.000219
# multivits,stress              1  0.000219
# bioflavonoid                  1  0.000219
# thermotabs                    1  0.000219
# tart                          1  0.000219
#
# [2786 rows x 2 columns]

# %%
# # Import libraries
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import psycopg2
# import getpass
# import pdvega
# import seaborn as sns
# # for configuring connection ∏
# from configobj import ConfigObj
# import os

# %matplotlib inline

# %%
# # Create a database connection using settings from config file
# config='../db/config.ini'

# # connection info
# conn_info = dict()
# if os.path.isfile(config):
#     config = ConfigObj(config)
#     conn_info["sqluser"] = config['username']
#     conn_info["sqlpass"] = config['password']
#     conn_info["sqlhost"] = config['host']
#     conn_info["sqlport"] = config['port']
#     conn_info["dbname"] = config['dbname']
#     conn_info["schema_name"] = config['schema_name']
# else:
#     conn_info["sqluser"] = 'postgres'
#     conn_info["sqlpass"] = ''
#     conn_info["sqlhost"] = 'localhost'
#     conn_info["sqlport"] = 5432
#     conn_info["dbname"] = 'eicu'
#     conn_info["schema_name"] = 'public,eicu_crd'
    
# # Connect to the eICU database
# print('Database: {}'.format(conn_info['dbname']))
# print('Username: {}'.format(conn_info["sqluser"]))
# if conn_info["sqlpass"] == '':
#     # try connecting without password, i.e. peer or OS authentication
#     try:
#         if (conn_info["sqlhost"] == 'localhost') & (conn_info["sqlport"]=='5432'):
#             con = psycopg2.connect(dbname=conn_info["dbname"],
#                                    user=conn_info["sqluser"])            
#         else:
#             con = psycopg2.connect(dbname=conn_info["dbname"],
#                                    host=conn_info["sqlhost"],
#                                    port=conn_info["sqlport"],
#                                    user=conn_info["sqluser"])
#     except:
#         conn_info["sqlpass"] = getpass.getpass('Password: ')

#         con = psycopg2.connect(dbname=conn_info["dbname"],
#                                host=conn_info["sqlhost"],
#                                port=conn_info["sqlport"],
#                                user=conn_info["sqluser"],
#                                password=conn_info["sqlpass"])
# query_schema = 'set search_path to ' + conn_info['schema_name'] + ';'
# Out:
# Database: eicu
# Username: postgres

# %%
# from sqlalchemy import create_engine
# con= create_engine('postgresql://eicu@localhost:5432/eicu')

# %%
# query = query_schema + """
# select *
# from admissiondrug
# order by drugoffset
# """

# df_addrug = pd.read_sql_query(query, con)
# n_drug = df_addrug['patientunitstayid'].nunique()
# print("There are {} patients in the admission drug record.".format(n_drug))
# Out:
# There are 40740 patients in the admission drug record.

# %%
# query = query_schema + """

# with selected_patients as (
# SELECT DISTINCT patientunitstayid,gender,age,apacheadmissiondx,unitadmitsource,admissionweight,	dischargeweight,unitdischargelocation,	unitdischargestatus
# FROM patient
# WHERE unitadmitsource IN ('Emergency Department', 'Direct Admit') 
# )
# select  adrug.admissiondrugid ,adrug.drugoffset,adrug.drugname, adrug.drugdosage, adrug.drugunit, adrug.drugadmitfrequency, sp.*
# from admissiondrug adrug
# join selected_patients sp
#   on adrug.patientunitstayid = sp.patientunitstayid
#  """
# df_addrug_selected = pd.read_sql_query(query, con)

# %%
# df_addrug_selected.head(n=10)
# Out:
#    admissiondrugid  drugoffset  \
# 0          1589228          64
# 1          2063596          29
# 2          2063592          29
# 3          2063589          29
# 4          2063595          29
# 5          2063591          29
# 6          2063588          29
# 7          2063594          29
# 8          2063590          29
# 9          2063593          29
#
#                                             drugname  drugdosage drugunit  \
# 0  ELIQUIS                                       ...         0.0
# 1  VICTOZA 2-PAK                                 ...         0.0
# 2  METFORMIN HCL                                 ...         0.0
# 3  LIPITOR                                       ...         0.0
# 4  POTASSIUM CHLORIDE                            ...         0.0
# 5  FLECAINIDE ACETATE                            ...         0.0
# 6  ASPIRIN                                       ...         0.0
# 7  OMEPRAZOLE                                    ...         0.0
# 8  CITALOPRAM HBR                                ...         0.0
# 9  NAPROXEN                                      ...         0.0
#
#   drugadmitfrequency  patientunitstayid gender age  \
# 0                                242954   Male  84
# 1                                243285   Male  67
# 2                                243285   Male  67
# 3                                243285   Male  67
# 4                                243285   Male  67
# 5                                243285   Male  67
# 6                                243285   Male  67
# 7                                243285   Male  67
# 8                                243285   Male  67
# 9                                243285   Male  67
#
#                    apacheadmissiondx       unitadmitsource  admissionweight  \
# 0  Hemorrhage/hematoma, intracranial          Direct Admit            106.3
# 1              Diabetic ketoacidosis  Emergency Department             96.7
# 2              Diabetic ketoacidosis  Emergency Department             96.7
# 3              Diabetic ketoacidosis  Emergency Department             96.7
# 4              Diabetic ketoacidosis  Emergency Department             96.7
# 5              Diabetic ketoacidosis  Emergency Department             96.7
# 6              Diabetic ketoacidosis  Emergency Department             96.7
# 7              Diabetic ketoacidosis  Emergency Department             96.7
# 8              Diabetic ketoacidosis  Emergency Department             96.7
# 9              Diabetic ketoacidosis  Emergency Department             96.7
#
#    dischargeweight unitdischargelocation unitdischargestatus
# 0            106.8                 Floor               Alive
# 1             98.8                 Floor               Alive
# 2             98.8                 Floor               Alive
# 3             98.8                 Floor               Alive
# 4             98.8                 Floor               Alive
# 5             98.8                 Floor               Alive
# 6             98.8                 Floor               Alive
# 7             98.8                 Floor               Alive
# 8             98.8                 Floor               Alive
# 9             98.8                 Floor               Alive

# %%
# df_addrug_selected.to_csv('/Users/meisun/Documents/study/thesis/master project/data-preprocessing/selected_patients_admissionDrug.csv')

# %%
# df_addrug_selected = pd.read_csv('/Users/meisun/Documents/study/thesis/master project/data-preprocessing/selected_patients_admissionDrug.csv')

# %%
# n_drug_selected= len(df_addrug_selected['drugname'])
# print("There are {} selected patients in the admission drug table with total {} records.".format(df_addrug_selected['patientunitstayid'].nunique(),n_drug_selected))
# Out:
# There are 23518 selected patients in the admission drug table with total 490189 records.

# %%
df=df_addrug_selected.copy()
df= df.set_index(['patientunitstayid', 'drugoffset'])
df= df.drop(df.index[np.where(df.index.get_level_values('drugoffset') < 0)])
df.sort_index(level = ['patientunitstayid', 'drugoffset'], inplace = True)
df= df[['drugname', 'drugdosage', 'drugunit','drugadmitfrequency', 'gender','age','apacheadmissiondx','unitadmitsource','admissionweight',	'dischargeweight','unitdischargelocation',	'unitdischargestatus']]
# Resample every 5 mins
df.rename(round_up, level = 'drugoffset', inplace = True)
df['drugname'] = df['drugname'].str.split(' ').str[0].str.lower()

# %%
df.head(n=10)
# Out:
#                                 drugname  drugdosage drugunit  \
# patientunitstayid drugoffset
# 242954            65             eliquis         0.0
# 243285            30             victoza         0.0
#                   30           metformin         0.0
#                   30             lipitor         0.0
#                   30           potassium         0.0
#                   30          flecainide         0.0
#                   30             aspirin         0.0
#                   30          omeprazole         0.0
#                   30          citalopram         0.0
#                   30            naproxen         0.0
#
#                              drugadmitfrequency gender age  \
# patientunitstayid drugoffset
# 242954            65                              Male  84
# 243285            30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#                   30                              Male  67
#
#                                               apacheadmissiondx  \
# patientunitstayid drugoffset
# 242954            65          Hemorrhage/hematoma, intracranial
# 243285            30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#                   30                      Diabetic ketoacidosis
#
#                                    unitadmitsource  admissionweight  \
# patientunitstayid drugoffset
# 242954            65                  Direct Admit            106.3
# 243285            30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#                   30          Emergency Department             96.7
#
#                               dischargeweight unitdischargelocation  \
# patientunitstayid drugoffset
# 242954            65                    106.8                 Floor
# 243285            30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#                   30                     98.8                 Floor
#
#                              unitdischargestatus
# patientunitstayid drugoffset
# 242954            65                       Alive
# 243285            30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive
#                   30                       Alive

# %%
freq_addrug = pd.DataFrame()
freq_addrug['noAnnotations'] = df['drugname'].value_counts() 
freq_addrug['%'] = df['drugname'].value_counts() / len(df.index) * 100

freq_addrug
# Out:
#                   noAnnotations         %
# drugname
# aspirin                   14503  3.181159
# lisinopril                 9676  2.122381
# vitamin                    8341  1.829556
# lasix                      7801  1.711110
# albuterol                  7763  1.702774
# ...                         ...       ...
# goniosoft                     1  0.000219
# oregano                       1  0.000219
# multivits,stress              1  0.000219
# bioflavonoid                  1  0.000219
# tart                          1  0.000219
#
# [2786 rows x 2 columns]
