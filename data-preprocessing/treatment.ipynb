# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
datadir = '/home/mei/nas/docker/dataset/EICU/eicu-collaborative-research-database-2.0/'
porcesseddir = '/home/mei/nas/docker/processedData/'

# %%
def round_up(x, base=5):
    return base * round(x/base)

# %%
df = pd.read_csv(datadir + 'treatment.csv.gz', compression='gzip')
df.head()
# Out:
#    treatmentid  patientunitstayid  treatmentoffset  \
# 0      8399138             242040              198
# 1      8626134             242040              198
# 2      8517569             242040              198
# 3      9597686             242040              616
# 4      9334096             242040              618
#
#                                      treatmentstring  activeupondischarge
# 0  cardiovascular|hypertension|angiotensin II rec...                False
# 1  cardiovascular|myocardial ischemia / infarctio...                False
# 2  infectious diseases|medications|therapeutic an...                False
# 3  cardiovascular|non-operative procedures|diagno...                False
# 4  infectious diseases|medications|therapeutic an...                 True

# %%
df_patient = pd.read_csv(porcesseddir + 'selected_patients.csv')
df_selected_tr= pd.merge(df_patient, df, on='patientunitstayid')
df_selected_tr.head()
# Out:
#    patientunitstayid  hospitaladmitoffset gender age  \
# 0             242040                  -31   Male  78
# 1             242040                  -31   Male  78
# 2             242040                  -31   Male  78
# 3             242040                  -31   Male  78
# 4             242040                  -31   Male  78
#
#                apacheadmissiondx       unitadmitsource  admissionweight  \
# 0  CHF, congestive heart failure  Emergency Department            91.71
# 1  CHF, congestive heart failure  Emergency Department            91.71
# 2  CHF, congestive heart failure  Emergency Department            91.71
# 3  CHF, congestive heart failure  Emergency Department            91.71
# 4  CHF, congestive heart failure  Emergency Department            91.71
#
#    dischargeweight unitdischargelocation unitdischargestatus  treatmentid  \
# 0             91.7                 Floor               Alive      8399138
# 1             91.7                 Floor               Alive      8626134
# 2             91.7                 Floor               Alive      8517569
# 3             91.7                 Floor               Alive      9597686
# 4             91.7                 Floor               Alive      9334096
#
#    treatmentoffset                                    treatmentstring  \
# 0              198  cardiovascular|hypertension|angiotensin II rec...
# 1              198  cardiovascular|myocardial ischemia / infarctio...
# 2              198  infectious diseases|medications|therapeutic an...
# 3              616  cardiovascular|non-operative procedures|diagno...
# 4              618  infectious diseases|medications|therapeutic an...
#
#    activeupondischarge
# 0                False
# 1                False
# 2                False
# 3                False
# 4                 True
